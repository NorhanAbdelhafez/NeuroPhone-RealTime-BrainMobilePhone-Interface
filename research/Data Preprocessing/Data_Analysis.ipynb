# %% [markdown]
# <a href="https://colab.research.google.com/github/norhan333/NeuroPhone-RealTime-BrainMobilePhone-Interface/blob/main/3.%20Software%20Implementation/Data_Analysis_and_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !!pip install -q MOABB
# Out:
# ['\x1b[?25l     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/140.8 KB\x1b \x1b?\x1b eta \x1b-:--:--\x1b',
#  '\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b\x1b╸\x1b\x1b━━\x1b \x1b133.1/140.8 KB\x1b \x1b4.2 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b140.8/140.8 KB\x1b \x1b2.2 MB/s\x1b eta \x1b0:00:00\x1b',
#  '\x1b[?25h\x1b[?25l     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/7.6 MB\x1b \x1b?\x1b eta \x1b-:--:--\x1b',
#  '\x1b[2K     \x1b━━━━━\x1b\x1b╸\x1b\x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b1.1/7.6 MB\x1b \x1b34.4 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━━━━━━\x1b\x1b╺\x1b\x1b━━━━━━━━━━━━━━━\x1b \x1b4.6/7.6 MB\x1b \x1b65.8 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b\x1b╸\x1b \x1b7.6/7.6 MB\x1b \x1b78.4 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b\x1b╸\x1b \x1b7.6/7.6 MB\x1b \x1b78.4 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b7.6/7.6 MB\x1b \x1b48.2 MB/s\x1b eta \x1b0:00:00\x1b',
#  '\x1b[?25h\x1b[?25l     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/662.4 KB\x1b \x1b?\x1b eta \x1b-:--:--\x1b',
#  '\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b\x1b╸\x1b \x1b655.4/662.4 KB\x1b \x1b65.2 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b662.4/662.4 KB\x1b \x1b10.9 MB/s\x1b eta \x1b0:00:00\x1b',
#  '\x1b[?25h\x1b[?25l     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/90.6 KB\x1b \x1b?\x1b eta \x1b-:--:--\x1b',
#  '\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b90.6/90.6 KB\x1b \x1b5.3 MB/s\x1b eta \x1b0:00:00\x1b',
#  '\x1b[?25h  Preparing metadata (setup.py) ... \x1b[?25l\x1b[?25hdone',
#  '\x1b[?25l     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/245.3 KB\x1b \x1b?\x1b eta \x1b-:--:--\x1b',
#  '\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b\x1b╺\x1b\x1b━\x1b \x1b235.5/245.3 KB\x1b \x1b83.5 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b\x1b╺\x1b\x1b━\x1b \x1b235.5/245.3 KB\x1b \x1b83.5 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b\x1b╺\x1b\x1b━\x1b \x1b235.5/245.3 KB\x1b \x1b83.5 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K     \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b245.3/245.3 KB\x1b \x1b1.5 MB/s\x1b eta \x1b0:00:00\x1b',
#  '\x1b[?25h  Building wheel for pyriemann (setup.py) ... \x1b[?25l\x1b[?25hdone']

# %%
# !pip install pywd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pywd
#   Downloading pywd-0.0.3.tar.gz (1.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pywd, docopt
#   Building wheel for pywd (setup.py) ... done
#   Created wheel for pywd: filename=pywd-0.0.3-py3-none-any.whl size=2238 sha256=1cc70e2161e376e783eefa11c595642a40214f8c7e58289e5f5aa9024bb3c80f
#   Stored in directory: /root/.cache/pip/wheels/b5/7a/5f/1512c6efc8bed9ef6a8c12ffea89c0b879e3dd195043cb999a
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=46099334bbb0a88ec5cc94ed6033d9bfec2383ad808ab9b1b215e37bc0018d2a
#   Stored in directory: /root/.cache/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built pywd docopt
# Installing collected packages: docopt, pywd
# Successfully installed docopt-0.6.2 pywd-0.0.3

# %%
# !pip install mlflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mlflow
#   Downloading mlflow-2.1.1-py3-none-any.whl (16.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 49.7 MB/s eta 0:00:00
# Collecting importlib-metadata!=4.7.0,<6,>=3.7.0
#   Downloading importlib_metadata-5.2.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: pandas<2 in /usr/local/lib/python3.8/dist-packages (from mlflow) (1.3.5)
# Requirement already satisfied: scipy<2 in /usr/local/lib/python3.8/dist-packages (from mlflow) (1.7.3)
# Requirement already satisfied: pyarrow<11,>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from mlflow) (9.0.0)
# Requirement already satisfied: entrypoints<1 in /usr/local/lib/python3.8/dist-packages (from mlflow) (0.4)
# Requirement already satisfied: Jinja2<4,>=2.11 in /usr/local/lib/python3.8/dist-packages (from mlflow) (3.1.2)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /usr/local/lib/python3.8/dist-packages (from mlflow) (3.19.6)
# Requirement already satisfied: pytz<2023 in /usr/local/lib/python3.8/dist-packages (from mlflow) (2022.7.1)
# Collecting querystring-parser<2
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Collecting docker<7,>=4.0.0
#   Downloading docker-6.0.1-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.5/147.5 KB 18.0 MB/s eta 0:00:00
# Collecting gunicorn<21
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 10.1 MB/s eta 0:00:00
# Collecting alembic<2
#   Downloading alembic-1.9.4-py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.5/210.5 KB 21.1 MB/s eta 0:00:00
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.8/dist-packages (from mlflow) (3.4.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from mlflow) (0.4.3)
# Collecting gitpython<4,>=2.1.0
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 20.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.8/dist-packages (from mlflow) (1.22.4)
# Collecting packaging<23
#   Downloading packaging-22.0-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 KB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.8/dist-packages (from mlflow) (3.5.3)
# Requirement already satisfied: pyyaml<7,>=5.1 in /usr/local/lib/python3.8/dist-packages (from mlflow) (5.4.1)
# Requirement already satisfied: cloudpickle<3 in /usr/local/lib/python3.8/dist-packages (from mlflow) (2.2.1)
# Collecting shap<1,>=0.40
#   Downloading shap-0.41.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (575 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 575.9/575.9 KB 40.4 MB/s eta 0:00:00
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.8/dist-packages (from mlflow) (8.1.3)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.8/dist-packages (from mlflow) (1.0.2)
# Requirement already satisfied: sqlalchemy<2,>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from mlflow) (1.4.46)
# Collecting databricks-cli<1,>=0.8.7
#   Downloading databricks-cli-0.17.4.tar.gz (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.3/82.3 KB 8.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.8/dist-packages (from mlflow) (2.25.1)
# Requirement already satisfied: Flask<3 in /usr/local/lib/python3.8/dist-packages (from mlflow) (2.2.3)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from alembic<2->mlflow) (5.12.0)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 KB 9.2 MB/s eta 0:00:00
# Collecting pyjwt>=1.7.0
#   Downloading PyJWT-2.6.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: oauthlib>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from databricks-cli<1,>=0.8.7->mlflow) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.8/dist-packages (from databricks-cli<1,>=0.8.7->mlflow) (0.8.10)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.8/dist-packages (from databricks-cli<1,>=0.8.7->mlflow) (1.15.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.8/dist-packages (from docker<7,>=4.0.0->mlflow) (1.26.14)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.5.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 6.4 MB/s eta 0:00:00
# Collecting requests<3,>=2.17.3
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.8/dist-packages (from Flask<3->mlflow) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.8/dist-packages (from Flask<3->mlflow) (2.2.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=3.0 in /usr/local/lib/python3.8/dist-packages (from gunicorn<21->mlflow) (57.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata!=4.7.0,<6,>=3.7.0->mlflow) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from Jinja2<4,>=2.11->mlflow) (2.1.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4->mlflow) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4->mlflow) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4->mlflow) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4->mlflow) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.17.3->mlflow) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.17.3->mlflow) (2.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.17.3->mlflow) (3.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn<2->mlflow) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn<2->mlflow) (1.2.0)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.8/dist-packages (from shap<1,>=0.40->mlflow) (4.64.1)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.8/dist-packages (from shap<1,>=0.40->mlflow) (0.56.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.8/dist-packages (from sqlalchemy<2,>=1.4.0->mlflow) (2.0.2)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba->shap<1,>=0.40->mlflow) (0.39.1)
# Building wheels for collected packages: databricks-cli
#   Building wheel for databricks-cli (setup.py) ... done
#   Created wheel for databricks-cli: filename=databricks_cli-0.17.4-py3-none-any.whl size=142894 sha256=56fa23d98e920b07b19c54d83233ab5a05673adcfb052634980115e9fa7add6d
#   Stored in directory: /root/.cache/pip/wheels/48/7c/6e/4bf2c1748c7ecf994ca951591de81674ed6bf633e1e337d873
# Successfully built databricks-cli
# Installing collected packages: websocket-client, smmap, slicer, requests, querystring-parser, pyjwt, packaging, Mako, importlib-metadata, gunicorn, gitdb, docker, databricks-cli, alembic, shap, gitpython, mlflow
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.0
#     Uninstalling packaging-23.0:
#       Successfully uninstalled packaging-23.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.0.0
#     Uninstalling importlib-metadata-6.0.0:
#       Successfully uninstalled importlib-metadata-6.0.0
# Successfully installed Mako-1.2.4 alembic-1.9.4 databricks-cli-0.17.4 docker-6.0.1 gitdb-4.0.10 gitpython-3.1.31 gunicorn-20.1.0 importlib-metadata-5.2.0 mlflow-2.1.1 packaging-22.0 pyjwt-2.6.0 querystring-parser-1.2.4 requests-2.28.2 shap-0.41.0 slicer-0.0.7 smmap-5.0.0 websocket-client-1.5.1

# %%
import numpy as np
import scipy.signal
import scipy.io as sio
import matplotlib
from matplotlib import pyplot as plt
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
import mne
from pywt import wavedec 

import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score
import mlflow
import mlflow.sklearn

# %%
import moabb
from moabb.datasets import EPFLP300, utils
from moabb.evaluations import CrossSessionEvaluation
from moabb.paradigms import LeftRightImagery
from moabb.pipelines.features import LogVariance
from mne.filter import construct_iir_filter
moabb.set_log_level("info")


import math
from sklearn.metrics import confusion_matrix

# %%
dataset=EPFLP300()

# %%
def getData(subjectNumbers,dataset=EPFLP300()):
  return dataset.get_data(subjectNumbers)

# %%
def getSubjectData(subjectNumber,session_number,run_number):
  session = f'session_{session_number}'
  run = f'run_{run_number}'
  return getData([subjectNumber])[subjectNumber][session][run]

# %% [markdown]
# **Necessary Information**:
#
#
# *   We have data of 8 subjects. (from 1 to 9, 5 is excluded).
# *   Each subject has data of 4 recording sessions.
# *   Each session has 6 runs.
# *   Each run is a recording of raw EEG signals in a duration of ~ 60 s.

# %%
data= getSubjectData(1,1,2)
# Out:
# /usr/local/lib/python3.8/dist-packages/moabb/datasets/download.py:53: RuntimeWarning: Setting non-standard config type: "MNE_DATASETS_EPFLP300_PATH"
#   set_config(key, get_config("MNE_DATA"))
# Downloading data from 'http://documents.epfl.ch/groups/m/mm/mmspg/www/BCI/p300/subject1.zip' to file '/root/mne_data/MNE-epflp300-data/groups/m/mm/mmspg/www/BCI/p300/subject1.zip'.
# MNE_DATA is not already configured. It will be set to default location in the home directory - /root/mne_data
# All datasets will be downloaded to this location, if anything is already downloaded, please move manually to this location
# 100%|████████████████████████████████████████| 267M/267M [00:00<00:00, 100GB/s]
# SHA256 hash of downloaded file: a493408349f2b5fc1a94f0bb5ed3f6cdcb2cdb290af7cb4c118cbc65c7ee1128
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# unzip /root/mne_data/MNE-epflp300-data/groups/m/mm/mmspg/www/BCI/p300/subject1.zip

# %%
data.to_data_frame()
# Out:
#              time          Fp1           AF3            F7            F3  \
# 0        0.000000  3316.546875  27753.171875 -10176.140625  20151.265625
# 1        0.000488  3315.968750  27752.437500 -10177.875000  20152.468750
# 2        0.000977  3316.781250  27753.343750 -10177.250000  20153.718750
# 3        0.001465  3317.843750  27755.750000 -10175.625000  20155.125000
# 4        0.001953  3314.734375  27753.921875 -10178.703125  20153.703125
# ...           ...          ...           ...           ...           ...
# 108538  52.997070  3113.375000  27905.906250 -10241.281250  20333.625000
# 108539  52.997559  3118.625000  27912.562500 -10231.718750  20339.562500
# 108540  52.998047  3122.671875  27915.015625 -10225.265625  20341.984375
# 108541  52.998535  3124.875000  27917.968750 -10221.281250  20344.375000
# 108542  52.999023  3126.250000  27921.250000 -10220.281250  20347.562500
#
#                 FC1         FC5            T7           C3           CP1  ...  \
# 0       1058.828125  199.390625  -9028.859375  2934.171875 -13486.109375  ...
# 1       1059.343750  201.250000  -9028.406250  2935.312500 -13486.312500  ...
# 2       1058.625000  204.187500  -9028.125000  2936.281250 -13486.218750  ...
# 3       1060.750000  207.968750  -9026.312500  2937.593750 -13483.781250  ...
# 4       1058.859375  207.296875  -9029.171875  2934.015625 -13486.828125  ...
# ...             ...         ...           ...          ...           ...  ...
# 108538   648.000000  695.343750 -10490.687500  2581.093750 -13860.312500  ...
# 108539   655.500000  700.750000 -10482.625000  2587.093750 -13854.406250  ...
# 108540   659.234375  700.828125 -10477.421875  2589.078125 -13850.640625  ...
# 108541   661.031250  700.531250 -10475.468750  2592.562500 -13846.062500  ...
# 108542   664.187500  698.468750 -10475.281250  2594.281250 -13846.062500  ...
#
#                 FC2           F4            F8          AF4           Fp2  \
# 0       6319.703125 -4055.171875 -18351.046875  3962.765625  23307.703125
# 1       6319.187500 -4054.531250 -18350.781250  3961.062500  23307.000000
# 2       6319.937500 -4054.593750 -18349.437500  3962.250000  23308.125000
# 3       6321.656250 -4052.218750 -18348.718750  3964.968750  23309.906250
# 4       6319.546875 -4055.671875 -18352.453125  3959.734375  23307.578125
# ...             ...          ...           ...          ...           ...
# 108538  5967.062500 -4845.062500 -18090.281250  3526.343750  23437.187500
# 108539  5974.625000 -4838.000000 -18085.062500  3530.625000  23444.437500
# 108540  5978.421875 -4833.328125 -18081.765625  3535.390625  23448.296875
# 108541  5983.062500 -4829.000000 -18077.437500  3538.781250  23451.781250
# 108542  5985.812500 -4825.031250 -18074.968750  3539.062500  23455.406250
#
#                  Fz           Cz       MA1       MA2  STI
# 0       5552.828125  8215.421875  0.006227 -0.006227  0.0
# 1       5551.625000  8214.500000  0.006224 -0.006224  0.0
# 2       5551.312500  8214.781250  0.006221 -0.006221  0.0
# 3       5550.718750  8216.500000  0.006222 -0.006222  0.0
# 4       5547.734375  8213.921875  0.006223 -0.006223  0.0
# ...             ...          ...       ...       ...  ...
# 108538  4869.718750  8191.875000  0.006235 -0.006235  0.0
# 108539  4875.750000  8198.718750  0.006239 -0.006239  0.0
# 108540  4879.421875  8202.015625  0.006242 -0.006242  0.0
# 108541  4882.656250  8205.437500  0.006243 -0.006243  0.0
# 108542  4883.718750  8209.062500  0.006244 -0.006244  0.0
#
# [108543 rows x 36 columns]

# %% [markdown]
# Since we are dealing with MNE library, it prodives the data in form of **RawArray**.
#
# The dimension of the RawArray is (num_Channels x num_Samples).

# %%
data.get_data
# Out:
# <bound method get_data of <RawArray | 35 x 108543 (53.0 s), ~29.0 MB, data loaded>>

# %% [markdown]
# **Necessary Information about the structure of a single run**:
#
# ![Screenshot 2023-02-25 123533.png](data:image/png;base64,...)
#
# *   We essentially have 6 runs inside a session because we have 6 images in our paradigm. So each run is essentially dedicated for one image.
# *   For a single run, the subject is asked to focus on one image.
# *   For a single run, the images on the grid were flashed in random sequence. The sequence of flashes was block-randomized, this means that after six flashes each image was flashed once, after twelve flashes each image was flashed twice, etc.
# *   The number of blocks was chosen randomly between 20 and 25. On average 22.5 (23) blocks of six flashes were displayed in one run.
# *   knowing that the subject only focuses on one image in a single run, and we have ~23 block of flashes, thus we have 23 target signals and 23x5 = 115 non-target signals inside single run.
# *   Each flash of an images lasts for 400 ms, The images only flash in the first 100 ms, and remains not flashed for the remaining 300 ms.
# *   knowing that we have ~23 block of flashes in a single run, where each block consists of 6 flashes (one for each image), so we have 23x6 = 138 flashes inside the run. and knowing that each flash has a duration of 400 ms, so the run lasts for 138x0.4 = 55.2 seconds.

# %% [markdown]
# Count of Stimulus in samples (i.e. count of target segments & non-target).
#
# Target has value of 2 and Non-Target hase value of 1 in STI column of the dataset.
#
# **Note**: the rest of EEG recording in the dataframe has values of 0, meaning that it's neither target nor non-target.

# %%
df=data.to_data_frame()
df.STI.value_counts()
# Out:
# 0.0    108411
# 1.0       110
# 2.0        22
# Name: STI, dtype: int64

# %% [markdown]
# to Get index of First flash (Stimulus)

# %%
df.STI.ne(0).idxmax()
# Out:
# 819

# %%
df.iloc[819]
# Out:
# time        0.399902
# Fp1      3328.312500
# AF3     27783.406250
# F7     -10150.718750
# F3      20180.312500
# FC1      1091.687500
# FC5       218.812500
# T7      -9003.937500
# C3       2941.031250
# CP1    -13475.156250
# CP5    -12517.750000
# P7       1107.437500
# P3      -6947.781250
# Pz      10481.000000
# PO3     -3456.750000
# O1       -334.875000
# Oz       -424.156250
# O2        872.343750
# PO4     -7620.500000
# P4      -6183.968750
# P8      -7528.875000
# CP6     -6005.562500
# CP2     -5770.468750
# C4       7649.968750
# T8       9276.406250
# FC6     -5270.093750
# FC2      6337.281250
# F4      -4022.687500
# F8     -18288.281250
# AF4      3971.781250
# Fp2     23336.687500
# Fz       5577.406250
# Cz       8230.750000
# MA1         0.006242
# MA2        -0.006242
# STI         1.000000
# Name: 819, dtype: float64

# %% [markdown]
# Get Sample indicies of Target stimulus (flash)

# %%
Target = df[df['STI']==2].index.values
val = np.full(len(Target),2)
target = pd.DataFrame(Target)
target["value"]=val
target
# Out:
#          0  value
# 0     3280      2
# 1     9023      2
# 2    10663      2
# 3    18046      2
# 4    22148      2
# 5    27891      2
# 6    31172      2
# 7    37736      2
# 8    41017      2
# 9    46759      2
# 10   53323      2
# 11   56604      2
# 12   62367      2
# 13   65648      2
# 14   73033      2
# 15   74673      2
# 16   81235      2
# 17   84518      2
# 18   89440      2
# 19   97644      2
# 20  100106      2
# 21  108308      2

# %% [markdown]
# Get Sample indicies of Non-Target stimulus (flash)

# %%
nonTarget = df[df['STI']==1].index.values
value = np.full(len(nonTarget),1)
nontarget= pd.DataFrame(nonTarget)
nontarget["value"]=value
nontarget
# Out:
#           0  value
# 0       819      1
# 1      1638      1
# 2      2459      1
# 3      4099      1
# 4      4921      1
# ..      ...    ...
# 105  104206      1
# 106  105027      1
# 107  105910      1
# 108  106667      1
# 109  107489      1
#
# [110 rows x 2 columns]

# %% [markdown]
# Combine both target and non-target dataframes and sort (based on time) target and non-target samples.

# %%
df2 = nontarget.append(target,ignore_index=True) 
TargetNnonTarget = df2.sort_values(by=[0],ignore_index=True)
TargetNnonTarget
# Out:
#           0  value
# 0       819      1
# 1      1638      1
# 2      2459      1
# 3      3280      2
# 4      4099      1
# ..      ...    ...
# 127  105027      1
# 128  105910      1
# 129  106667      1
# 130  107489      1
# 131  108308      2
#
# 3682  5579.187500  8242.593750  0.006289 -0.006289  0.0
# 3683  5579.078125  8242.015625  0.006286 -0.006286  0.0
# 3684  5571.000000  8235.906250  0.006280 -0.006280  0.0
# 3685  5566.187500  8230.468750  0.006276 -0.006276  0.0
#
# [2048 rows x 36 columns]

# %% [markdown]
# **Cropping Segment out of RawArray & plotting it.**

# %%
d = data.copy()
segment.reset_index(inplace=True)
tmax= segment['time'][len(segment)-1]
tmin= segment['time'][0]

# %%
seg=d.crop(tmin=tmin, tmax=tmax)

# %%
seg.plot(n_channels=1)
# Out:
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %% [markdown]
# Applying Preprocessing steps on a segment and plot it. Ths steps are:
#
#
# *   Filtering, bandpass butterworth filter (1-12 hz).
# *   Resampling to 32hz.
# *   Scaling to (-1,1).

# %%
def filterAndResampleData(data,seglen,lp=12,hp=1,sf=2048,resample=32):
  iir_params = dict(order=4, ftype='butter', output='sos')  
  iir_params = construct_iir_filter(iir_params, [hp,lp], None, sf, 'bandpass', return_copy=False)
  data.filter(method='iir',iir_params=iir_params,h_freq=hp,l_freq=lp)
  return data.resample(math.ceil(((sf*32)/seglen)))

# %%
filtered = filterAndResampleData(seg,2048)

# %%
filtered.plot(n_channels=1)
# Out:
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
filtered.to_data_frame()
# Out:
#        time        Fp1        AF3         F7         F3        FC1        FC5  \
# 0   0.00000   0.047157   0.072182   0.706882  -0.053740   0.053783  -0.723678
# 1   0.03125 -14.916303 -12.772545 -40.920632 -10.985045 -13.973217  -4.856563
# 2   0.06250 -13.636871 -10.064415 -30.408699  -7.354167 -12.226369  -1.807094
# 3   0.09375 -15.325464 -12.046944 -30.245409  -9.872017 -20.929015  -3.812052
# 4   0.12500 -18.066431 -17.128757 -34.429455 -15.632085 -22.196360 -10.754161
# 5   0.15625 -10.725624 -10.874214 -31.070064 -11.444440 -12.022939  -9.276203
# 6   0.18750 -11.699024 -14.035085 -27.885651 -14.271408 -15.623211 -12.543368
# 7   0.21875 -21.297439 -24.004075 -31.059880 -23.211060 -26.855315 -17.928712
# 8   0.25000 -21.794514 -22.702551 -25.301263 -21.858264 -29.444805 -19.873999
# 9   0.28125 -14.842020 -13.432380 -17.138009 -10.871623 -14.633539  -7.443699
# 10  0.31250 -12.152799 -11.043305 -12.410376 -10.444279  -4.182578  -7.418728
# 11  0.34375  -8.331446  -6.901150 -11.072189  -8.245801  -0.377749  -2.497622
# 12  0.37500  -0.444602   1.897645  -5.054093   0.857007   0.202001   5.401532
# 13  0.40625   7.304998   7.766009   6.780176   6.444491   3.600867   4.795457
# 14  0.43750  16.352562  16.333585  12.394004  17.424770  18.622030  19.039578
# 15  0.46875  20.622875  18.048340  16.622897  19.057534  22.065853  24.820358
# 16  0.50000  13.155745  10.152040  17.311359  10.048306  10.910726  13.274970
# 17  0.53125   5.205052   4.846008  10.839942   5.854700   5.087138   8.609631
# 18  0.56250   6.422868   6.616860  13.103751   7.846641  10.737857   6.777313
# 19  0.59375   4.534801   4.403461   7.816853   5.803825  10.086115   4.799055
# 30 -16.530522 -18.363600 -12.863067 -17.709420  0.006263 -0.006263  0.0
# 31 -19.811361 -21.899198 -18.273975 -15.510558  0.006253 -0.006253  0.0
#
# [32 rows x 36 columns]

# %%
def getTargetData(df):
  Target = df[df['STI']==2].index.values
  val = np.full(len(Target),2)
  targetDF= pd.DataFrame(Target)
  targetDF["value"]=val
  return targetDF

# %%
def getNonTargetData(df):
  nonTarget = df[df['STI']==1].index.values
  value = np.full(len(nonTarget),1)
  nontargetDF= pd.DataFrame(nonTarget)
  nontargetDF["value"]=value
  return nontargetDF

# %%
def getTottalData(df):
  targetDF = getTargetData(df)
  nontargetDF = getNonTargetData(df)
  totaldf = nontargetDF.append(targetDF,ignore_index=True) 
  TargetNnonTarget = totaldf.sort_values(by=[0],ignore_index=True)
  return TargetNnonTarget

# %% [markdown]
# We extract **one feature vector** out of each single segment inside a run.
# So we end up with pairs of (feature vectors, label). Label is either target or non-target.

# %%
def scaleAndExtractFeatures(segment,runNum,segindx):
  scaler = MinMaxScaler(feature_range = (-1,1))
  df = segment.to_data_frame()
  columns = ['time', 'MA1', 'MA2' , 'STI']
  df.drop(columns,axis=1,inplace=True)
  featureVector = []
  for val in df.columns.values:
    vals=df[val].values.reshape(-1, 1)
    scaled = scaler.fit_transform(vals)
    # print("rum number: ",runNum,"\nsegment number",segindx)
    col= scaled.reshape(32,)
    cA2, cD2, cD1 = wavedec(col,'db1',level=2)
    featureVector.extend(cA2)
    featureVector.extend(cD2)
    featureVector.extend(cD1)
  return featureVector

# %%
def divideSingleRun(df, data,runNum):
  TargetNnonTarget= getTottalData(df)
  segments=[]
  output=[]
  length=len(TargetNnonTarget)
  for index, row in TargetNnonTarget.iterrows():
    if(index==length-1):
      Segment = df.iloc[TargetNnonTarget[0].iloc[index]:]
    else:
      Segment = df.iloc[TargetNnonTarget[0].iloc[index]:TargetNnonTarget[0].iloc[index]+2048]

    # crop segment from RawArray
    d = data.copy()
    Segment.reset_index(inplace=True)
    tmax= Segment['time'][len(Segment)-1]
    tmin= Segment['time'][0]
    seg=d.crop(tmin=tmin, tmax=tmax)

    # Filter and resample
    filtered = filterAndResampleData(seg,len(Segment))

    # Scale and extract features
    if(len(filtered.to_data_frame())!=32):
      continue
    featureVector= scaleAndExtractFeatures(filtered,runNum,index)

    segments.append(featureVector)
    output.append(TargetNnonTarget['value'].iloc[index])
  return segments, output

# %%
def prepareSubjectDataForSVM(subjectNumber):
  x_train=[]
  y_train=[]
  for sessionNumber in range(1,4):
    for runNumber in range(1,7):
      data=getSubjectData(subjectNumber,sessionNumber,runNumber)
      df=data.to_data_frame()
      segments, target = divideSingleRun(df, data, runNumber)
      x_train+=segments
      y_train+=target
    print("   session Number ",sessionNumber , " completed.......")
  x_test =[]
  y_test =[]
  for runNumber in range(1,7):
      data=getSubjectData(subjectNumber,4,runNumber)
      df=data.to_data_frame()
      segments, target = divideSingleRun(df, data,runNumber)
      x_test+=segments
      y_test+=target
  return x_train,y_train, x_test ,y_test

# %%
def SVM(subjectNumber):
  print("preparing Subject ",subjectNumber , " Data.......")
  x_train,y_train, x_test ,y_test=prepareSubjectDataForSVM(subjectNumber)
  clf = svm.SVC()
  clf.fit(x_train,y_train)
  predictions =clf.predict(x_test)
  print(subjectNumber , "accuracy score " , accuracy_score(predictions , y_test))
  
 
  cm = confusion_matrix(y_test,predictions,labels=[2,1])
  print(cm)
  print("______________________________________________")

# %%
def decisionTrees(subjectNumber):
  print("preparing Subject ",subjectNumber , " Data.......")
  x_train,y_train, x_test ,y_test=prepareSubjectDataForSVM(subjectNumber)
  with mlflow.start_run():
    decisionTreeClassifier = DecisionTreeClassifier()
    decisionTreeClassifier.fit(x_train,y_train)
    predictions =decisionTreeClassifier.predict(x_test)
    precision =  precision_score(y_test, predictions)
    recall = recall_score(y_test, predictions)
    accuracy = accuracy_score(y_test, predictions)
    mlflow.log_param("Subject number", subjectNumber)
    mlflow.log_param("Accuracy", accuracy)
    mlflow.log_metric("Recall", recall)
    mlflow.log_metric("Precision", precision)
    print(subjectNumber , "accuracy score " , accuracy_score(predictions , y_test))
  
    cm = confusion_matrix(y_test,predictions,labels=[2,1])
    print(cm)
    print("______________________________________________")

# %%
decisionTrees(1)
# Out:
# preparing Subject  1  Data.......
#    session Number  1  completed.......
#    session Number  2  completed.......
#    session Number  3  completed.......
# 1 accuracy score  0.7560975609756098
# [[ 33 102]
#  [ 98 587]]
# ______________________________________________

# %%
decisionTrees(2)
# Out:
# Downloading data from 'http://documents.epfl.ch/groups/m/mm/mmspg/www/BCI/p300/subject2.zip' to file '/root/mne_data/MNE-epflp300-data/groups/m/mm/mmspg/www/BCI/p300/subject2.zip'.
# preparing Subject  2  Data.......
# 100%|███████████████████████████████████████| 292M/292M [00:00<00:00, 61.9GB/s]
# SHA256 hash of downloaded file: 416006f6885e948bb48c6a1d26c403a166f4ca8bf7ab44df35301be34456d958
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# unzip /root/mne_data/MNE-epflp300-data/groups/m/mm/mmspg/www/BCI/p300/subject2.zip
#    session Number  1  completed.......
#    session Number  2  completed.......
#    session Number  3  completed.......
# 2 accuracy score  0.7298245614035088
# [[ 23 119]
#  [112 601]]
# ______________________________________________

# %%
decisionTrees(8)
# Out:
# Downloading data from 'http://documents.epfl.ch/groups/m/mm/mmspg/www/BCI/p300/subject8.zip' to file '/root/mne_data/MNE-epflp300-data/groups/m/mm/mmspg/www/BCI/p300/subject8.zip'.
# preparing Subject  8  Data.......
# 100%|███████████████████████████████████████| 266M/266M [00:00<00:00, 92.1GB/s]
# SHA256 hash of downloaded file: 020ceea17f16f1c67729a3e2ba0b6b1f86b79b3161e2ba1e6a986d615b048af4
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# unzip /root/mne_data/MNE-epflp300-data/groups/m/mm/mmspg/www/BCI/p300/subject8.zip
#    session Number  1  completed.......
#    session Number  2  completed.......
#    session Number  3  completed.......
# <ipython-input-23-0b6f0d932841>:5: RuntimeWarning: Resampling of the stim channels caused event information to become unreliable. Consider finding events on the original data and passing the event matrix as a parameter.
#   return data.resample(math.ceil(((sf*32)/seglen)))
# <ipython-input-23-0b6f0d932841>:5: RuntimeWarning: Resampling of the stim channels caused event information to become unreliable. Consider finding events on the original data and passing the event matrix as a parameter.
#   return data.resample(math.ceil(((sf*32)/seglen)))
# 8 accuracy score  0.8076923076923077
# [[ 56  79]
#  [ 76 595]]
# ______________________________________________

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
def BLDA(subjectNumber):
  print("preparing Subject ",subjectNumber , " Data.......")
  x_train,y_train, x_test ,y_test=prepareSubjectDataForSVM(subjectNumber)
  clf = LinearDiscriminantAnalysis()
  clf.fit(x_train,y_train)
  preditions =clf.predict(x_test)
  print(subjectNumber , "accuracy score " , accuracy_score(preditions , y_test))
  
 
  cm = confusion_matrix(y_test,preditions,labels=[2,1])
  print(cm)
  print("______________________________________________")

# %%
BLDA(1)
# Out:
# preparing Subject  1  Data.......
#    session Number  1  completed.......
#    session Number  2  completed.......
#    session Number  3  completed.......
# 1 accuracy score  0.7829268292682927
# [[ 43  92]
#  [ 86 599]]
# ______________________________________________

# %%
BLDA(7)
# Out:
#    session Number  1  completed.......
#    session Number  2  completed.......
#    session Number  3  completed.......
# 7 accuracy score  0.8319719953325554
# [[ 70  73]
#  [ 71 643]]
# ______________________________________________

# %%
BLDA(4)
# Out:
# Downloading data from 'http://documents.epfl.ch/groups/m/mm/mmspg/www/BCI/p300/subject4.zip' to file '/root/mne_data/MNE-epflp300-data/groups/m/mm/mmspg/www/BCI/p300/subject4.zip'.
# preparing Subject  4  Data.......
# 100%|████████████████████████████████████████| 280M/280M [00:00<00:00, 117GB/s]
# SHA256 hash of downloaded file: 6c43a64ae0e6286e1d48c9acbdfc47a1b1938ceaede3bb0b9ffe6ba663b4bc5e
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# unzip /root/mne_data/MNE-epflp300-data/groups/m/mm/mmspg/www/BCI/p300/subject4.zip
#    session Number  1  completed.......
#    session Number  2  completed.......
#    session Number  3  completed.......
# 4 accuracy score  0.8149038461538461
# [[ 55  84]
#  [ 70 623]]
# ______________________________________________

# %%
BLDA(8)
# Out:
# Downloading data from 'http://documents.epfl.ch/groups/m/mm/mmspg/www/BCI/p300/subject8.zip' to file '/root/mne_data/MNE-epflp300-data/groups/m/mm/mmspg/www/BCI/p300/subject8.zip'.
# preparing Subject  8  Data.......
# 100%|███████████████████████████████████████| 266M/266M [00:00<00:00, 93.2GB/s]
# SHA256 hash of downloaded file: 020ceea17f16f1c67729a3e2ba0b6b1f86b79b3161e2ba1e6a986d615b048af4
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# unzip /root/mne_data/MNE-epflp300-data/groups/m/mm/mmspg/www/BCI/p300/subject8.zip
#    session Number  1  completed.......
#    session Number  2  completed.......
#    session Number  3  completed.......
# <ipython-input-22-0b6f0d932841>:5: RuntimeWarning: Resampling of the stim channels caused event information to become unreliable. Consider finding events on the original data and passing the event matrix as a parameter.
#   return data.resample(math.ceil(((sf*32)/seglen)))
# <ipython-input-22-0b6f0d932841>:5: RuntimeWarning: Resampling of the stim channels caused event information to become unreliable. Consider finding events on the original data and passing the event matrix as a parameter.
#   return data.resample(math.ceil(((sf*32)/seglen)))
# 8 accuracy score  0.9069478908188585
# [[ 93  42]
#  [ 33 638]]
# ______________________________________________

# %%
events = mne.find_events(data, stim_channel='STI', verbose=True)
# Out:
# 132 events found
# Event IDs: [1 2]

# %%
events
# Out:
# array([[   819,      0,      1],
#        [  1638,      0,      1],
#        [  2459,      0,      1],
#        [  3280,      0,      2],
#        [  4099,      0,      1],
#        [  4921,      0,      1],
#        [  5740,      0,      1],
#        [  6561,      0,      1],
#        [  7382,      0,      1],
#        [  8202,      0,      1],
#        [  9023,      0,      2],
#        [  9842,      0,      1],
#        [ 10663,      0,      2],
#        [ 11482,      0,      1],
#        [ 12304,      0,      1],
#        [ 13125,      0,      1],
#        [ 13942,      0,      1],
#        [ 14765,      0,      1],
#        [ 15585,      0,      1],
#        [ 16406,      0,      1],
#        [ 17225,      0,      1],
#        [ 18046,      0,      2],
#        [ 18868,      0,      1],
#        [ 19687,      0,      1],
#        [ 20508,      0,      1],
#        [ 21327,      0,      1],
#        [ 22148,      0,      2],
#        [ 22968,      0,      1],
#        [ 23789,      0,      1],
#        [ 24610,      0,      1],
#        [ 25429,      0,      1],
#        [ 26251,      0,      1],
#        [ 27070,      0,      1],
#        [ 27891,      0,      2],
#        [ 28710,      0,      1],
#        [ 29531,      0,      1],
#        [ 30353,      0,      1],
#        [ 31172,      0,      2],
#        [ 31993,      0,      1],
#        [ 32812,      0,      1],
#        [ 33634,      0,      1],
#        [ 34455,      0,      1],
#        [ 35335,      0,      1],
#        [ 36095,      0,      1],
#        [ 36915,      0,      1],
#        [ 37736,      0,      2],
#        [ 38555,      0,      1],
#        [ 39376,      0,      1],
#        [ 40197,      0,      1],
#        [ 41017,      0,      2],
#        [ 41838,      0,      1],
#        [ 42657,      0,      1],
#        [ 43478,      0,      1],
#        [ 44298,      0,      1],
#        [ 45119,      0,      1],
#        [ 45940,      0,      1],
#        [ 46759,      0,      2],
#        [ 47580,      0,      1],
#        [ 48400,      0,      1],
#        [ 49221,      0,      1],
#        [ 50040,      0,      1],
#        [ 50861,      0,      1],
#        [ 51683,      0,      1],
#        [ 52502,      0,      1],
#        [ 53323,      0,      2],
#        [ 54142,      0,      1],
#        [ 54964,      0,      1],
#        [ 55783,      0,      1],
#        [ 56604,      0,      2],
#        [ 57425,      0,      1],
#        [ 58244,      0,      1],
#        [ 59066,      0,      1],
#        [ 59885,      0,      1],
#        [ 60727,      0,      1],
#        [ 61548,      0,      1],
#        [ 62367,      0,      2],
#        [ 63188,      0,      1],
#        [ 64007,      0,      1],
#        [ 64829,      0,      1],
#        [ 65648,      0,      2],
#        [ 66469,      0,      1],
#        [ 67290,      0,      1],
#        [ 68110,      0,      1],
#        [ 68931,      0,      1],
#        [ 69750,      0,      1],
#        [ 70571,      0,      1],
#        [ 71391,      0,      1],
#        [ 72212,      0,      1],
#        [ 73033,      0,      2],
#        [ 73852,      0,      1],
#        [ 74673,      0,      2],
#        [ 75493,      0,      1],
#        [ 76314,      0,      1],
#        [ 77133,      0,      1],
#        [ 77954,      0,      1],
#        [ 78817,      0,      1],
#        [ 79595,      0,      1],
#        [ 80416,      0,      1],
#        [ 81235,      0,      2],
#        [ 82057,      0,      1],
#        [ 82960,      0,      1],
#        [ 83697,      0,      1],
#        [ 84518,      0,      2],
#        [ 85337,      0,      1],
#        [ 86159,      0,      1],
#        [ 86978,      0,      1],
#        [ 87799,      0,      1],
#        [ 88620,      0,      1],
#        [ 89440,      0,      2],
#        [ 90261,      0,      1],
#        [ 91080,      0,      1],
#        [ 91901,      0,      1],
#        [ 92720,      0,      1],
#        [ 93542,      0,      1],
#        [ 94363,      0,      1],
#        [ 95182,      0,      1],
#        [ 96003,      0,      1],
#        [ 96823,      0,      1],
#        [ 97644,      0,      2],
#        [ 98463,      0,      1],
#        [ 99284,      0,      1],
#        [100106,      0,      2],
#        [100925,      0,      1],
#        [101787,      0,      1],
#        [102565,      0,      1],
#        [103386,      0,      1],
#        [104206,      0,      1],
#        [105027,      0,      1],
#        [105910,      0,      1],
#        [106667,      0,      1],
#        [107489,      0,      1],
#        [108308,      0,      2]])

# %%
data.plot(events, n_channels=1)
# Out:
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEBrowseFigure size 576x576 with 4 Axes>
