# %% [markdown]
# # **Import Librairies**

# %%
# !!pip install -q MOABB

# %%
# !pip install pywd

# %%
import datetime as dt
import glob
import os
import zipfile

# %%
import numpy as np
import pandas as pd


import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
import scipy.signal
import scipy.io as sio
from scipy.io import loadmat
from scipy.signal import butter, filtfilt
import math


from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import StratifiedKFold
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn import svm
from keras.models import load_model
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score
from sklearn.metrics import confusion_matrix
from sklearn.utils.class_weight import compute_class_weight, compute_sample_weight
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc, confusion_matrix

# %%
import mne
from mne.channels import make_standard_montage
from mne.filter import construct_iir_filter

import moabb
from pywt import wavedec
from moabb.datasets import EPFLP300, utils
from moabb.evaluations import CrossSessionEvaluation
from moabb.paradigms import LeftRightImagery
from moabb.pipelines.features import LogVariance
from moabb.datasets import download as dl
from moabb.datasets.base import BaseDataset

moabb.set_log_level("info")
# Out:
# Tensorflow not install, you could not use those pipelines
# To use the get_shape_from_baseconcar, InputShapeSetterEEG, BraindecodeDatasetLoaderyou need to install `braindecode`.`pip install braindecode` or Please refer to `https://braindecode.org`.

# %%
import keras
import tensorflow as tf
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import classification_report
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, Flatten, Concatenate
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Dropout, GRU, Dense, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import Dense

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Starting clean**

# %%
class Normalize:
    def __init__(self):
        self.min = []    # minimal amplitude for all EEG channels
        self.max = []    # maximal amplitude for all EEG channels
        self.mean = []   # mean amplitude for all EEG channels
        self.std = []    # standard deviation for all EEG channels
        self.method = '' # normalization method "minmax" or "z-score"

    def apply(self,n, x):
        # normalization procedure for EEG data
        # uses minima and maxima or means and standard deviations stored in
        # the object n

        n_channels, n_samples, n_trials = x.shape
        x = x.reshape(n_channels, n_samples * n_trials)

        if n.method == 'minmax':
            x = x - np.tile(n.min, (n_samples * n_trials, 1)).T
            x = x / np.tile(n.max - n.min, (n_samples * n_trials, 1)).T
            x = 2 * x - np.ones((n_channels, n_samples * n_trials))

        elif n.method == 'z-score':
            x = x - np.tile(n.mean, (n_samples * n_trials, 1)).T
            x = x / np.tile(n.std, (n_samples * n_trials, 1)).T

        else:
            print('unknown normalization method')

        x = x.reshape(n_channels, n_samples, n_trials)
        return x
    def train(self,n, x, method):
        """
        training procedure for normalize
        computes minima and maxima, or means and standard deviations for
        normalization of EEG channels

        INPUT:
            n       - object of type normalize
            x       - m*n*t matrix containing t EEG trials with m channels and
                      n samples
            method  - either 'minmax' or 'z-score'

        OUTPUT:
            n       - updated object of type normalize
        """
        n_channels = x.shape[0]
        n_samples = x.shape[1]
        n_trials = x.shape[2]
        x = x.reshape(n_channels, n_samples * n_trials)

        if method == 'minmax':
            n.min = np.min(x, axis=1)
            n.max = np.max(x, axis=1)
            n.method = 'minmax'
        elif method == 'z-score':
            n.mean = np.mean(x, axis=1)
            n.std = np.std(x, axis=1)
            n.method = 'z-score'
        else:
            print('unknown normalization method')

        return n

# %%
class windsor:
    def __init__(self):
        # constructor for class windsor
        # windsor can be used to "windsorize" EEG data

        # METHODS:
        #       train - computes percentiles of EEG channels
        #       apply - clips samples with amplitudes smaller or bigger than
        #               previously computed percentiles

        # Author: Ulrich Hoffmann - EPFL, 2006

        self.limit_l = []  # (lower) percentiles for each EEG channel
        self.limit_h = []  # (upper) percentiles for each EEG channel

    def apply(self, w, x):
        # windsorizes the data in x
        # this means that values that are smaller or bigger than the percentile
        # values in w.limit_l and w.limit_h are clipped

        # INPUT:
        #    w       - object of type windsor
        #    x       - m*n*t matrix containing t EEG trials with m channels and
        #              n samples

        # OUTPUT:
        #    x       - x windsorized

        # Author: Ulrich Hoffmann - EPFL, 2006

        ## initialize variables
        n_channels = x.shape[0]
        n_samples = x.shape[1]
        n_trials = x.shape[2]

        ## clip the data
        x = x.reshape(n_channels, n_samples * n_trials)
        w.limit_l=np.array(w.limit_l)
        w.limit_h=np.array(w.limit_h)
        l = np.tile(w.limit_l.reshape(-1, 1), (1, n_samples * n_trials))
        h = np.tile(w.limit_h.reshape(-1, 1), (1, n_samples * n_trials))
        i_l = x < l
        i_h = x > h
        x[i_l] = l[i_l]
        x[i_h] = h[i_h]
        x = x.reshape(n_channels, n_samples, n_trials)

        return x

    def train(self, w, x, p):
        # computes percentiles for windsorizing

        # INPUT:
        #    w       - object of type windsor
        #    x       - m*n*t matrix containing t EEG trials with m channels and
        #              n samples
        #    p       - percentage of samples that will be clipped from each channel

        # OUTPUT:
        #    w       - updated object of type windsor

        # Author: Ulrich Hoffmann - EPFL, 2006

        ## initialize variables
        n_channels = x.shape[0]
        n_samples  = x.shape[1]
        n_trials   = x.shape[2]
        n_clip     = round(n_samples*n_trials*p/2)
        x = np.reshape(x, (n_channels, n_samples*n_trials))
        w.limit_l = []
        w.limit_h = []

        ## compute (p/2)th percentiles for each channel
        for i in range(n_channels):
            tmp = np.sort(x[i,:])
            w.limit_l.append(tmp[n_clip])
            w.limit_h.append(tmp[-n_clip+1])

        return w

# %% [markdown]
# # **Preprocess Single Subject Data**

# %%
filename ='/content/drive/MyDrive/MNE/MNE-epflp300-data/groups/m/mm/mmspg/www/BCI/p300/subject9/session1/eeg_200308270304_epochs.mat'

f =scipy.io.loadmat(filename)
f['events'].shape[0]
# Out:
# 126

# %%
n_targets = 0  # keeps track of number of target trials
n_nontargets = 0  # keeps track of nontarget trials

# initialize variables
srate = 2048  # sampling rate of raw data in Hz
reference = [6, 23]  # indices of channels used as reference
filterorder = 3
filtercutoff = [1/1024, 12/1024]
f_b, f_a = scipy.signal.butter(filterorder, filtercutoff ,btype='bandpass')
decimation = 64  # downsampling factor
n_samples = 32  # number of (temporal) samples in a trial
sessions=[]  # main array of sessions for single subject (len = 4)

indir='/content/drive/MyDrive/MNE/MNE-epflp300-data/groups/m/mm/mmspg/www/BCI/p300/subject9'

for session in os.listdir(indir):
  runs = [None] * 6
  i=0
  sessiondir=os.path.join(indir, session)
  for filename in os.listdir(sessiondir):
      if not os.path.isdir(os.path.join(sessiondir, filename)):
          filename = os.path.join(sessiondir, filename)
          f =scipy.io.loadmat(filename)

          signals = f["data"]
          stimuli = f["stimuli"].squeeze()
          events = f["events"]
          target = f["target"][0][0]

          # 1. The last X entries are 0 for all signals. This leads to
          # artifacts when epoching and band-pass filtering the data.
          # We correct the signals for this.
          sig_i = np.where(np.diff(np.all(signals == 0, axis=0).astype(int)) != 0)[0][0]
          signals = signals[:, :sig_i]

          # 2. Rereference the data
          n_channels = f['data'].shape[0]
          ref = np.tile(np.mean(f['data'][reference, :], axis=0), (n_channels, 1))
          f['data'] = f['data'] - ref

          # 3. drop the mastoid channels
          f['data'] = f['data'][[1, 2, 3, 5, 6, 10, 14, 16, 19, 23, 24, 26, 27, 28], :]
          n_channels = f['data'].shape[0]

          # 4. Bandpass filter the data (with a forward-backward filter)
          for j in range(n_channels):
              f['data'][j, :] = filtfilt(f_b, f_a, f['data'][j, :])

          # 5. Downsample the data (from 2048 Hz to 64 Hz)
          f['data'] = f['data'][:, 0::decimation]

          n_trials = f['events'].shape[0]
          runs[i]={'x': np.zeros((n_channels, n_samples, n_trials)),
                        'y': np.zeros(n_trials),
                        'stimuli': stimuli,
                        'target': target}

          # getting the event time in a Python standardized way
          events_datetime = []
          for eventi in events:
              events_datetime.append(dt.datetime(*eventi.astype(int), int(eventi[-1] * 1e3) % 1000 * 1000))

          # Get the indices of the stimuli
          pos = []
          n_trials = len(stimuli)
          for j in range(n_trials):
              delta_seconds = (events_datetime[j] - events_datetime[0]).total_seconds()
              delta_indices = int(delta_seconds * srate/decimation)
              # has to add an offset
              pos.append(delta_indices + int(0.4 * srate/decimation))

          # 6. Extract trials (segmentation)
          # put everything in the cell-array runs
          # compute class labels
          for j in range(n_trials):
              runs[i]['x'][:, :, j] = f['data'][:, pos[j]:pos[j]+n_samples]
          runs[i]['y'][stimuli == target] = 1
          runs[i]['y'][stimuli != target] = -1

          # 7. Windsorizing
          xt=runs[i]['x']
          w = windsor()
          w= w.train(w,xt,0.1)
          x = w.apply(w,xt)

          # 8. Normalization using Z-score
          n= Normalize()
          n= n.train(n,x,'z-score')
          x= n.apply(n,x)
          runs[i]['x']=x

          # update counters
          n_targets += np.sum(runs[i]['y'] == 1)
          n_nontargets += np.sum(runs[i]['y'] == -1)
      i=i+1
  sessions.append(runs)

print(f'total target trials: {n_targets}')
print(f'total nontarget trials: {n_nontargets}')
# Out:
# total target trials: 551
# total nontarget trials: 2755

# %%
sessions[0][0]['x']
# Out:
# (14, 32, 126)

# %% [markdown]
# ### **Prepare data to be 2D array (n_channels, n_samples) (32,32) array and outputs to be 0 and 1**

# %%
def Preprocess_KF(sessions):
  X=[]
  Y=[]

  for session in range(4):
    for run in range(6):
      n_trials=sessions[session][run]['x'].shape[2]
      for trial in range(n_trials):
        X.append(sessions[session][run]['x'][:,:,trial])
        if(sessions[session][run]['y'][trial]==1):
          Y.append(1)
        else:
          Y.append(0)

  return X,Y

# %%
X, Y = Preprocess_KF(sessions)

# %%
x = np.array(X).astype(np.float64)
y = np.array(Y).astype(int)

# %%
np.save('/content/drive/MyDrive/Emotiv/Sub 9/X.npy', x)
np.save('/content/drive/MyDrive/Emotiv/Sub 9/Y.npy', y)

# %% [markdown]
# ### **Split Dataset**

# %%
def Preprocess(sessions):
  x_train=[]
  y_train=[]

  for session in range(3):
    for run in range(6):
      n_trials=sessions[session][run]['x'].shape[2]
      for trial in range(n_trials):
        x_train.append(sessions[session][run]['x'][:,:,trial])
        if(sessions[session][run]['y'][trial]==1):
          y_train.append(1)
        else:
           y_train.append(0)

  x_test =[]
  y_test =[]
  for run in range(6):
      n_trials=sessions[3][run]['x'].shape[2]
      for trial in range(n_trials):
        x_test.append(sessions[3][run]['x'][:,:,trial])
        if(sessions[3][run]['y'][trial]==1):
          y_test.append(1)
        else:
          y_test.append(0)
  return x_train,y_train, x_test ,y_test

# %%
x_train,y_train, x_test ,y_test=Preprocess(sessions)

# %%
x_train = np.array(x_train).astype(np.float64)
y_train = np.array(y_train).astype(int)

x_test = np.array(x_test).astype(np.float64)
y_test = np.array(y_test).astype(int)

# %%
np.save('/content/drive/MyDrive/Pre-processed Dataset/Sub 8/x_train.npy', x_train)
np.save('/content/drive/MyDrive/Pre-processed Dataset/Sub 8/y_train.npy', y_train)
np.save('/content/drive/MyDrive/Pre-processed Dataset/Sub 8/x_test.npy', x_test)
np.save('/content/drive/MyDrive/Pre-processed Dataset/Sub 8/y_test.npy', y_test)

# %% [markdown]
# ### **Classification Metric**

# %%
def metric(x, y, model):
  Y_pred = model.predict(x)
  Y_pred_classes = Y_pred.round()
  # Accuracy
  acc = accuracy_score(y, Y_pred_classes)
  # Precision
  prec = precision_score(y, Y_pred_classes)
  # Recall
  rec = recall_score(y, Y_pred_classes)
  # F1 score
  f1 = f1_score(y, Y_pred_classes)
  # ROC curve
  fpr, tpr, thresholds = roc_curve(y, Y_pred_classes)
  roc_auc = auc(fpr, tpr)
  # Confusion matrix
  cm = confusion_matrix(y, Y_pred_classes)

  print(f"Accuracy: {acc}\nPrecision: {rec}\nF1-score: {f1}\nROC-curve: {roc_auc}\nConfusion matrix:")

  f,ax = plt.subplots(figsize=(8, 8))
  sns.heatmap(cm, annot=True, linewidths=0.01,cmap="viridis",linecolor="gray", fmt= '.1f',ax=ax)
  plt.xlabel("Predicted Label")
  plt.ylabel("True Label")
  plt.title("Confusion Matrix")
  plt.show()

# %%
def plot_confusion_matrix(x,y,model):
  Y_pred = model.predict(x)
  Y_pred_classes = Y_pred.round()
  confusion_mtx = confusion_matrix(y, Y_pred_classes)
  f,ax = plt.subplots(figsize=(8, 8))
  sns.heatmap(confusion_mtx, annot=True, linewidths=0.01,cmap="Greens",linecolor="gray", fmt= '.1f',ax=ax)
  plt.xlabel("Predicted Label")
  plt.ylabel("True Label")
  plt.title("Confusion Matrix")
  plt.show()

# %% [markdown]
# ### **K-Fold Validation & Class-Weights**

# %%
def K_Fold_Val(model_name, model, X, y, epochs, batch_size, K=5):

  k = K  # number of folds

  # assume X and y are your EEG data and labels, respectively
  skf = StratifiedKFold(n_splits=k)

  # initialize lists to store results
  acc_scores = []
  loss_scores = []

  for fold, (train_idx, test_idx) in enumerate(skf.split(X, y)):
      # split data into training and testing sets
      X_train, X_test = X[train_idx], X[test_idx]
      y_train, y_test = y[train_idx], y[test_idx]

      # calculate class weights
      class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(y_train), y=y_train)
      class_weights = dict(enumerate(class_weights))

      model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

      # define checkpoint callback
      checkpoint = ModelCheckpoint(f"{model_name}_checkpoint_{fold}.h5", monitor='val_loss', save_best_only=True, verbose=1)

      # train model with checkpoint callback
      model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, class_weight=class_weights, validation_data=(X_test, y_test), callbacks=[checkpoint])

      # evaluate model on testing set
      loss, acc = model.evaluate(X_test, y_test)
      loss_scores.append(loss)
      acc_scores.append(acc)

  # print average scores across all folds
  print("Average loss:", np.mean(loss_scores))
  print("Average accuracy:", np.mean(acc_scores))

# %% [markdown]
# # **EEGNET**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.constraints import max_norm

def EEGNet(nb_classes, Chans=32, Samples=32):
    # Define the input shape
    input_shape = (Chans, Samples, 1)

    # Define the model architecture
    input_layer = layers.Input(shape=input_shape)

    block1 = layers.Conv2D(16, (1, 32), padding='same', input_shape=input_shape)(input_layer)
    block1 = layers.BatchNormalization()(block1)
    block1 = layers.DepthwiseConv2D((Chans, 1), use_bias=False, depth_multiplier=2, depthwise_constraint=max_norm(1.))(block1)
    block1 = layers.BatchNormalization()(block1)
    block1 = layers.Activation('elu')(block1)
    block1 = layers.SeparableConv2D(32, (1, 4), use_bias=False, padding='same')(block1)
    block1 = layers.BatchNormalization()(block1)
    block1 = layers.Activation('elu')(block1)
    block1 = layers.MaxPooling2D((1, 4))(block1)
    block1 = layers.Dropout(0.25)(block1)

    block2 = layers.DepthwiseConv2D((1, 4), use_bias=False, depth_multiplier=2, depthwise_constraint=max_norm(1.))(block1)
    block2 = layers.BatchNormalization()(block2)
    block2 = layers.Activation('elu')(block2)
    block2 = layers.SeparableConv2D(64, (1, 4), use_bias=False, padding='same')(block2)
    block2 = layers.BatchNormalization()(block2)
    block2 = layers.Activation('elu')(block2)
    block2 = layers.MaxPooling2D((1, 2))(block2)
    block2 = layers.Dropout(0.25)(block2)

    flatten = layers.Flatten()(block2)

    dense = layers.Dense(256, activation='elu')(flatten)
    dense = layers.Dropout(0.5)(dense)

    output_layer = layers.Dense(1, activation='sigmoid')(dense)

    # Compile the model
    model = models.Model(inputs=input_layer, outputs=output_layer)

    return model

# %%
eegmodel = None
eegmodel = EEGNet(nb_classes=2)
K_Fold_Val("EEGNet", eegmodel, x, y, 25, 16, K=6)
# Out:
# Epoch 1/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.7993 - accuracy: 0.5603
# Epoch 1: val_loss improved from inf to 0.61963, saving model to EEGNet_checkpoint_0.h5
# 175/175 [==============================] - 10s 35ms/step - loss: 0.7983 - accuracy: 0.5598 - val_loss: 0.6196 - val_accuracy: 0.8330
# Epoch 2/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.6717 - accuracy: 0.6644
# Epoch 2: val_loss improved from 0.61963 to 0.55517, saving model to EEGNet_checkpoint_0.h5
# 175/175 [==============================] - 5s 28ms/step - loss: 0.6726 - accuracy: 0.6643 - val_loss: 0.5552 - val_accuracy: 0.7612
# Epoch 3/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.5448 - accuracy: 0.7367
# Epoch 3: val_loss improved from 0.55517 to 0.54024, saving model to EEGNet_checkpoint_0.h5
# 175/175 [==============================] - 8s 45ms/step - loss: 0.5446 - accuracy: 0.7368 - val_loss: 0.5402 - val_accuracy: 0.7289
# Epoch 4/25
# 175/175 [==============================] - ETA: 0s - loss: 0.4762 - accuracy: 0.7921
# Epoch 4: val_loss improved from 0.54024 to 0.49391, saving model to EEGNet_checkpoint_0.h5
# 175/175 [==============================] - 6s 35ms/step - loss: 0.4762 - accuracy: 0.7921 - val_loss: 0.4939 - val_accuracy: 0.7702
# Epoch 5/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.4411 - accuracy: 0.8014
# Epoch 5: val_loss improved from 0.49391 to 0.40132, saving model to EEGNet_checkpoint_0.h5
# 175/175 [==============================] - 5s 28ms/step - loss: 0.4417 - accuracy: 0.8011 - val_loss: 0.4013 - val_accuracy: 0.8223
# Epoch 6/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.4284 - accuracy: 0.7942
# Epoch 6: val_loss did not improve from 0.40132
# 175/175 [==============================] - 7s 39ms/step - loss: 0.4282 - accuracy: 0.7943 - val_loss: 0.4036 - val_accuracy: 0.8061
# Epoch 7/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.3902 - accuracy: 0.8280
# Epoch 7: val_loss improved from 0.40132 to 0.39336, saving model to EEGNet_checkpoint_0.h5
# 175/175 [==============================] - 5s 28ms/step - loss: 0.3899 - accuracy: 0.8284 - val_loss: 0.3934 - val_accuracy: 0.8330
# Epoch 8/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.3600 - accuracy: 0.8324
# Epoch 8: val_loss did not improve from 0.39336
# 175/175 [==============================] - 5s 30ms/step - loss: 0.3608 - accuracy: 0.8312 - val_loss: 0.4520 - val_accuracy: 0.7917
# Epoch 9/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.3241 - accuracy: 0.8620
# Epoch 9: val_loss improved from 0.39336 to 0.37356, saving model to EEGNet_checkpoint_0.h5
# 175/175 [==============================] - 7s 38ms/step - loss: 0.3236 - accuracy: 0.8625 - val_loss: 0.3736 - val_accuracy: 0.8492
# Epoch 10/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.2948 - accuracy: 0.8732
# Epoch 10: val_loss did not improve from 0.37356
# 175/175 [==============================] - 5s 28ms/step - loss: 0.2951 - accuracy: 0.8729 - val_loss: 0.3898 - val_accuracy: 0.8366
# Epoch 11/25
# 175/175 [==============================] - ETA: 0s - loss: 0.2740 - accuracy: 0.8847
# Epoch 11: val_loss improved from 0.37356 to 0.34062, saving model to EEGNet_checkpoint_0.h5
# 175/175 [==============================] - 8s 47ms/step - loss: 0.2740 - accuracy: 0.8847 - val_loss: 0.3406 - val_accuracy: 0.8636
# Epoch 12/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.2937 - accuracy: 0.8779
# Epoch 12: val_loss did not improve from 0.34062
# 175/175 [==============================] - 6s 33ms/step - loss: 0.2936 - accuracy: 0.8779 - val_loss: 0.3700 - val_accuracy: 0.8546
# Epoch 13/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.2746 - accuracy: 0.8811
# Epoch 13: val_loss improved from 0.34062 to 0.31642, saving model to EEGNet_checkpoint_0.h5
# 175/175 [==============================] - 6s 35ms/step - loss: 0.2745 - accuracy: 0.8811 - val_loss: 0.3164 - val_accuracy: 0.8636
# Epoch 14/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.2314 - accuracy: 0.9045
# Epoch 14: val_loss did not improve from 0.31642
# 175/175 [==============================] - 9s 49ms/step - loss: 0.2315 - accuracy: 0.9041 - val_loss: 0.3760 - val_accuracy: 0.8636
# Epoch 15/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.2171 - accuracy: 0.9192
# Epoch 15: val_loss did not improve from 0.31642
# 175/175 [==============================] - 5s 28ms/step - loss: 0.2171 - accuracy: 0.9192 - val_loss: 0.3691 - val_accuracy: 0.8510
# Epoch 16/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.2099 - accuracy: 0.9080
# Epoch 16: val_loss did not improve from 0.31642
# 175/175 [==============================] - 6s 35ms/step - loss: 0.2099 - accuracy: 0.9081 - val_loss: 0.4346 - val_accuracy: 0.8546
# Epoch 17/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.2209 - accuracy: 0.9032
# Epoch 17: val_loss did not improve from 0.31642
# 175/175 [==============================] - 6s 32ms/step - loss: 0.2215 - accuracy: 0.9031 - val_loss: 0.3775 - val_accuracy: 0.8618
# Epoch 18/25
# 175/175 [==============================] - ETA: 0s - loss: 0.2750 - accuracy: 0.8732
# Epoch 18: val_loss did not improve from 0.31642
# 175/175 [==============================] - 7s 42ms/step - loss: 0.2750 - accuracy: 0.8732 - val_loss: 0.4297 - val_accuracy: 0.8492
# Epoch 19/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.2103 - accuracy: 0.9072
# Epoch 19: val_loss did not improve from 0.31642
# 175/175 [==============================] - 7s 37ms/step - loss: 0.2124 - accuracy: 0.9074 - val_loss: 0.4181 - val_accuracy: 0.8474
# Epoch 20/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.2854 - accuracy: 0.8707
# Epoch 20: val_loss did not improve from 0.31642
# 175/175 [==============================] - 5s 28ms/step - loss: 0.2853 - accuracy: 0.8707 - val_loss: 0.3878 - val_accuracy: 0.8510
# Epoch 21/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.2314 - accuracy: 0.9027
# Epoch 21: val_loss did not improve from 0.31642
# 175/175 [==============================] - 6s 34ms/step - loss: 0.2313 - accuracy: 0.9027 - val_loss: 0.3745 - val_accuracy: 0.8456
# Epoch 22/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.1777 - accuracy: 0.9228
# Epoch 22: val_loss did not improve from 0.31642
# 175/175 [==============================] - 6s 33ms/step - loss: 0.1776 - accuracy: 0.9228 - val_loss: 0.3892 - val_accuracy: 0.8528
# Epoch 23/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.1674 - accuracy: 0.9274
# Epoch 23: val_loss did not improve from 0.31642
# 175/175 [==============================] - 5s 27ms/step - loss: 0.1676 - accuracy: 0.9271 - val_loss: 0.3764 - val_accuracy: 0.8797
# Epoch 24/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.1570 - accuracy: 0.9332
# Epoch 24: val_loss did not improve from 0.31642
# 175/175 [==============================] - 7s 42ms/step - loss: 0.1569 - accuracy: 0.9332 - val_loss: 0.4800 - val_accuracy: 0.8330
# Epoch 25/25
# 175/175 [==============================] - ETA: 0s - loss: 0.1532 - accuracy: 0.9350
# Epoch 25: val_loss did not improve from 0.31642
# 175/175 [==============================] - 8s 48ms/step - loss: 0.1532 - accuracy: 0.9350 - val_loss: 0.4203 - val_accuracy: 0.8689
# 18/18 [==============================] - 0s 25ms/step - loss: 0.4203 - accuracy: 0.8689
# Epoch 1/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.2640 - accuracy: 0.9027
# Epoch 1: val_loss improved from inf to 0.12203, saving model to EEGNet_checkpoint_1.h5
# 175/175 [==============================] - 8s 30ms/step - loss: 0.2640 - accuracy: 0.9027 - val_loss: 0.1220 - val_accuracy: 0.9551
# Epoch 2/25
# 175/175 [==============================] - ETA: 0s - loss: 0.2149 - accuracy: 0.9127
# Epoch 2: val_loss did not improve from 0.12203
# 175/175 [==============================] - 5s 31ms/step - loss: 0.2149 - accuracy: 0.9127 - val_loss: 0.1553 - val_accuracy: 0.9318
# Epoch 3/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.1938 - accuracy: 0.9198
# Epoch 3: val_loss did not improve from 0.12203
# 175/175 [==============================] - 6s 36ms/step - loss: 0.1950 - accuracy: 0.9185 - val_loss: 0.1971 - val_accuracy: 0.9156
# Epoch 4/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.2577 - accuracy: 0.8815
# Epoch 4: val_loss did not improve from 0.12203
# 175/175 [==============================] - 5s 28ms/step - loss: 0.2580 - accuracy: 0.8811 - val_loss: 0.1412 - val_accuracy: 0.9533
# Epoch 5/25
# 175/175 [==============================] - ETA: 0s - loss: 0.1749 - accuracy: 0.9246
# Epoch 5: val_loss improved from 0.12203 to 0.11499, saving model to EEGNet_checkpoint_1.h5
# 175/175 [==============================] - 6s 37ms/step - loss: 0.1749 - accuracy: 0.9246 - val_loss: 0.1150 - val_accuracy: 0.9461
# Epoch 6/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.1649 - accuracy: 0.9361
# Epoch 6: val_loss did not improve from 0.11499
# 175/175 [==============================] - 5s 30ms/step - loss: 0.1657 - accuracy: 0.9357 - val_loss: 0.1414 - val_accuracy: 0.9318
# Epoch 7/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.1850 - accuracy: 0.9131
# Epoch 7: val_loss did not improve from 0.11499
# 175/175 [==============================] - 5s 28ms/step - loss: 0.1849 - accuracy: 0.9131 - val_loss: 0.1692 - val_accuracy: 0.9246
# Epoch 8/25
# 175/175 [==============================] - ETA: 0s - loss: 0.1331 - accuracy: 0.9422
# Epoch 8: val_loss did not improve from 0.11499
# 175/175 [==============================] - 9s 49ms/step - loss: 0.1331 - accuracy: 0.9422 - val_loss: 0.1419 - val_accuracy: 0.9443
# Epoch 9/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.1414 - accuracy: 0.9415
# Epoch 9: val_loss did not improve from 0.11499
# 175/175 [==============================] - 6s 33ms/step - loss: 0.1413 - accuracy: 0.9415 - val_loss: 0.1780 - val_accuracy: 0.9264
# Epoch 10/25
# 175/175 [==============================] - ETA: 0s - loss: 0.1270 - accuracy: 0.9490
# Epoch 10: val_loss did not improve from 0.11499
# 175/175 [==============================] - 5s 28ms/step - loss: 0.1270 - accuracy: 0.9490 - val_loss: 0.2143 - val_accuracy: 0.9138
# Epoch 11/25
# 175/175 [==============================] - ETA: 0s - loss: 0.1287 - accuracy: 0.9461
# Epoch 11: val_loss did not improve from 0.11499
# 175/175 [==============================] - 7s 40ms/step - loss: 0.1287 - accuracy: 0.9461 - val_loss: 0.1960 - val_accuracy: 0.9120
# Epoch 12/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.1283 - accuracy: 0.9422
# Epoch 12: val_loss did not improve from 0.11499
# 175/175 [==============================] - 5s 28ms/step - loss: 0.1276 - accuracy: 0.9425 - val_loss: 0.1902 - val_accuracy: 0.9300
# Epoch 13/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.1348 - accuracy: 0.9461
# Epoch 13: val_loss did not improve from 0.11499
# 175/175 [==============================] - 5s 28ms/step - loss: 0.1350 - accuracy: 0.9461 - val_loss: 0.2012 - val_accuracy: 0.9192
# Epoch 14/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.1263 - accuracy: 0.9458
# Epoch 14: val_loss did not improve from 0.11499
# 175/175 [==============================] - 7s 40ms/step - loss: 0.1312 - accuracy: 0.9454 - val_loss: 0.2184 - val_accuracy: 0.9156
# Epoch 15/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.1087 - accuracy: 0.9494
# Epoch 15: val_loss did not improve from 0.11499
# 175/175 [==============================] - 6s 33ms/step - loss: 0.1086 - accuracy: 0.9494 - val_loss: 0.1982 - val_accuracy: 0.9282
# Epoch 16/25
# 175/175 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9645
# Epoch 16: val_loss did not improve from 0.11499
# 175/175 [==============================] - 8s 47ms/step - loss: 0.0885 - accuracy: 0.9645 - val_loss: 0.1863 - val_accuracy: 0.9372
# Epoch 17/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.1038 - accuracy: 0.9569
# Epoch 17: val_loss did not improve from 0.11499
# 175/175 [==============================] - 5s 29ms/step - loss: 0.1038 - accuracy: 0.9569 - val_loss: 0.1747 - val_accuracy: 0.9354
# Epoch 18/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.1135 - accuracy: 0.9501
# Epoch 18: val_loss did not improve from 0.11499
# 175/175 [==============================] - 5s 28ms/step - loss: 0.1132 - accuracy: 0.9501 - val_loss: 0.1979 - val_accuracy: 0.9138
# Epoch 19/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.1079 - accuracy: 0.9585
# Epoch 19: val_loss did not improve from 0.11499
# 175/175 [==============================] - 7s 40ms/step - loss: 0.1075 - accuracy: 0.9587 - val_loss: 0.2260 - val_accuracy: 0.9138
# Epoch 20/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.1068 - accuracy: 0.9555
# Epoch 20: val_loss did not improve from 0.11499
# 175/175 [==============================] - 5s 28ms/step - loss: 0.1068 - accuracy: 0.9555 - val_loss: 0.2350 - val_accuracy: 0.9048
# Epoch 21/25
# 175/175 [==============================] - ETA: 0s - loss: 0.0729 - accuracy: 0.9709
# Epoch 21: val_loss did not improve from 0.11499
# 175/175 [==============================] - 5s 31ms/step - loss: 0.0729 - accuracy: 0.9709 - val_loss: 0.1997 - val_accuracy: 0.9156
# Epoch 22/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0979 - accuracy: 0.9653
# Epoch 22: val_loss did not improve from 0.11499
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0979 - accuracy: 0.9648 - val_loss: 0.2183 - val_accuracy: 0.9210
# Epoch 23/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0940 - accuracy: 0.9594
# Epoch 23: val_loss did not improve from 0.11499
# 175/175 [==============================] - 9s 50ms/step - loss: 0.0940 - accuracy: 0.9594 - val_loss: 0.2384 - val_accuracy: 0.9102
# Epoch 24/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0987 - accuracy: 0.9612
# Epoch 24: val_loss did not improve from 0.11499
# 175/175 [==============================] - 8s 45ms/step - loss: 0.0986 - accuracy: 0.9612 - val_loss: 0.3250 - val_accuracy: 0.9048
# Epoch 25/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0883 - accuracy: 0.9603
# Epoch 25: val_loss did not improve from 0.11499
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0927 - accuracy: 0.9598 - val_loss: 0.1901 - val_accuracy: 0.9246
# 18/18 [==============================] - 0s 15ms/step - loss: 0.1901 - accuracy: 0.9246
# Epoch 1/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.1677 - accuracy: 0.9447
# Epoch 1: val_loss improved from inf to 0.08965, saving model to EEGNet_checkpoint_2.h5
# 175/175 [==============================] - 9s 41ms/step - loss: 0.1676 - accuracy: 0.9447 - val_loss: 0.0897 - val_accuracy: 0.9587
# Epoch 2/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.1002 - accuracy: 0.9588
# Epoch 2: val_loss did not improve from 0.08965
# 175/175 [==============================] - 5s 30ms/step - loss: 0.0997 - accuracy: 0.9591 - val_loss: 0.1063 - val_accuracy: 0.9569
# Epoch 3/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.1184 - accuracy: 0.9509
# Epoch 3: val_loss improved from 0.08965 to 0.08695, saving model to EEGNet_checkpoint_2.h5
# 175/175 [==============================] - 5s 29ms/step - loss: 0.1182 - accuracy: 0.9512 - val_loss: 0.0870 - val_accuracy: 0.9659
# Epoch 4/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.1013 - accuracy: 0.9573
# Epoch 4: val_loss improved from 0.08695 to 0.06508, saving model to EEGNet_checkpoint_2.h5
# 175/175 [==============================] - 8s 48ms/step - loss: 0.1013 - accuracy: 0.9573 - val_loss: 0.0651 - val_accuracy: 0.9785
# Epoch 5/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.1025 - accuracy: 0.9537
# Epoch 5: val_loss did not improve from 0.06508
# 175/175 [==============================] - 6s 33ms/step - loss: 0.1054 - accuracy: 0.9533 - val_loss: 0.1191 - val_accuracy: 0.9461
# Epoch 6/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.2190 - accuracy: 0.9028
# Epoch 6: val_loss did not improve from 0.06508
# 175/175 [==============================] - 5s 29ms/step - loss: 0.2203 - accuracy: 0.9023 - val_loss: 0.1833 - val_accuracy: 0.9228
# Epoch 7/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.1792 - accuracy: 0.9263
# Epoch 7: val_loss did not improve from 0.06508
# 175/175 [==============================] - 7s 40ms/step - loss: 0.1784 - accuracy: 0.9268 - val_loss: 0.1546 - val_accuracy: 0.9372
# Epoch 8/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.1286 - accuracy: 0.9461
# Epoch 8: val_loss did not improve from 0.06508
# 175/175 [==============================] - 5s 28ms/step - loss: 0.1285 - accuracy: 0.9461 - val_loss: 0.1550 - val_accuracy: 0.9372
# Epoch 9/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0984 - accuracy: 0.9551
# Epoch 9: val_loss did not improve from 0.06508
# 175/175 [==============================] - 6s 32ms/step - loss: 0.0983 - accuracy: 0.9551 - val_loss: 0.1524 - val_accuracy: 0.9461
# Epoch 10/25
# 175/175 [==============================] - ETA: 0s - loss: 0.0887 - accuracy: 0.9583
# Epoch 10: val_loss did not improve from 0.06508
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0887 - accuracy: 0.9583 - val_loss: 0.1735 - val_accuracy: 0.9425
# Epoch 11/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0762 - accuracy: 0.9715
# Epoch 11: val_loss did not improve from 0.06508
# 175/175 [==============================] - 5s 28ms/step - loss: 0.0772 - accuracy: 0.9706 - val_loss: 0.1117 - val_accuracy: 0.9551
# Epoch 12/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0860 - accuracy: 0.9616
# Epoch 12: val_loss did not improve from 0.06508
# 175/175 [==============================] - 9s 50ms/step - loss: 0.0859 - accuracy: 0.9616 - val_loss: 0.1361 - val_accuracy: 0.9443
# Epoch 13/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0773 - accuracy: 0.9691
# Epoch 13: val_loss did not improve from 0.06508
# 175/175 [==============================] - 6s 32ms/step - loss: 0.0773 - accuracy: 0.9691 - val_loss: 0.1201 - val_accuracy: 0.9587
# Epoch 14/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0633 - accuracy: 0.9762
# Epoch 14: val_loss did not improve from 0.06508
# 175/175 [==============================] - 5s 28ms/step - loss: 0.0630 - accuracy: 0.9763 - val_loss: 0.1359 - val_accuracy: 0.9479
# Epoch 15/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0794 - accuracy: 0.9723
# Epoch 15: val_loss did not improve from 0.06508
# 175/175 [==============================] - 7s 40ms/step - loss: 0.0794 - accuracy: 0.9724 - val_loss: 0.1256 - val_accuracy: 0.9515
# Epoch 16/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0667 - accuracy: 0.9722
# Epoch 16: val_loss did not improve from 0.06508
# 175/175 [==============================] - 5s 28ms/step - loss: 0.0667 - accuracy: 0.9724 - val_loss: 0.1115 - val_accuracy: 0.9515
# Epoch 17/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0727 - accuracy: 0.9695
# Epoch 17: val_loss did not improve from 0.06508
# 175/175 [==============================] - 5s 30ms/step - loss: 0.0726 - accuracy: 0.9695 - val_loss: 0.0962 - val_accuracy: 0.9551
# Epoch 18/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0831 - accuracy: 0.9678
# Epoch 18: val_loss did not improve from 0.06508
# 175/175 [==============================] - 7s 39ms/step - loss: 0.0828 - accuracy: 0.9677 - val_loss: 0.1122 - val_accuracy: 0.9587
# Epoch 19/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0704 - accuracy: 0.9691
# Epoch 19: val_loss did not improve from 0.06508
# 175/175 [==============================] - 7s 40ms/step - loss: 0.0704 - accuracy: 0.9691 - val_loss: 0.1528 - val_accuracy: 0.9408
# Epoch 20/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0726 - accuracy: 0.9741
# Epoch 20: val_loss did not improve from 0.06508
# 175/175 [==============================] - 9s 50ms/step - loss: 0.0726 - accuracy: 0.9741 - val_loss: 0.1273 - val_accuracy: 0.9443
# Epoch 21/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0619 - accuracy: 0.9741
# Epoch 21: val_loss did not improve from 0.06508
# 175/175 [==============================] - 6s 33ms/step - loss: 0.0618 - accuracy: 0.9741 - val_loss: 0.1241 - val_accuracy: 0.9515
# Epoch 22/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0441 - accuracy: 0.9820
# Epoch 22: val_loss did not improve from 0.06508
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0441 - accuracy: 0.9820 - val_loss: 0.1602 - val_accuracy: 0.9425
# Epoch 23/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0489 - accuracy: 0.9802
# Epoch 23: val_loss did not improve from 0.06508
# 175/175 [==============================] - 7s 40ms/step - loss: 0.0489 - accuracy: 0.9803 - val_loss: 0.1522 - val_accuracy: 0.9354
# Epoch 24/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0662 - accuracy: 0.9756
# Epoch 24: val_loss did not improve from 0.06508
# 175/175 [==============================] - 5s 28ms/step - loss: 0.0661 - accuracy: 0.9756 - val_loss: 0.1416 - val_accuracy: 0.9479
# Epoch 25/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0794 - accuracy: 0.9693
# Epoch 25: val_loss did not improve from 0.06508
# 175/175 [==============================] - 5s 31ms/step - loss: 0.0792 - accuracy: 0.9691 - val_loss: 0.1692 - val_accuracy: 0.9336
# 18/18 [==============================] - 0s 24ms/step - loss: 0.1692 - accuracy: 0.9336
# Epoch 1/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.1279 - accuracy: 0.9511
# Epoch 1: val_loss improved from inf to 0.03909, saving model to EEGNet_checkpoint_3.h5
# 175/175 [==============================] - 11s 43ms/step - loss: 0.1278 - accuracy: 0.9512 - val_loss: 0.0391 - val_accuracy: 0.9856
# Epoch 2/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0922 - accuracy: 0.9630
# Epoch 2: val_loss improved from 0.03909 to 0.03321, saving model to EEGNet_checkpoint_3.h5
# 175/175 [==============================] - 7s 40ms/step - loss: 0.0921 - accuracy: 0.9630 - val_loss: 0.0332 - val_accuracy: 0.9874
# Epoch 3/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0810 - accuracy: 0.9652
# Epoch 3: val_loss did not improve from 0.03321
# 175/175 [==============================] - 5s 30ms/step - loss: 0.0809 - accuracy: 0.9652 - val_loss: 0.0509 - val_accuracy: 0.9767
# Epoch 4/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0970 - accuracy: 0.9616
# Epoch 4: val_loss did not improve from 0.03321
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0972 - accuracy: 0.9612 - val_loss: 0.0437 - val_accuracy: 0.9803
# Epoch 5/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0935 - accuracy: 0.9619
# Epoch 5: val_loss did not improve from 0.03321
# 175/175 [==============================] - 7s 40ms/step - loss: 0.0935 - accuracy: 0.9619 - val_loss: 0.0541 - val_accuracy: 0.9767
# Epoch 6/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0800 - accuracy: 0.9680
# Epoch 6: val_loss did not improve from 0.03321
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0801 - accuracy: 0.9680 - val_loss: 0.0484 - val_accuracy: 0.9803
# Epoch 7/25
# 175/175 [==============================] - ETA: 0s - loss: 0.0916 - accuracy: 0.9616
# Epoch 7: val_loss did not improve from 0.03321
# 175/175 [==============================] - 6s 34ms/step - loss: 0.0916 - accuracy: 0.9616 - val_loss: 0.0581 - val_accuracy: 0.9820
# Epoch 8/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0731 - accuracy: 0.9705
# Epoch 8: val_loss did not improve from 0.03321
# 175/175 [==============================] - 7s 42ms/step - loss: 0.0730 - accuracy: 0.9706 - val_loss: 0.0590 - val_accuracy: 0.9749
# Epoch 9/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0907 - accuracy: 0.9591
# Epoch 9: val_loss did not improve from 0.03321
# 175/175 [==============================] - 6s 35ms/step - loss: 0.0907 - accuracy: 0.9591 - val_loss: 0.0579 - val_accuracy: 0.9767
# Epoch 10/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0798 - accuracy: 0.9648
# Epoch 10: val_loss did not improve from 0.03321
# 175/175 [==============================] - 7s 40ms/step - loss: 0.0798 - accuracy: 0.9648 - val_loss: 0.0599 - val_accuracy: 0.9695
# Epoch 11/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0705 - accuracy: 0.9686
# Epoch 11: val_loss did not improve from 0.03321
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0711 - accuracy: 0.9684 - val_loss: 0.0663 - val_accuracy: 0.9695
# Epoch 12/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0565 - accuracy: 0.9734
# Epoch 12: val_loss did not improve from 0.03321
# 175/175 [==============================] - 6s 35ms/step - loss: 0.0565 - accuracy: 0.9734 - val_loss: 0.0732 - val_accuracy: 0.9731
# Epoch 13/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0797 - accuracy: 0.9646
# Epoch 13: val_loss did not improve from 0.03321
# 175/175 [==============================] - 6s 34ms/step - loss: 0.0797 - accuracy: 0.9648 - val_loss: 0.0658 - val_accuracy: 0.9695
# Epoch 14/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0741 - accuracy: 0.9718
# Epoch 14: val_loss did not improve from 0.03321
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0743 - accuracy: 0.9716 - val_loss: 0.0731 - val_accuracy: 0.9767
# Epoch 15/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0913 - accuracy: 0.9671
# Epoch 15: val_loss did not improve from 0.03321
# 175/175 [==============================] - 7s 40ms/step - loss: 0.0910 - accuracy: 0.9673 - val_loss: 0.1098 - val_accuracy: 0.9515
# Epoch 16/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0682 - accuracy: 0.9713
# Epoch 16: val_loss did not improve from 0.03321
# 175/175 [==============================] - 7s 39ms/step - loss: 0.0682 - accuracy: 0.9713 - val_loss: 0.0795 - val_accuracy: 0.9659
# Epoch 17/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0760 - accuracy: 0.9734
# Epoch 17: val_loss did not improve from 0.03321
# 175/175 [==============================] - 7s 39ms/step - loss: 0.0760 - accuracy: 0.9734 - val_loss: 0.0764 - val_accuracy: 0.9641
# Epoch 18/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0591 - accuracy: 0.9762
# Epoch 18: val_loss did not improve from 0.03321
# 175/175 [==============================] - 6s 33ms/step - loss: 0.0591 - accuracy: 0.9759 - val_loss: 0.0738 - val_accuracy: 0.9659
# Epoch 19/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0632 - accuracy: 0.9758
# Epoch 19: val_loss did not improve from 0.03321
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0635 - accuracy: 0.9756 - val_loss: 0.1390 - val_accuracy: 0.9461
# Epoch 20/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0667 - accuracy: 0.9772
# Epoch 20: val_loss did not improve from 0.03321
# 175/175 [==============================] - 7s 41ms/step - loss: 0.0663 - accuracy: 0.9774 - val_loss: 0.0858 - val_accuracy: 0.9695
# Epoch 21/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0692 - accuracy: 0.9718
# Epoch 21: val_loss did not improve from 0.03321
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0689 - accuracy: 0.9720 - val_loss: 0.0821 - val_accuracy: 0.9677
# Epoch 22/25
# 175/175 [==============================] - ETA: 0s - loss: 0.0504 - accuracy: 0.9785
# Epoch 22: val_loss did not improve from 0.03321
# 175/175 [==============================] - 6s 32ms/step - loss: 0.0504 - accuracy: 0.9785 - val_loss: 0.1063 - val_accuracy: 0.9569
# Epoch 23/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0600 - accuracy: 0.9743
# Epoch 23: val_loss did not improve from 0.03321
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0602 - accuracy: 0.9741 - val_loss: 0.1407 - val_accuracy: 0.9443
# Epoch 24/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0625 - accuracy: 0.9747
# Epoch 24: val_loss did not improve from 0.03321
# 175/175 [==============================] - 7s 41ms/step - loss: 0.0622 - accuracy: 0.9749 - val_loss: 0.1224 - val_accuracy: 0.9533
# Epoch 25/25
# 175/175 [==============================] - ETA: 0s - loss: 0.0587 - accuracy: 0.9734
# Epoch 25: val_loss did not improve from 0.03321
# 175/175 [==============================] - 8s 48ms/step - loss: 0.0587 - accuracy: 0.9734 - val_loss: 0.0732 - val_accuracy: 0.9695
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0732 - accuracy: 0.9695
# Epoch 1/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0920 - accuracy: 0.9677
# Epoch 1: val_loss improved from inf to 0.02015, saving model to EEGNet_checkpoint_4.h5
# 175/175 [==============================] - 10s 42ms/step - loss: 0.0920 - accuracy: 0.9677 - val_loss: 0.0201 - val_accuracy: 0.9928
# Epoch 2/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0637 - accuracy: 0.9720
# Epoch 2: val_loss did not improve from 0.02015
# 175/175 [==============================] - 5s 30ms/step - loss: 0.0637 - accuracy: 0.9720 - val_loss: 0.0550 - val_accuracy: 0.9767
# Epoch 3/25
# 175/175 [==============================] - ETA: 0s - loss: 0.0711 - accuracy: 0.9670
# Epoch 3: val_loss did not improve from 0.02015
# 175/175 [==============================] - 6s 32ms/step - loss: 0.0711 - accuracy: 0.9670 - val_loss: 0.0415 - val_accuracy: 0.9838
# Epoch 4/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0605 - accuracy: 0.9763
# Epoch 4: val_loss did not improve from 0.02015
# 175/175 [==============================] - 7s 37ms/step - loss: 0.0605 - accuracy: 0.9763 - val_loss: 0.0407 - val_accuracy: 0.9803
# Epoch 5/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0605 - accuracy: 0.9745
# Epoch 5: val_loss did not improve from 0.02015
# 175/175 [==============================] - 6s 33ms/step - loss: 0.0604 - accuracy: 0.9745 - val_loss: 0.0250 - val_accuracy: 0.9874
# Epoch 6/25
# 175/175 [==============================] - ETA: 0s - loss: 0.0761 - accuracy: 0.9670
# Epoch 6: val_loss did not improve from 0.02015
# 175/175 [==============================] - 8s 48ms/step - loss: 0.0761 - accuracy: 0.9670 - val_loss: 0.0220 - val_accuracy: 0.9928
# Epoch 7/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0676 - accuracy: 0.9738
# Epoch 7: val_loss did not improve from 0.02015
# 175/175 [==============================] - 5s 30ms/step - loss: 0.0679 - accuracy: 0.9734 - val_loss: 0.0602 - val_accuracy: 0.9731
# Epoch 8/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.1046 - accuracy: 0.9603
# Epoch 8: val_loss did not improve from 0.02015
# 175/175 [==============================] - 5s 29ms/step - loss: 0.1043 - accuracy: 0.9605 - val_loss: 0.0445 - val_accuracy: 0.9820
# Epoch 9/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0554 - accuracy: 0.9763
# Epoch 9: val_loss did not improve from 0.02015
# 175/175 [==============================] - 7s 40ms/step - loss: 0.0554 - accuracy: 0.9763 - val_loss: 0.0356 - val_accuracy: 0.9856
# Epoch 10/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0745 - accuracy: 0.9758
# Epoch 10: val_loss did not improve from 0.02015
# 175/175 [==============================] - 5s 30ms/step - loss: 0.0745 - accuracy: 0.9756 - val_loss: 0.0460 - val_accuracy: 0.9820
# Epoch 11/25
# 175/175 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.9759
# Epoch 11: val_loss did not improve from 0.02015
# 175/175 [==============================] - 6s 35ms/step - loss: 0.0584 - accuracy: 0.9759 - val_loss: 0.0555 - val_accuracy: 0.9820
# Epoch 12/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0878 - accuracy: 0.9653
# Epoch 12: val_loss did not improve from 0.02015
# 175/175 [==============================] - 6s 35ms/step - loss: 0.0873 - accuracy: 0.9655 - val_loss: 0.0664 - val_accuracy: 0.9785
# Epoch 13/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0766 - accuracy: 0.9678
# Epoch 13: val_loss did not improve from 0.02015
# 175/175 [==============================] - 7s 41ms/step - loss: 0.0824 - accuracy: 0.9677 - val_loss: 0.0597 - val_accuracy: 0.9749
# Epoch 14/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.1586 - accuracy: 0.9285
# Epoch 14: val_loss did not improve from 0.02015
# 175/175 [==============================] - 7s 39ms/step - loss: 0.1585 - accuracy: 0.9285 - val_loss: 0.0980 - val_accuracy: 0.9749
# Epoch 15/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0834 - accuracy: 0.9652
# Epoch 15: val_loss did not improve from 0.02015
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0834 - accuracy: 0.9652 - val_loss: 0.0660 - val_accuracy: 0.9749
# Epoch 16/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0620 - accuracy: 0.9731
# Epoch 16: val_loss did not improve from 0.02015
# 175/175 [==============================] - 6s 35ms/step - loss: 0.0620 - accuracy: 0.9731 - val_loss: 0.0478 - val_accuracy: 0.9838
# Epoch 17/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0628 - accuracy: 0.9781
# Epoch 17: val_loss did not improve from 0.02015
# 175/175 [==============================] - 6s 34ms/step - loss: 0.0628 - accuracy: 0.9781 - val_loss: 0.0620 - val_accuracy: 0.9820
# Epoch 18/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0535 - accuracy: 0.9776
# Epoch 18: val_loss did not improve from 0.02015
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0533 - accuracy: 0.9777 - val_loss: 0.0404 - val_accuracy: 0.9856
# Epoch 19/25
# 175/175 [==============================] - ETA: 0s - loss: 0.0594 - accuracy: 0.9759
# Epoch 19: val_loss did not improve from 0.02015
# 175/175 [==============================] - 7s 42ms/step - loss: 0.0594 - accuracy: 0.9759 - val_loss: 0.0618 - val_accuracy: 0.9749
# Epoch 20/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0592 - accuracy: 0.9784
# Epoch 20: val_loss did not improve from 0.02015
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0636 - accuracy: 0.9781 - val_loss: 0.0723 - val_accuracy: 0.9695
# Epoch 21/25
# 175/175 [==============================] - ETA: 0s - loss: 0.1512 - accuracy: 0.9372
# Epoch 21: val_loss did not improve from 0.02015
# 175/175 [==============================] - 7s 42ms/step - loss: 0.1512 - accuracy: 0.9372 - val_loss: 0.1638 - val_accuracy: 0.9318
# Epoch 22/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0860 - accuracy: 0.9603
# Epoch 22: val_loss did not improve from 0.02015
# 175/175 [==============================] - 6s 32ms/step - loss: 0.0857 - accuracy: 0.9605 - val_loss: 0.1116 - val_accuracy: 0.9623
# Epoch 23/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0813 - accuracy: 0.9673
# Epoch 23: val_loss did not improve from 0.02015
# 175/175 [==============================] - 7s 39ms/step - loss: 0.0813 - accuracy: 0.9673 - val_loss: 0.0957 - val_accuracy: 0.9623
# Epoch 24/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0653 - accuracy: 0.9709
# Epoch 24: val_loss did not improve from 0.02015
# 175/175 [==============================] - 8s 43ms/step - loss: 0.0653 - accuracy: 0.9709 - val_loss: 0.0946 - val_accuracy: 0.9659
# Epoch 25/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0703 - accuracy: 0.9765
# Epoch 25: val_loss did not improve from 0.02015
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0702 - accuracy: 0.9763 - val_loss: 0.1025 - val_accuracy: 0.9659
# 18/18 [==============================] - 0s 26ms/step - loss: 0.1025 - accuracy: 0.9659
# Epoch 1/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.1051 - accuracy: 0.9653
# Epoch 1: val_loss improved from inf to 0.05702, saving model to EEGNet_checkpoint_5.h5
# 175/175 [==============================] - 8s 31ms/step - loss: 0.1045 - accuracy: 0.9655 - val_loss: 0.0570 - val_accuracy: 0.9820
# Epoch 2/25
# 175/175 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9767
# Epoch 2: val_loss improved from 0.05702 to 0.03977, saving model to EEGNet_checkpoint_5.h5
# 175/175 [==============================] - 8s 44ms/step - loss: 0.0544 - accuracy: 0.9767 - val_loss: 0.0398 - val_accuracy: 0.9874
# Epoch 3/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0629 - accuracy: 0.9741
# Epoch 3: val_loss improved from 0.03977 to 0.03853, saving model to EEGNet_checkpoint_5.h5
# 175/175 [==============================] - 7s 42ms/step - loss: 0.0629 - accuracy: 0.9741 - val_loss: 0.0385 - val_accuracy: 0.9820
# Epoch 4/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0610 - accuracy: 0.9743
# Epoch 4: val_loss improved from 0.03853 to 0.03833, saving model to EEGNet_checkpoint_5.h5
# 175/175 [==============================] - 5s 29ms/step - loss: 0.0606 - accuracy: 0.9745 - val_loss: 0.0383 - val_accuracy: 0.9874
# Epoch 5/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0731 - accuracy: 0.9729
# Epoch 5: val_loss improved from 0.03833 to 0.02873, saving model to EEGNet_checkpoint_5.h5
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0729 - accuracy: 0.9727 - val_loss: 0.0287 - val_accuracy: 0.9892
# Epoch 6/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0585 - accuracy: 0.9795
# Epoch 6: val_loss did not improve from 0.02873
# 175/175 [==============================] - 6s 33ms/step - loss: 0.0584 - accuracy: 0.9795 - val_loss: 0.0637 - val_accuracy: 0.9731
# Epoch 7/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0462 - accuracy: 0.9801
# Epoch 7: val_loss did not improve from 0.02873
# 175/175 [==============================] - 5s 30ms/step - loss: 0.0460 - accuracy: 0.9803 - val_loss: 0.0788 - val_accuracy: 0.9695
# Epoch 8/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0302 - accuracy: 0.9871
# Epoch 8: val_loss did not improve from 0.02873
# 175/175 [==============================] - 7s 42ms/step - loss: 0.0301 - accuracy: 0.9871 - val_loss: 0.0431 - val_accuracy: 0.9785
# Epoch 9/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0709 - accuracy: 0.9794
# Epoch 9: val_loss did not improve from 0.02873
# 175/175 [==============================] - 6s 37ms/step - loss: 0.0705 - accuracy: 0.9795 - val_loss: 0.0536 - val_accuracy: 0.9820
# Epoch 10/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0528 - accuracy: 0.9799
# Epoch 10: val_loss did not improve from 0.02873
# 175/175 [==============================] - 8s 45ms/step - loss: 0.0528 - accuracy: 0.9799 - val_loss: 0.0663 - val_accuracy: 0.9767
# Epoch 11/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0592 - accuracy: 0.9794
# Epoch 11: val_loss did not improve from 0.02873
# 175/175 [==============================] - 5s 31ms/step - loss: 0.0624 - accuracy: 0.9788 - val_loss: 0.0639 - val_accuracy: 0.9785
# Epoch 12/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.1029 - accuracy: 0.9574
# Epoch 12: val_loss did not improve from 0.02873
# 175/175 [==============================] - 5s 30ms/step - loss: 0.1024 - accuracy: 0.9576 - val_loss: 0.0918 - val_accuracy: 0.9623
# Epoch 13/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0684 - accuracy: 0.9713
# Epoch 13: val_loss did not improve from 0.02873
# 175/175 [==============================] - 7s 41ms/step - loss: 0.0684 - accuracy: 0.9713 - val_loss: 0.0728 - val_accuracy: 0.9749
# Epoch 14/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0633 - accuracy: 0.9747
# Epoch 14: val_loss did not improve from 0.02873
# 175/175 [==============================] - 5s 30ms/step - loss: 0.0629 - accuracy: 0.9749 - val_loss: 0.0957 - val_accuracy: 0.9749
# Epoch 15/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0608 - accuracy: 0.9745
# Epoch 15: val_loss did not improve from 0.02873
# 175/175 [==============================] - 6s 35ms/step - loss: 0.0608 - accuracy: 0.9745 - val_loss: 0.0697 - val_accuracy: 0.9767
# Epoch 16/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0402 - accuracy: 0.9827
# Epoch 16: val_loss did not improve from 0.02873
# 175/175 [==============================] - 6s 36ms/step - loss: 0.0409 - accuracy: 0.9824 - val_loss: 0.0858 - val_accuracy: 0.9713
# Epoch 17/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0456 - accuracy: 0.9799
# Epoch 17: val_loss did not improve from 0.02873
# 175/175 [==============================] - 8s 44ms/step - loss: 0.0456 - accuracy: 0.9799 - val_loss: 0.0825 - val_accuracy: 0.9713
# Epoch 18/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0383 - accuracy: 0.9827
# Epoch 18: val_loss did not improve from 0.02873
# 175/175 [==============================] - 7s 40ms/step - loss: 0.0384 - accuracy: 0.9824 - val_loss: 0.0767 - val_accuracy: 0.9713
# Epoch 19/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0480 - accuracy: 0.9809
# Epoch 19: val_loss did not improve from 0.02873
# 175/175 [==============================] - 5s 30ms/step - loss: 0.0481 - accuracy: 0.9806 - val_loss: 0.0935 - val_accuracy: 0.9587
# Epoch 20/25
# 175/175 [==============================] - ETA: 0s - loss: 0.0382 - accuracy: 0.9838
# Epoch 20: val_loss did not improve from 0.02873
# 175/175 [==============================] - 7s 38ms/step - loss: 0.0382 - accuracy: 0.9838 - val_loss: 0.0844 - val_accuracy: 0.9677
# Epoch 21/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0500 - accuracy: 0.9788
# Epoch 21: val_loss did not improve from 0.02873
# 175/175 [==============================] - 8s 46ms/step - loss: 0.0500 - accuracy: 0.9788 - val_loss: 0.1055 - val_accuracy: 0.9677
# Epoch 22/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0518 - accuracy: 0.9835
# Epoch 22: val_loss did not improve from 0.02873
# 175/175 [==============================] - 6s 33ms/step - loss: 0.0518 - accuracy: 0.9835 - val_loss: 0.1157 - val_accuracy: 0.9587
# Epoch 23/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0470 - accuracy: 0.9816
# Epoch 23: val_loss did not improve from 0.02873
# 175/175 [==============================] - 7s 40ms/step - loss: 0.0472 - accuracy: 0.9813 - val_loss: 0.1196 - val_accuracy: 0.9515
# Epoch 24/25
# 174/175 [============================>.] - ETA: 0s - loss: 0.0395 - accuracy: 0.9835
# Epoch 24: val_loss did not improve from 0.02873
# 175/175 [==============================] - 7s 40ms/step - loss: 0.0395 - accuracy: 0.9835 - val_loss: 0.0877 - val_accuracy: 0.9695
# Epoch 25/25
# 173/175 [============================>.] - ETA: 0s - loss: 0.0426 - accuracy: 0.9819
# Epoch 25: val_loss did not improve from 0.02873
# 175/175 [==============================] - 7s 42ms/step - loss: 0.0423 - accuracy: 0.9820 - val_loss: 0.1243 - val_accuracy: 0.9641
# 18/18 [==============================] - 0s 17ms/step - loss: 0.1243 - accuracy: 0.9641
# Average loss: 0.17995348572731018
# Average accuracy: 0.9377618233362833

# %%
for i in range(6):
  print(f"-------------------------------------------{i}----------------------------------------------")
  eegmodel = load_model(f"/content/EEGNet_checkpoint_{i}.h5")
  print("-----------------------------------------training--------------------------------------------")
  metric(x_train,y_train,eegmodel)
  print("-----------------------------------------testing---------------------------------------------")
  metric(x_test,y_test,eegmodel)
  print("---------------------------------------------------------------------------------------------")
# Out:
# -------------------------------------------0----------------------------------------------
# -----------------------------------------training--------------------------------------------
# 79/79 [==============================] - 2s 26ms/step
# Accuracy: 0.933095803642122
# Precision: 0.9002375296912114
# F1-score: 0.8176914778856527
# ROC-curve: 0.9199524940617578
# Confusion matrix:
# -----------------------------------------testing---------------------------------------------
# 26/26 [==============================] - 1s 24ms/step
# Accuracy: 0.9485294117647058
# Precision: 0.9632352941176471
# F1-score: 0.861842105263158
# ROC-curve: 0.9544117647058824
# Confusion matrix:
# ---------------------------------------------------------------------------------------------
# -------------------------------------------1----------------------------------------------
# -----------------------------------------training--------------------------------------------
# 79/79 [==============================] - 1s 15ms/step
# Accuracy: 0.9647664291369754
# Precision: 0.9572446555819477
# F1-score: 0.900558659217877
# ROC-curve: 0.9617577197149643
# Confusion matrix:
# -----------------------------------------testing---------------------------------------------
# 26/26 [==============================] - 0s 14ms/step
# Accuracy: 0.9828431372549019
# Precision: 0.9926470588235294
# F1-score: 0.9507042253521126
# ROC-curve: 0.986764705882353
# Confusion matrix:
# ---------------------------------------------------------------------------------------------
# -------------------------------------------2----------------------------------------------
# -----------------------------------------training--------------------------------------------
# 79/79 [==============================] - 1s 15ms/step
# Accuracy: 0.9853523357086302
# Precision: 0.9904988123515439
# F1-score: 0.9575200918484499
# ROC-curve: 0.9874109263657956
# Confusion matrix:
# -----------------------------------------testing---------------------------------------------
# 26/26 [==============================] - 0s 15ms/step
# Accuracy: 0.9901960784313726
# Precision: 1.0
# F1-score: 0.9714285714285714
# ROC-curve: 0.9941176470588236
# Confusion matrix:
# ---------------------------------------------------------------------------------------------
# -------------------------------------------3----------------------------------------------
# -----------------------------------------training--------------------------------------------
# 79/79 [==============================] - 1s 15ms/step
# Accuracy: 0.9853523357086302
# Precision: 0.995249406175772
# F1-score: 0.9577142857142857
# ROC-curve: 0.9893111638954869
# Confusion matrix:
# -----------------------------------------testing---------------------------------------------
# 26/26 [==============================] - 0s 16ms/step
# Accuracy: 0.991421568627451
# Precision: 1.0
# F1-score: 0.974910394265233
# ROC-curve: 0.9948529411764706
# Confusion matrix:
# ---------------------------------------------------------------------------------------------
# -------------------------------------------4----------------------------------------------
# -----------------------------------------training--------------------------------------------
# 79/79 [==============================] - 1s 15ms/step
# Accuracy: 0.994061757719715
# Precision: 0.997624703087886
# F1-score: 0.9824561403508771
# ROC-curve: 0.9954869358669834
# Confusion matrix:
# -----------------------------------------testing---------------------------------------------
# 26/26 [==============================] - 1s 25ms/step
# Accuracy: 0.9938725490196079
# Precision: 1.0
# F1-score: 0.9819494584837545
# ROC-curve: 0.9963235294117647
# Confusion matrix:
# ---------------------------------------------------------------------------------------------
# -------------------------------------------5----------------------------------------------
# -----------------------------------------training--------------------------------------------
# 79/79 [==============================] - 1s 15ms/step
# Accuracy: 0.9956452889944576
# Precision: 1.0
# F1-score: 0.9871043376318874
# ROC-curve: 0.9973871733966746
# Confusion matrix:
# -----------------------------------------testing---------------------------------------------
# 26/26 [==============================] - 0s 16ms/step
# Accuracy: 0.991421568627451
# Precision: 1.0
# F1-score: 0.974910394265233
# ROC-curve: 0.9948529411764706
# Confusion matrix:
# ---------------------------------------------------------------------------------------------

# %% [markdown]
# # **ChronoNet**

# %% [markdown]
# **V1**

# %%
def chrono_v1():
  # Define the model architecture
  model = Sequential()

  # Add the convolutional layers
  model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(32, 32)))
  model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
  model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))

  # Add the max pooling layers
  model.add(MaxPooling1D(pool_size=2, strides=2))

  # Add the recurrent layers
  model.add(LSTM(units=32, dropout=0.5, recurrent_dropout=0.5, return_sequences=True))
  model.add(LSTM(units=32, dropout=0.5, recurrent_dropout=0.5))

  # Concatenate the output from the convolutional and recurrent layers
  model.add(Flatten())
  model.add(Dense(units=64, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(units=1, activation='sigmoid'))
  return model

# %%
chrono_v1_model=None
chrono_v1_model = chrono_v1()
K_Fold_Val("chrono_v1", chrono_v1_model, x, y, 25, 8, K=5)
# Out:
# Epoch 1/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.6679 - accuracy: 0.5353
# Epoch 1: val_loss improved from inf to 0.57669, saving model to chrono_v1_checkpoint_0.h5
# 334/334 [==============================] - 23s 39ms/step - loss: 0.6680 - accuracy: 0.5356 - val_loss: 0.5767 - val_accuracy: 0.6123
# Epoch 2/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.6309 - accuracy: 0.6434
# Epoch 2: val_loss did not improve from 0.57669
# 334/334 [==============================] - 11s 33ms/step - loss: 0.6309 - accuracy: 0.6428 - val_loss: 0.6072 - val_accuracy: 0.6228
# Epoch 3/25
# 334/334 [==============================] - ETA: 0s - loss: 0.6036 - accuracy: 0.6574
# Epoch 3: val_loss did not improve from 0.57669
# 334/334 [==============================] - 12s 36ms/step - loss: 0.6036 - accuracy: 0.6574 - val_loss: 0.6363 - val_accuracy: 0.6362
# Epoch 4/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.5903 - accuracy: 0.6749
# Epoch 4: val_loss did not improve from 0.57669
# 334/334 [==============================] - 13s 38ms/step - loss: 0.5903 - accuracy: 0.6747 - val_loss: 0.6405 - val_accuracy: 0.6527
# Epoch 5/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.5546 - accuracy: 0.7365
# Epoch 5: val_loss improved from 0.57669 to 0.50027, saving model to chrono_v1_checkpoint_0.h5
# 334/334 [==============================] - 13s 38ms/step - loss: 0.5553 - accuracy: 0.7365 - val_loss: 0.5003 - val_accuracy: 0.7979
# Epoch 6/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.5338 - accuracy: 0.7673
# Epoch 6: val_loss did not improve from 0.50027
# 334/334 [==============================] - 13s 38ms/step - loss: 0.5334 - accuracy: 0.7676 - val_loss: 0.5487 - val_accuracy: 0.7455
# Epoch 7/25
# 334/334 [==============================] - ETA: 0s - loss: 0.5126 - accuracy: 0.7721
# Epoch 7: val_loss improved from 0.50027 to 0.42875, saving model to chrono_v1_checkpoint_0.h5
# 334/334 [==============================] - 14s 42ms/step - loss: 0.5126 - accuracy: 0.7721 - val_loss: 0.4287 - val_accuracy: 0.8024
# Epoch 8/25
# 334/334 [==============================] - ETA: 0s - loss: 0.4928 - accuracy: 0.7759
# Epoch 8: val_loss did not improve from 0.42875
# 334/334 [==============================] - 11s 32ms/step - loss: 0.4928 - accuracy: 0.7759 - val_loss: 0.6427 - val_accuracy: 0.6677
# Epoch 9/25
# 334/334 [==============================] - ETA: 0s - loss: 0.4791 - accuracy: 0.7717
# Epoch 9: val_loss did not improve from 0.42875
# 334/334 [==============================] - 12s 36ms/step - loss: 0.4791 - accuracy: 0.7717 - val_loss: 0.5655 - val_accuracy: 0.7290
# Epoch 10/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.4544 - accuracy: 0.7913
# Epoch 10: val_loss did not improve from 0.42875
# 334/334 [==============================] - 13s 37ms/step - loss: 0.4541 - accuracy: 0.7916 - val_loss: 0.6303 - val_accuracy: 0.7111
# Epoch 11/25
# 334/334 [==============================] - ETA: 0s - loss: 0.4273 - accuracy: 0.8070
# Epoch 11: val_loss did not improve from 0.42875
# 334/334 [==============================] - 13s 38ms/step - loss: 0.4273 - accuracy: 0.8070 - val_loss: 0.6621 - val_accuracy: 0.6931
# Epoch 12/25
# 334/334 [==============================] - ETA: 0s - loss: 0.4056 - accuracy: 0.8126
# Epoch 12: val_loss did not improve from 0.42875
# 334/334 [==============================] - 12s 37ms/step - loss: 0.4056 - accuracy: 0.8126 - val_loss: 0.5785 - val_accuracy: 0.7500
# Epoch 13/25
# 334/334 [==============================] - ETA: 0s - loss: 0.3923 - accuracy: 0.8261
# Epoch 13: val_loss did not improve from 0.42875
# 334/334 [==============================] - 11s 33ms/step - loss: 0.3923 - accuracy: 0.8261 - val_loss: 0.5573 - val_accuracy: 0.7440
# Epoch 14/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.3716 - accuracy: 0.8442
# Epoch 14: val_loss did not improve from 0.42875
# 334/334 [==============================] - 12s 35ms/step - loss: 0.3732 - accuracy: 0.8437 - val_loss: 0.5188 - val_accuracy: 0.7769
# Epoch 15/25
# 334/334 [==============================] - ETA: 0s - loss: 0.3417 - accuracy: 0.8407
# Epoch 15: val_loss did not improve from 0.42875
# 334/334 [==============================] - 12s 37ms/step - loss: 0.3417 - accuracy: 0.8407 - val_loss: 0.6329 - val_accuracy: 0.7455
# Epoch 16/25
# 334/334 [==============================] - ETA: 0s - loss: 0.3352 - accuracy: 0.8433
# Epoch 16: val_loss did not improve from 0.42875
# 334/334 [==============================] - 13s 38ms/step - loss: 0.3352 - accuracy: 0.8433 - val_loss: 0.5909 - val_accuracy: 0.7635
# Epoch 17/25
# 334/334 [==============================] - ETA: 0s - loss: 0.3032 - accuracy: 0.8433
# Epoch 17: val_loss did not improve from 0.42875
# 334/334 [==============================] - 15s 44ms/step - loss: 0.3032 - accuracy: 0.8433 - val_loss: 0.5899 - val_accuracy: 0.7380
# Epoch 18/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.3173 - accuracy: 0.8525
# Epoch 18: val_loss did not improve from 0.42875
# 334/334 [==============================] - 13s 39ms/step - loss: 0.3169 - accuracy: 0.8527 - val_loss: 0.6334 - val_accuracy: 0.7455
# Epoch 19/25
# 334/334 [==============================] - ETA: 0s - loss: 0.2794 - accuracy: 0.8767
# Epoch 19: val_loss did not improve from 0.42875
# 334/334 [==============================] - 11s 32ms/step - loss: 0.2794 - accuracy: 0.8767 - val_loss: 0.5677 - val_accuracy: 0.7784
# Epoch 20/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.2697 - accuracy: 0.8754
# Epoch 20: val_loss did not improve from 0.42875
# 334/334 [==============================] - 12s 37ms/step - loss: 0.2695 - accuracy: 0.8756 - val_loss: 0.6802 - val_accuracy: 0.7380
# Epoch 21/25
# 334/334 [==============================] - ETA: 0s - loss: 0.2292 - accuracy: 0.8891
# Epoch 21: val_loss did not improve from 0.42875
# 334/334 [==============================] - 13s 38ms/step - loss: 0.2292 - accuracy: 0.8891 - val_loss: 0.6686 - val_accuracy: 0.7635
# Epoch 22/25
# 334/334 [==============================] - ETA: 0s - loss: 0.2479 - accuracy: 0.8853
# Epoch 22: val_loss did not improve from 0.42875
# 334/334 [==============================] - 13s 38ms/step - loss: 0.2479 - accuracy: 0.8853 - val_loss: 0.6710 - val_accuracy: 0.7665
# Epoch 23/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.2319 - accuracy: 0.8956
# Epoch 23: val_loss did not improve from 0.42875
# 334/334 [==============================] - 13s 38ms/step - loss: 0.2316 - accuracy: 0.8958 - val_loss: 0.6359 - val_accuracy: 0.7814
# Epoch 24/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.2299 - accuracy: 0.8893
# Epoch 24: val_loss did not improve from 0.42875
# 334/334 [==============================] - 11s 33ms/step - loss: 0.2302 - accuracy: 0.8887 - val_loss: 0.6504 - val_accuracy: 0.7889
# Epoch 25/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.2115 - accuracy: 0.9009
# Epoch 25: val_loss did not improve from 0.42875
# 334/334 [==============================] - 12s 35ms/step - loss: 0.2113 - accuracy: 0.9010 - val_loss: 0.8288 - val_accuracy: 0.7425
# 21/21 [==============================] - 0s 12ms/step - loss: 0.8288 - accuracy: 0.7425
# Epoch 1/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.3701 - accuracy: 0.8626
# Epoch 1: val_loss improved from inf to 0.20676, saving model to chrono_v1_checkpoint_1.h5
# 334/334 [==============================] - 21s 40ms/step - loss: 0.3700 - accuracy: 0.8625 - val_loss: 0.2068 - val_accuracy: 0.9235
# Epoch 2/25
# 334/334 [==============================] - ETA: 0s - loss: 0.3150 - accuracy: 0.8756
# Epoch 2: val_loss did not improve from 0.20676
# 334/334 [==============================] - 13s 38ms/step - loss: 0.3150 - accuracy: 0.8756 - val_loss: 0.2317 - val_accuracy: 0.9175
# Epoch 3/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.2954 - accuracy: 0.8851
# Epoch 3: val_loss did not improve from 0.20676
# 334/334 [==============================] - 11s 32ms/step - loss: 0.2955 - accuracy: 0.8854 - val_loss: 0.2507 - val_accuracy: 0.8996
# Epoch 4/25
# 334/334 [==============================] - ETA: 0s - loss: 0.2606 - accuracy: 0.9041
# Epoch 4: val_loss did not improve from 0.20676
# 334/334 [==============================] - 12s 37ms/step - loss: 0.2606 - accuracy: 0.9041 - val_loss: 0.3581 - val_accuracy: 0.8666
# Epoch 5/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.2617 - accuracy: 0.8851
# Epoch 5: val_loss did not improve from 0.20676
# 334/334 [==============================] - 13s 38ms/step - loss: 0.2620 - accuracy: 0.8850 - val_loss: 0.3165 - val_accuracy: 0.8441
# Epoch 6/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.2323 - accuracy: 0.9088
# Epoch 6: val_loss did not improve from 0.20676
# 334/334 [==============================] - 12s 37ms/step - loss: 0.2319 - accuracy: 0.9090 - val_loss: 0.2774 - val_accuracy: 0.8861
# Epoch 7/25
# 334/334 [==============================] - ETA: 0s - loss: 0.2239 - accuracy: 0.9037
# Epoch 7: val_loss did not improve from 0.20676
# 334/334 [==============================] - 15s 45ms/step - loss: 0.2239 - accuracy: 0.9037 - val_loss: 0.2885 - val_accuracy: 0.8756
# Epoch 8/25
# 334/334 [==============================] - ETA: 0s - loss: 0.2338 - accuracy: 0.8928
# Epoch 8: val_loss did not improve from 0.20676
# 334/334 [==============================] - 12s 37ms/step - loss: 0.2338 - accuracy: 0.8928 - val_loss: 0.2950 - val_accuracy: 0.8726
# Epoch 9/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.2042 - accuracy: 0.9174
# Epoch 9: val_loss did not improve from 0.20676
# 334/334 [==============================] - 11s 32ms/step - loss: 0.2041 - accuracy: 0.9172 - val_loss: 0.2587 - val_accuracy: 0.8906
# Epoch 10/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.1853 - accuracy: 0.9197
# Epoch 10: val_loss did not improve from 0.20676
# 334/334 [==============================] - 12s 37ms/step - loss: 0.1852 - accuracy: 0.9198 - val_loss: 0.2744 - val_accuracy: 0.8921
# Epoch 11/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.2058 - accuracy: 0.9133
# Epoch 11: val_loss did not improve from 0.20676
# 334/334 [==============================] - 13s 38ms/step - loss: 0.2056 - accuracy: 0.9131 - val_loss: 0.2634 - val_accuracy: 0.8996
# Epoch 12/25
# 334/334 [==============================] - ETA: 0s - loss: 0.2122 - accuracy: 0.9075
# Epoch 12: val_loss did not improve from 0.20676
# 334/334 [==============================] - 13s 38ms/step - loss: 0.2122 - accuracy: 0.9075 - val_loss: 0.3587 - val_accuracy: 0.8681
# Epoch 13/25
# 334/334 [==============================] - ETA: 0s - loss: 0.1693 - accuracy: 0.9251
# Epoch 13: val_loss did not improve from 0.20676
# 334/334 [==============================] - 13s 38ms/step - loss: 0.1693 - accuracy: 0.9251 - val_loss: 0.4376 - val_accuracy: 0.8501
# Epoch 14/25
# 334/334 [==============================] - ETA: 0s - loss: 0.1577 - accuracy: 0.9374
# Epoch 14: val_loss did not improve from 0.20676
# 334/334 [==============================] - 11s 32ms/step - loss: 0.1577 - accuracy: 0.9374 - val_loss: 0.4054 - val_accuracy: 0.8681
# Epoch 15/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.1511 - accuracy: 0.9388
# Epoch 15: val_loss did not improve from 0.20676
# 334/334 [==============================] - 12s 37ms/step - loss: 0.1508 - accuracy: 0.9389 - val_loss: 0.4269 - val_accuracy: 0.8516
# Epoch 16/25
# 334/334 [==============================] - ETA: 0s - loss: 0.1528 - accuracy: 0.9303
# Epoch 16: val_loss did not improve from 0.20676
# 334/334 [==============================] - 13s 39ms/step - loss: 0.1528 - accuracy: 0.9303 - val_loss: 0.4345 - val_accuracy: 0.8636
# Epoch 17/25
# 334/334 [==============================] - ETA: 0s - loss: 0.1530 - accuracy: 0.9356
# Epoch 17: val_loss did not improve from 0.20676
# 334/334 [==============================] - 13s 38ms/step - loss: 0.1530 - accuracy: 0.9356 - val_loss: 0.3510 - val_accuracy: 0.8801
# Epoch 18/25
# 334/334 [==============================] - ETA: 0s - loss: 0.1600 - accuracy: 0.9288
# Epoch 18: val_loss did not improve from 0.20676
# 334/334 [==============================] - 13s 38ms/step - loss: 0.1600 - accuracy: 0.9288 - val_loss: 0.4906 - val_accuracy: 0.8456
# Epoch 19/25
# 334/334 [==============================] - ETA: 0s - loss: 0.1656 - accuracy: 0.9288
# Epoch 19: val_loss did not improve from 0.20676
# 334/334 [==============================] - 11s 33ms/step - loss: 0.1656 - accuracy: 0.9288 - val_loss: 0.4346 - val_accuracy: 0.8651
# Epoch 20/25
# 334/334 [==============================] - ETA: 0s - loss: 0.1266 - accuracy: 0.9453
# Epoch 20: val_loss did not improve from 0.20676
# 334/334 [==============================] - 12s 36ms/step - loss: 0.1266 - accuracy: 0.9453 - val_loss: 0.4122 - val_accuracy: 0.8756
# Epoch 21/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.1206 - accuracy: 0.9516
# Epoch 21: val_loss did not improve from 0.20676
# 334/334 [==============================] - 13s 38ms/step - loss: 0.1212 - accuracy: 0.9517 - val_loss: 0.4027 - val_accuracy: 0.8816
# Epoch 22/25
# 334/334 [==============================] - ETA: 0s - loss: 0.1335 - accuracy: 0.9423
# Epoch 22: val_loss did not improve from 0.20676
# 334/334 [==============================] - 13s 39ms/step - loss: 0.1335 - accuracy: 0.9423 - val_loss: 0.3676 - val_accuracy: 0.9085
# Epoch 23/25
# 334/334 [==============================] - ETA: 0s - loss: 0.1081 - accuracy: 0.9539
# Epoch 23: val_loss did not improve from 0.20676
# 334/334 [==============================] - 14s 43ms/step - loss: 0.1081 - accuracy: 0.9539 - val_loss: 0.3607 - val_accuracy: 0.8906
# Epoch 24/25
# 334/334 [==============================] - ETA: 0s - loss: 0.1276 - accuracy: 0.9505
# Epoch 24: val_loss did not improve from 0.20676
# 334/334 [==============================] - 13s 38ms/step - loss: 0.1276 - accuracy: 0.9505 - val_loss: 0.3596 - val_accuracy: 0.8891
# Epoch 25/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0958 - accuracy: 0.9539
# Epoch 25: val_loss did not improve from 0.20676
# 334/334 [==============================] - 11s 34ms/step - loss: 0.0958 - accuracy: 0.9539 - val_loss: 0.3949 - val_accuracy: 0.8951
# 21/21 [==============================] - 0s 7ms/step - loss: 0.3949 - accuracy: 0.8951
# Epoch 1/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.2375 - accuracy: 0.9238
# Epoch 1: val_loss improved from inf to 0.28047, saving model to chrono_v1_checkpoint_2.h5
# 334/334 [==============================] - 22s 41ms/step - loss: 0.2382 - accuracy: 0.9232 - val_loss: 0.2805 - val_accuracy: 0.8861
# Epoch 2/25
# 334/334 [==============================] - ETA: 0s - loss: 0.1636 - accuracy: 0.9322
# Epoch 2: val_loss improved from 0.28047 to 0.12485, saving model to chrono_v1_checkpoint_2.h5
# 334/334 [==============================] - 13s 39ms/step - loss: 0.1636 - accuracy: 0.9322 - val_loss: 0.1248 - val_accuracy: 0.9610
# Epoch 3/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.1415 - accuracy: 0.9463
# Epoch 3: val_loss did not improve from 0.12485
# 334/334 [==============================] - 11s 33ms/step - loss: 0.1423 - accuracy: 0.9460 - val_loss: 0.2053 - val_accuracy: 0.9235
# Epoch 4/25
# 334/334 [==============================] - ETA: 0s - loss: 0.1404 - accuracy: 0.9457
# Epoch 4: val_loss did not improve from 0.12485
# 334/334 [==============================] - 12s 37ms/step - loss: 0.1404 - accuracy: 0.9457 - val_loss: 0.1534 - val_accuracy: 0.9430
# Epoch 5/25
# 334/334 [==============================] - ETA: 0s - loss: 0.1258 - accuracy: 0.9479
# Epoch 5: val_loss improved from 0.12485 to 0.12464, saving model to chrono_v1_checkpoint_2.h5
# 334/334 [==============================] - 13s 39ms/step - loss: 0.1258 - accuracy: 0.9479 - val_loss: 0.1246 - val_accuracy: 0.9520
# Epoch 6/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.1000 - accuracy: 0.9565
# Epoch 6: val_loss improved from 0.12464 to 0.11678, saving model to chrono_v1_checkpoint_2.h5
# 334/334 [==============================] - 13s 40ms/step - loss: 0.0998 - accuracy: 0.9565 - val_loss: 0.1168 - val_accuracy: 0.9520
# Epoch 7/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.1191 - accuracy: 0.9550
# Epoch 7: val_loss did not improve from 0.11678
# 334/334 [==============================] - 13s 38ms/step - loss: 0.1189 - accuracy: 0.9550 - val_loss: 0.1823 - val_accuracy: 0.9400
# Epoch 8/25
# 334/334 [==============================] - ETA: 0s - loss: 0.1116 - accuracy: 0.9562
# Epoch 8: val_loss did not improve from 0.11678
# 334/334 [==============================] - 13s 39ms/step - loss: 0.1116 - accuracy: 0.9562 - val_loss: 0.1790 - val_accuracy: 0.9295
# Epoch 9/25
# 334/334 [==============================] - ETA: 0s - loss: 0.1119 - accuracy: 0.9607
# Epoch 9: val_loss did not improve from 0.11678
# 334/334 [==============================] - 11s 33ms/step - loss: 0.1119 - accuracy: 0.9607 - val_loss: 0.1654 - val_accuracy: 0.9460
# Epoch 10/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0904 - accuracy: 0.9651
# Epoch 10: val_loss did not improve from 0.11678
# 334/334 [==============================] - 12s 37ms/step - loss: 0.0903 - accuracy: 0.9652 - val_loss: 0.2477 - val_accuracy: 0.9130
# Epoch 11/25
# 334/334 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9569
# Epoch 11: val_loss did not improve from 0.11678
# 334/334 [==============================] - 13s 39ms/step - loss: 0.1042 - accuracy: 0.9569 - val_loss: 0.1998 - val_accuracy: 0.9325
# Epoch 12/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0978 - accuracy: 0.9580
# Epoch 12: val_loss did not improve from 0.11678
# 334/334 [==============================] - 13s 39ms/step - loss: 0.0978 - accuracy: 0.9580 - val_loss: 0.2028 - val_accuracy: 0.9190
# Epoch 13/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0888 - accuracy: 0.9637
# Epoch 13: val_loss did not improve from 0.11678
# 334/334 [==============================] - 13s 39ms/step - loss: 0.0888 - accuracy: 0.9637 - val_loss: 0.2237 - val_accuracy: 0.9295
# Epoch 14/25
# 334/334 [==============================] - ETA: 0s - loss: 0.1118 - accuracy: 0.9562
# Epoch 14: val_loss did not improve from 0.11678
# 334/334 [==============================] - 16s 47ms/step - loss: 0.1118 - accuracy: 0.9562 - val_loss: 0.2459 - val_accuracy: 0.9235
# Epoch 15/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0761 - accuracy: 0.9745
# Epoch 15: val_loss did not improve from 0.11678
# 334/334 [==============================] - 12s 37ms/step - loss: 0.0761 - accuracy: 0.9745 - val_loss: 0.2781 - val_accuracy: 0.9040
# Epoch 16/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.1271 - accuracy: 0.9583
# Epoch 16: val_loss did not improve from 0.11678
# 334/334 [==============================] - 12s 37ms/step - loss: 0.1269 - accuracy: 0.9584 - val_loss: 0.2487 - val_accuracy: 0.9190
# Epoch 17/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0905 - accuracy: 0.9606
# Epoch 17: val_loss did not improve from 0.11678
# 334/334 [==============================] - 12s 36ms/step - loss: 0.0910 - accuracy: 0.9603 - val_loss: 0.2229 - val_accuracy: 0.9250
# Epoch 18/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0907 - accuracy: 0.9688
# Epoch 18: val_loss did not improve from 0.11678
# 334/334 [==============================] - 13s 39ms/step - loss: 0.0906 - accuracy: 0.9689 - val_loss: 0.3156 - val_accuracy: 0.8951
# Epoch 19/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0759 - accuracy: 0.9733
# Epoch 19: val_loss did not improve from 0.11678
# 334/334 [==============================] - 13s 39ms/step - loss: 0.0757 - accuracy: 0.9734 - val_loss: 0.2614 - val_accuracy: 0.9145
# Epoch 20/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0811 - accuracy: 0.9678
# Epoch 20: val_loss did not improve from 0.11678
# 334/334 [==============================] - 13s 40ms/step - loss: 0.0811 - accuracy: 0.9678 - val_loss: 0.2967 - val_accuracy: 0.8996
# Epoch 21/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0689 - accuracy: 0.9707
# Epoch 21: val_loss did not improve from 0.11678
# 334/334 [==============================] - 14s 41ms/step - loss: 0.0688 - accuracy: 0.9708 - val_loss: 0.3294 - val_accuracy: 0.9055
# Epoch 22/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0538 - accuracy: 0.9820
# Epoch 22: val_loss did not improve from 0.11678
# 334/334 [==============================] - 11s 34ms/step - loss: 0.0538 - accuracy: 0.9820 - val_loss: 0.2812 - val_accuracy: 0.9160
# Epoch 23/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0856 - accuracy: 0.9708
# Epoch 23: val_loss did not improve from 0.11678
# 334/334 [==============================] - 12s 37ms/step - loss: 0.0856 - accuracy: 0.9708 - val_loss: 0.2861 - val_accuracy: 0.9100
# Epoch 24/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.1040 - accuracy: 0.9561
# Epoch 24: val_loss did not improve from 0.11678
# 334/334 [==============================] - 13s 40ms/step - loss: 0.1038 - accuracy: 0.9562 - val_loss: 0.2794 - val_accuracy: 0.9100
# Epoch 25/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0963 - accuracy: 0.9599
# Epoch 25: val_loss did not improve from 0.11678
# 334/334 [==============================] - 13s 39ms/step - loss: 0.0963 - accuracy: 0.9599 - val_loss: 0.3148 - val_accuracy: 0.9025
# 21/21 [==============================] - 0s 7ms/step - loss: 0.3148 - accuracy: 0.9025
# Epoch 1/25
# 334/334 [==============================] - ETA: 0s - loss: 0.1580 - accuracy: 0.9490
# Epoch 1: val_loss improved from inf to 0.05380, saving model to chrono_v1_checkpoint_3.h5
# 334/334 [==============================] - 22s 41ms/step - loss: 0.1580 - accuracy: 0.9490 - val_loss: 0.0538 - val_accuracy: 0.9820
# Epoch 2/25
# 334/334 [==============================] - ETA: 0s - loss: 0.1025 - accuracy: 0.9569
# Epoch 2: val_loss improved from 0.05380 to 0.02770, saving model to chrono_v1_checkpoint_3.h5
# 334/334 [==============================] - 12s 34ms/step - loss: 0.1025 - accuracy: 0.9569 - val_loss: 0.0277 - val_accuracy: 0.9895
# Epoch 3/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0931 - accuracy: 0.9640
# Epoch 3: val_loss did not improve from 0.02770
# 334/334 [==============================] - 12s 37ms/step - loss: 0.0931 - accuracy: 0.9640 - val_loss: 0.0524 - val_accuracy: 0.9790
# Epoch 4/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0969 - accuracy: 0.9602
# Epoch 4: val_loss did not improve from 0.02770
# 334/334 [==============================] - 16s 48ms/step - loss: 0.0967 - accuracy: 0.9603 - val_loss: 0.0596 - val_accuracy: 0.9700
# Epoch 5/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0809 - accuracy: 0.9722
# Epoch 5: val_loss did not improve from 0.02770
# 334/334 [==============================] - 13s 39ms/step - loss: 0.0808 - accuracy: 0.9723 - val_loss: 0.0447 - val_accuracy: 0.9805
# Epoch 6/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0843 - accuracy: 0.9667
# Epoch 6: val_loss did not improve from 0.02770
# 334/334 [==============================] - 13s 39ms/step - loss: 0.0843 - accuracy: 0.9667 - val_loss: 0.0859 - val_accuracy: 0.9685
# Epoch 7/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0667 - accuracy: 0.9734
# Epoch 7: val_loss did not improve from 0.02770
# 334/334 [==============================] - 11s 34ms/step - loss: 0.0667 - accuracy: 0.9734 - val_loss: 0.1101 - val_accuracy: 0.9535
# Epoch 8/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0978 - accuracy: 0.9640
# Epoch 8: val_loss did not improve from 0.02770
# 334/334 [==============================] - 12s 37ms/step - loss: 0.0978 - accuracy: 0.9640 - val_loss: 0.0932 - val_accuracy: 0.9655
# Epoch 9/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0708 - accuracy: 0.9741
# Epoch 9: val_loss did not improve from 0.02770
# 334/334 [==============================] - 13s 40ms/step - loss: 0.0708 - accuracy: 0.9741 - val_loss: 0.1105 - val_accuracy: 0.9580
# Epoch 10/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0828 - accuracy: 0.9659
# Epoch 10: val_loss did not improve from 0.02770
# 334/334 [==============================] - 13s 40ms/step - loss: 0.0828 - accuracy: 0.9659 - val_loss: 0.0969 - val_accuracy: 0.9640
# Epoch 11/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0379 - accuracy: 0.9854
# Epoch 11: val_loss did not improve from 0.02770
# 334/334 [==============================] - 13s 39ms/step - loss: 0.0378 - accuracy: 0.9854 - val_loss: 0.0691 - val_accuracy: 0.9805
# Epoch 12/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0803 - accuracy: 0.9697
# Epoch 12: val_loss did not improve from 0.02770
# 334/334 [==============================] - 13s 40ms/step - loss: 0.0803 - accuracy: 0.9697 - val_loss: 0.1153 - val_accuracy: 0.9625
# Epoch 13/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0921 - accuracy: 0.9667
# Epoch 13: val_loss did not improve from 0.02770
# 334/334 [==============================] - 12s 37ms/step - loss: 0.0921 - accuracy: 0.9667 - val_loss: 0.0956 - val_accuracy: 0.9610
# Epoch 14/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0695 - accuracy: 0.9700
# Epoch 14: val_loss did not improve from 0.02770
# 334/334 [==============================] - 12s 36ms/step - loss: 0.0695 - accuracy: 0.9700 - val_loss: 0.1037 - val_accuracy: 0.9685
# Epoch 15/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0900 - accuracy: 0.9677
# Epoch 15: val_loss did not improve from 0.02770
# 334/334 [==============================] - 13s 39ms/step - loss: 0.0899 - accuracy: 0.9678 - val_loss: 0.1614 - val_accuracy: 0.9535
# Epoch 16/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0564 - accuracy: 0.9775
# Epoch 16: val_loss did not improve from 0.02770
# 334/334 [==============================] - 13s 39ms/step - loss: 0.0563 - accuracy: 0.9775 - val_loss: 0.1319 - val_accuracy: 0.9595
# Epoch 17/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0570 - accuracy: 0.9760
# Epoch 17: val_loss did not improve from 0.02770
# 334/334 [==============================] - 13s 39ms/step - loss: 0.0569 - accuracy: 0.9760 - val_loss: 0.1956 - val_accuracy: 0.9475
# Epoch 18/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0755 - accuracy: 0.9693
# Epoch 18: val_loss did not improve from 0.02770
# 334/334 [==============================] - 13s 40ms/step - loss: 0.0755 - accuracy: 0.9693 - val_loss: 0.1337 - val_accuracy: 0.9565
# Epoch 19/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0477 - accuracy: 0.9828
# Epoch 19: val_loss did not improve from 0.02770
# 334/334 [==============================] - 14s 43ms/step - loss: 0.0477 - accuracy: 0.9828 - val_loss: 0.1608 - val_accuracy: 0.9505
# Epoch 20/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0592 - accuracy: 0.9779
# Epoch 20: val_loss did not improve from 0.02770
# 334/334 [==============================] - 12s 36ms/step - loss: 0.0592 - accuracy: 0.9779 - val_loss: 0.1678 - val_accuracy: 0.9490
# Epoch 21/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.1117 - accuracy: 0.9565
# Epoch 21: val_loss did not improve from 0.02770
# 334/334 [==============================] - 13s 39ms/step - loss: 0.1115 - accuracy: 0.9565 - val_loss: 0.1869 - val_accuracy: 0.9385
# Epoch 22/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0594 - accuracy: 0.9737
# Epoch 22: val_loss did not improve from 0.02770
# 334/334 [==============================] - 13s 39ms/step - loss: 0.0593 - accuracy: 0.9738 - val_loss: 0.1795 - val_accuracy: 0.9445
# Epoch 23/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0595 - accuracy: 0.9801
# Epoch 23: val_loss did not improve from 0.02770
# 334/334 [==============================] - 13s 40ms/step - loss: 0.0595 - accuracy: 0.9801 - val_loss: 0.2179 - val_accuracy: 0.9400
# Epoch 24/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0404 - accuracy: 0.9820
# Epoch 24: val_loss did not improve from 0.02770
# 334/334 [==============================] - 13s 40ms/step - loss: 0.0409 - accuracy: 0.9816 - val_loss: 0.1637 - val_accuracy: 0.9550
# Epoch 25/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0533 - accuracy: 0.9801
# Epoch 25: val_loss did not improve from 0.02770
# 334/334 [==============================] - 12s 37ms/step - loss: 0.0533 - accuracy: 0.9801 - val_loss: 0.2444 - val_accuracy: 0.9310
# 21/21 [==============================] - 0s 7ms/step - loss: 0.2444 - accuracy: 0.9310
# Epoch 1/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.1271 - accuracy: 0.9583
# Epoch 1: val_loss improved from inf to 0.05982, saving model to chrono_v1_checkpoint_4.h5
# 334/334 [==============================] - 20s 38ms/step - loss: 0.1269 - accuracy: 0.9584 - val_loss: 0.0598 - val_accuracy: 0.9805
# Epoch 2/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0733 - accuracy: 0.9681
# Epoch 2: val_loss improved from 0.05982 to 0.02890, saving model to chrono_v1_checkpoint_4.h5
# 334/334 [==============================] - 13s 40ms/step - loss: 0.0732 - accuracy: 0.9682 - val_loss: 0.0289 - val_accuracy: 0.9865
# Epoch 3/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0495 - accuracy: 0.9809
# Epoch 3: val_loss did not improve from 0.02890
# 334/334 [==============================] - 13s 40ms/step - loss: 0.0494 - accuracy: 0.9809 - val_loss: 0.1045 - val_accuracy: 0.9760
# Epoch 4/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0927 - accuracy: 0.9662
# Epoch 4: val_loss did not improve from 0.02890
# 334/334 [==============================] - 13s 40ms/step - loss: 0.0925 - accuracy: 0.9663 - val_loss: 0.0538 - val_accuracy: 0.9865
# Epoch 5/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0728 - accuracy: 0.9718
# Epoch 5: val_loss did not improve from 0.02890
# 334/334 [==============================] - 15s 46ms/step - loss: 0.0728 - accuracy: 0.9719 - val_loss: 0.0606 - val_accuracy: 0.9820
# Epoch 6/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0656 - accuracy: 0.9801
# Epoch 6: val_loss did not improve from 0.02890
# 334/334 [==============================] - 13s 40ms/step - loss: 0.0655 - accuracy: 0.9801 - val_loss: 0.0499 - val_accuracy: 0.9805
# Epoch 7/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0741 - accuracy: 0.9737
# Epoch 7: val_loss did not improve from 0.02890
# 334/334 [==============================] - 13s 38ms/step - loss: 0.0739 - accuracy: 0.9738 - val_loss: 0.1391 - val_accuracy: 0.9655
# Epoch 8/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0578 - accuracy: 0.9786
# Epoch 8: val_loss did not improve from 0.02890
# 334/334 [==============================] - 12s 35ms/step - loss: 0.0578 - accuracy: 0.9786 - val_loss: 0.1205 - val_accuracy: 0.9610
# Epoch 9/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0435 - accuracy: 0.9854
# Epoch 9: val_loss did not improve from 0.02890
# 334/334 [==============================] - 13s 39ms/step - loss: 0.0435 - accuracy: 0.9854 - val_loss: 0.1005 - val_accuracy: 0.9760
# Epoch 10/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0558 - accuracy: 0.9801
# Epoch 10: val_loss did not improve from 0.02890
# 334/334 [==============================] - 13s 40ms/step - loss: 0.0557 - accuracy: 0.9801 - val_loss: 0.1339 - val_accuracy: 0.9655
# Epoch 11/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0384 - accuracy: 0.9839
# Epoch 11: val_loss did not improve from 0.02890
# 334/334 [==============================] - 13s 39ms/step - loss: 0.0384 - accuracy: 0.9839 - val_loss: 0.1332 - val_accuracy: 0.9685
# Epoch 12/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0681 - accuracy: 0.9816
# Epoch 12: val_loss did not improve from 0.02890
# 334/334 [==============================] - 13s 40ms/step - loss: 0.0680 - accuracy: 0.9816 - val_loss: 0.1048 - val_accuracy: 0.9670
# Epoch 13/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0338 - accuracy: 0.9880
# Epoch 13: val_loss did not improve from 0.02890
# 334/334 [==============================] - 12s 37ms/step - loss: 0.0338 - accuracy: 0.9880 - val_loss: 0.1289 - val_accuracy: 0.9655
# Epoch 14/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0549 - accuracy: 0.9816
# Epoch 14: val_loss did not improve from 0.02890
# 334/334 [==============================] - 12s 35ms/step - loss: 0.0549 - accuracy: 0.9816 - val_loss: 0.1903 - val_accuracy: 0.9475
# Epoch 15/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0665 - accuracy: 0.9760
# Epoch 15: val_loss did not improve from 0.02890
# 334/334 [==============================] - 13s 39ms/step - loss: 0.0665 - accuracy: 0.9760 - val_loss: 0.1820 - val_accuracy: 0.9595
# Epoch 16/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0728 - accuracy: 0.9733
# Epoch 16: val_loss did not improve from 0.02890
# 334/334 [==============================] - 13s 39ms/step - loss: 0.0728 - accuracy: 0.9734 - val_loss: 0.1814 - val_accuracy: 0.9430
# Epoch 17/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0681 - accuracy: 0.9768
# Epoch 17: val_loss did not improve from 0.02890
# 334/334 [==============================] - 13s 39ms/step - loss: 0.0681 - accuracy: 0.9768 - val_loss: 0.1617 - val_accuracy: 0.9565
# Epoch 18/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0554 - accuracy: 0.9824
# Epoch 18: val_loss did not improve from 0.02890
# 334/334 [==============================] - 13s 40ms/step - loss: 0.0554 - accuracy: 0.9824 - val_loss: 0.1635 - val_accuracy: 0.9505
# Epoch 19/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0321 - accuracy: 0.9876
# Epoch 19: val_loss did not improve from 0.02890
# 334/334 [==============================] - 12s 35ms/step - loss: 0.0320 - accuracy: 0.9876 - val_loss: 0.1650 - val_accuracy: 0.9580
# Epoch 20/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0660 - accuracy: 0.9805
# Epoch 20: val_loss did not improve from 0.02890
# 334/334 [==============================] - 15s 44ms/step - loss: 0.0659 - accuracy: 0.9805 - val_loss: 0.2004 - val_accuracy: 0.9475
# Epoch 21/25
# 333/334 [============================>.] - ETA: 0s - loss: 0.0356 - accuracy: 0.9854
# Epoch 21: val_loss did not improve from 0.02890
# 334/334 [==============================] - 13s 39ms/step - loss: 0.0355 - accuracy: 0.9854 - val_loss: 0.1850 - val_accuracy: 0.9580
# Epoch 22/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0427 - accuracy: 0.9876
# Epoch 22: val_loss did not improve from 0.02890
# 334/334 [==============================] - 13s 39ms/step - loss: 0.0427 - accuracy: 0.9876 - val_loss: 0.1958 - val_accuracy: 0.9550
# Epoch 23/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0553 - accuracy: 0.9831
# Epoch 23: val_loss did not improve from 0.02890
# 334/334 [==============================] - 13s 40ms/step - loss: 0.0553 - accuracy: 0.9831 - val_loss: 0.2644 - val_accuracy: 0.9340
# Epoch 24/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0713 - accuracy: 0.9723
# Epoch 24: val_loss did not improve from 0.02890
# 334/334 [==============================] - 14s 41ms/step - loss: 0.0713 - accuracy: 0.9723 - val_loss: 0.1634 - val_accuracy: 0.9505
# Epoch 25/25
# 334/334 [==============================] - ETA: 0s - loss: 0.0395 - accuracy: 0.9831
# Epoch 25: val_loss did not improve from 0.02890
# 334/334 [==============================] - 14s 41ms/step - loss: 0.0395 - accuracy: 0.9831 - val_loss: 0.2552 - val_accuracy: 0.9490
# 21/21 [==============================] - 0s 8ms/step - loss: 0.2552 - accuracy: 0.9490
# Average loss: 0.4076141744852066
# Average accuracy: 0.8840352416038513

# %%
chrono_v1_model = load_model("/content/chrono_v1_checkpoint_4.h5")

# %%
metric(x_train,y_train,chrono_v1_model)
# Out:
# 79/79 [==============================] - 1s 7ms/step
# Accuracy: 0.9908946951702297
# Precision: 0.997624703087886
# F1-score: 0.9733487833140209
# ROC-curve: 0.9935866983372922
# Confusion matrix:

# %%
metric(x_test,y_test,chrono_v1_model)
# Out:
# 26/26 [==============================] - 0s 7ms/step
# Accuracy: 0.9864197530864197
# Precision: 0.9851851851851852
# F1-score: 0.9602888086642599
# ROC-curve: 0.9859259259259259
# Confusion matrix:

# %% [markdown]
# **V2**

# %%
import numpy as np
import tensorflow as tf
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, Flatten, Concatenate
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, Dropout, GRU, Dense, Reshape
from tensorflow.keras.models import Model

# %%
def ChronoNet(input_shape=(32, 32, 1)):
  # Input layer
  X_input = Input(input_shape)

  # Convolutional layer
  X = Conv2D(8, (32, 1), strides=(4, 1), padding='same', activation=None)(X_input)
  X = BatchNormalization()(X)
  X = Activation('relu')(X)
  X = MaxPooling2D((2, 1), strides=(2, 1), padding='same')(X)
  X = Dropout(0.5)(X)
  # Reshape output of Convolutional layer to (batch_size, timesteps, input_dim)
  X = Reshape((-1, X.shape[2] * X.shape[3]))(X)

  # Recurrent layer
  X = GRU(16, return_sequences=True)(X)
  X = Dropout(0.5)(X)
  X = GRU(16)(X)
  X = Dropout(0.5)(X)

  # Output layer
  X = Dense(1, activation='sigmoid')(X)

  # Create model
  model = Model(inputs=X_input, outputs=X)

  return model

# %%
chrono_v2_model = None
chrono_v2_model = ChronoNet(input_shape=(32, 32, 1))
K_Fold_Val("chrono_v2", chrono_v2_model, x, y, 20, 8, K=5)
# Out:
# Epoch 1/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.7086 - accuracy: 0.5370
# Epoch 1: val_loss improved from inf to 0.64350, saving model to chrono_v2_checkpoint_0.h5
# 334/334 [==============================] - 21s 19ms/step - loss: 0.7081 - accuracy: 0.5379 - val_loss: 0.6435 - val_accuracy: 0.6527
# Epoch 2/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.6704 - accuracy: 0.5762
# Epoch 2: val_loss did not improve from 0.64350
# 334/334 [==============================] - 5s 15ms/step - loss: 0.6701 - accuracy: 0.5761 - val_loss: 0.6736 - val_accuracy: 0.5838
# Epoch 3/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.6435 - accuracy: 0.6299
# Epoch 3: val_loss improved from 0.64350 to 0.60054, saving model to chrono_v2_checkpoint_0.h5
# 334/334 [==============================] - 4s 13ms/step - loss: 0.6418 - accuracy: 0.6304 - val_loss: 0.6005 - val_accuracy: 0.6647
# Epoch 4/20
# 334/334 [==============================] - ETA: 0s - loss: 0.6231 - accuracy: 0.6668
# Epoch 4: val_loss did not improve from 0.60054
# 334/334 [==============================] - 5s 16ms/step - loss: 0.6231 - accuracy: 0.6668 - val_loss: 0.6618 - val_accuracy: 0.6183
# Epoch 5/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.5994 - accuracy: 0.6766
# Epoch 5: val_loss improved from 0.60054 to 0.59599, saving model to chrono_v2_checkpoint_0.h5
# 334/334 [==============================] - 5s 15ms/step - loss: 0.5997 - accuracy: 0.6765 - val_loss: 0.5960 - val_accuracy: 0.6692
# Epoch 6/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.5811 - accuracy: 0.6811
# Epoch 6: val_loss improved from 0.59599 to 0.39354, saving model to chrono_v2_checkpoint_0.h5
# 334/334 [==============================] - 4s 13ms/step - loss: 0.5813 - accuracy: 0.6818 - val_loss: 0.3935 - val_accuracy: 0.8548
# Epoch 7/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.5683 - accuracy: 0.7258
# Epoch 7: val_loss did not improve from 0.39354
# 334/334 [==============================] - 5s 15ms/step - loss: 0.5684 - accuracy: 0.7256 - val_loss: 0.4812 - val_accuracy: 0.7665
# Epoch 8/20
# 334/334 [==============================] - ETA: 0s - loss: 0.5321 - accuracy: 0.7507
# Epoch 8: val_loss did not improve from 0.39354
# 334/334 [==============================] - 5s 16ms/step - loss: 0.5321 - accuracy: 0.7507 - val_loss: 0.5041 - val_accuracy: 0.7530
# Epoch 9/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.4948 - accuracy: 0.7712
# Epoch 9: val_loss did not improve from 0.39354
# 334/334 [==============================] - 5s 14ms/step - loss: 0.4947 - accuracy: 0.7714 - val_loss: 0.6995 - val_accuracy: 0.6647
# Epoch 10/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.4981 - accuracy: 0.7676
# Epoch 10: val_loss did not improve from 0.39354
# 334/334 [==============================] - 5s 16ms/step - loss: 0.4977 - accuracy: 0.7676 - val_loss: 0.4723 - val_accuracy: 0.7859
# Epoch 11/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.5053 - accuracy: 0.7647
# Epoch 11: val_loss improved from 0.39354 to 0.38388, saving model to chrono_v2_checkpoint_0.h5
# 334/334 [==============================] - 5s 15ms/step - loss: 0.5049 - accuracy: 0.7657 - val_loss: 0.3839 - val_accuracy: 0.8398
# Epoch 12/20
# 334/334 [==============================] - ETA: 0s - loss: 0.4750 - accuracy: 0.7856
# Epoch 12: val_loss improved from 0.38388 to 0.35134, saving model to chrono_v2_checkpoint_0.h5
# 334/334 [==============================] - 4s 13ms/step - loss: 0.4750 - accuracy: 0.7856 - val_loss: 0.3513 - val_accuracy: 0.8533
# Epoch 13/20
# 334/334 [==============================] - ETA: 0s - loss: 0.4664 - accuracy: 0.7867
# Epoch 13: val_loss improved from 0.35134 to 0.34777, saving model to chrono_v2_checkpoint_0.h5
# 334/334 [==============================] - 5s 16ms/step - loss: 0.4664 - accuracy: 0.7867 - val_loss: 0.3478 - val_accuracy: 0.8518
# Epoch 14/20
# 334/334 [==============================] - ETA: 0s - loss: 0.4470 - accuracy: 0.8137
# Epoch 14: val_loss improved from 0.34777 to 0.30991, saving model to chrono_v2_checkpoint_0.h5
# 334/334 [==============================] - 5s 15ms/step - loss: 0.4470 - accuracy: 0.8137 - val_loss: 0.3099 - val_accuracy: 0.8817
# Epoch 15/20
# 334/334 [==============================] - ETA: 0s - loss: 0.4272 - accuracy: 0.8182
# Epoch 15: val_loss did not improve from 0.30991
# 334/334 [==============================] - 5s 14ms/step - loss: 0.4272 - accuracy: 0.8182 - val_loss: 0.3963 - val_accuracy: 0.8144
# Epoch 16/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.4379 - accuracy: 0.8131
# Epoch 16: val_loss did not improve from 0.30991
# 334/334 [==============================] - 5s 16ms/step - loss: 0.4384 - accuracy: 0.8130 - val_loss: 0.3628 - val_accuracy: 0.8353
# Epoch 17/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.4269 - accuracy: 0.8142
# Epoch 17: val_loss improved from 0.30991 to 0.29493, saving model to chrono_v2_checkpoint_0.h5
# 334/334 [==============================] - 5s 16ms/step - loss: 0.4256 - accuracy: 0.8152 - val_loss: 0.2949 - val_accuracy: 0.8802
# Epoch 18/20
# 334/334 [==============================] - ETA: 0s - loss: 0.4489 - accuracy: 0.7999
# Epoch 18: val_loss did not improve from 0.29493
# 334/334 [==============================] - 5s 14ms/step - loss: 0.4489 - accuracy: 0.7999 - val_loss: 0.4444 - val_accuracy: 0.7964
# Epoch 19/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.4311 - accuracy: 0.8031
# Epoch 19: val_loss did not improve from 0.29493
# 334/334 [==============================] - 5s 16ms/step - loss: 0.4312 - accuracy: 0.8036 - val_loss: 0.4043 - val_accuracy: 0.8159
# Epoch 20/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.4160 - accuracy: 0.8140
# Epoch 20: val_loss did not improve from 0.29493
# 334/334 [==============================] - 5s 16ms/step - loss: 0.4163 - accuracy: 0.8137 - val_loss: 0.3917 - val_accuracy: 0.8189
# 21/21 [==============================] - 0s 9ms/step - loss: 0.3917 - accuracy: 0.8189
# Epoch 1/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.4177 - accuracy: 0.8309
# Epoch 1: val_loss improved from inf to 0.25768, saving model to chrono_v2_checkpoint_1.h5
# 334/334 [==============================] - 12s 21ms/step - loss: 0.4171 - accuracy: 0.8310 - val_loss: 0.2577 - val_accuracy: 0.9010
# Epoch 2/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.4152 - accuracy: 0.8273
# Epoch 2: val_loss improved from 0.25768 to 0.25388, saving model to chrono_v2_checkpoint_1.h5
# 334/334 [==============================] - 5s 15ms/step - loss: 0.4127 - accuracy: 0.8277 - val_loss: 0.2539 - val_accuracy: 0.8936
# Epoch 3/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.4051 - accuracy: 0.8276
# Epoch 3: val_loss did not improve from 0.25388
# 334/334 [==============================] - 4s 13ms/step - loss: 0.4039 - accuracy: 0.8280 - val_loss: 0.2616 - val_accuracy: 0.8891
# Epoch 4/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.4035 - accuracy: 0.8327
# Epoch 4: val_loss did not improve from 0.25388
# 334/334 [==============================] - 6s 18ms/step - loss: 0.4041 - accuracy: 0.8329 - val_loss: 0.2690 - val_accuracy: 0.8816
# Epoch 5/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.4128 - accuracy: 0.8187
# Epoch 5: val_loss did not improve from 0.25388
# 334/334 [==============================] - 5s 14ms/step - loss: 0.4124 - accuracy: 0.8190 - val_loss: 0.2826 - val_accuracy: 0.8771
# Epoch 6/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.3934 - accuracy: 0.8380
# Epoch 6: val_loss did not improve from 0.25388
# 334/334 [==============================] - 4s 13ms/step - loss: 0.3930 - accuracy: 0.8381 - val_loss: 0.3009 - val_accuracy: 0.8666
# Epoch 7/20
# 334/334 [==============================] - ETA: 0s - loss: 0.3650 - accuracy: 0.8434
# Epoch 7: val_loss improved from 0.25388 to 0.25140, saving model to chrono_v2_checkpoint_1.h5
# 334/334 [==============================] - 6s 19ms/step - loss: 0.3650 - accuracy: 0.8434 - val_loss: 0.2514 - val_accuracy: 0.8891
# Epoch 8/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.3654 - accuracy: 0.8421
# Epoch 8: val_loss improved from 0.25140 to 0.23161, saving model to chrono_v2_checkpoint_1.h5
# 334/334 [==============================] - 5s 14ms/step - loss: 0.3658 - accuracy: 0.8423 - val_loss: 0.2316 - val_accuracy: 0.9010
# Epoch 9/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.3565 - accuracy: 0.8539
# Epoch 9: val_loss did not improve from 0.23161
# 334/334 [==============================] - 5s 14ms/step - loss: 0.3570 - accuracy: 0.8524 - val_loss: 0.2448 - val_accuracy: 0.8921
# Epoch 10/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.3471 - accuracy: 0.8505
# Epoch 10: val_loss did not improve from 0.23161
# 334/334 [==============================] - 6s 18ms/step - loss: 0.3470 - accuracy: 0.8498 - val_loss: 0.2343 - val_accuracy: 0.8996
# Epoch 11/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.3587 - accuracy: 0.8475
# Epoch 11: val_loss did not improve from 0.23161
# 334/334 [==============================] - 5s 15ms/step - loss: 0.3586 - accuracy: 0.8479 - val_loss: 0.2903 - val_accuracy: 0.8591
# Epoch 12/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.3821 - accuracy: 0.8321
# Epoch 12: val_loss did not improve from 0.23161
# 334/334 [==============================] - 5s 14ms/step - loss: 0.3824 - accuracy: 0.8318 - val_loss: 0.3129 - val_accuracy: 0.8501
# Epoch 13/20
# 334/334 [==============================] - ETA: 0s - loss: 0.3555 - accuracy: 0.8445
# Epoch 13: val_loss did not improve from 0.23161
# 334/334 [==============================] - 6s 19ms/step - loss: 0.3555 - accuracy: 0.8445 - val_loss: 0.3234 - val_accuracy: 0.8666
# Epoch 14/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.3517 - accuracy: 0.8428
# Epoch 14: val_loss did not improve from 0.23161
# 334/334 [==============================] - 5s 14ms/step - loss: 0.3510 - accuracy: 0.8423 - val_loss: 0.2788 - val_accuracy: 0.8681
# Epoch 15/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.3257 - accuracy: 0.8562
# Epoch 15: val_loss did not improve from 0.23161
# 334/334 [==============================] - 5s 15ms/step - loss: 0.3270 - accuracy: 0.8561 - val_loss: 0.2671 - val_accuracy: 0.8771
# Epoch 16/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.3503 - accuracy: 0.8502
# Epoch 16: val_loss did not improve from 0.23161
# 334/334 [==============================] - 6s 18ms/step - loss: 0.3512 - accuracy: 0.8494 - val_loss: 0.3347 - val_accuracy: 0.8426
# Epoch 17/20
# 334/334 [==============================] - ETA: 0s - loss: 0.3254 - accuracy: 0.8677
# Epoch 17: val_loss did not improve from 0.23161
# 334/334 [==============================] - 4s 13ms/step - loss: 0.3254 - accuracy: 0.8677 - val_loss: 0.2676 - val_accuracy: 0.8711
# Epoch 18/20
# 334/334 [==============================] - ETA: 0s - loss: 0.3357 - accuracy: 0.8621
# Epoch 18: val_loss did not improve from 0.23161
# 334/334 [==============================] - 5s 16ms/step - loss: 0.3357 - accuracy: 0.8621 - val_loss: 0.3053 - val_accuracy: 0.8636
# Epoch 19/20
# 334/334 [==============================] - ETA: 0s - loss: 0.3310 - accuracy: 0.8591
# Epoch 19: val_loss did not improve from 0.23161
# 334/334 [==============================] - 6s 17ms/step - loss: 0.3310 - accuracy: 0.8591 - val_loss: 0.2519 - val_accuracy: 0.8921
# Epoch 20/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.3117 - accuracy: 0.8686
# Epoch 20: val_loss improved from 0.23161 to 0.21062, saving model to chrono_v2_checkpoint_1.h5
# 334/334 [==============================] - 5s 15ms/step - loss: 0.3115 - accuracy: 0.8689 - val_loss: 0.2106 - val_accuracy: 0.9145
# 21/21 [==============================] - 0s 9ms/step - loss: 0.2106 - accuracy: 0.9145
# Epoch 1/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.3754 - accuracy: 0.8557
# Epoch 1: val_loss improved from inf to 0.18183, saving model to chrono_v2_checkpoint_2.h5
# 334/334 [==============================] - 12s 17ms/step - loss: 0.3752 - accuracy: 0.8554 - val_loss: 0.1818 - val_accuracy: 0.9340
# Epoch 2/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.3239 - accuracy: 0.8652
# Epoch 2: val_loss did not improve from 0.18183
# 334/334 [==============================] - 4s 13ms/step - loss: 0.3248 - accuracy: 0.8651 - val_loss: 0.1897 - val_accuracy: 0.9295
# Epoch 3/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.3436 - accuracy: 0.8604
# Epoch 3: val_loss did not improve from 0.18183
# 334/334 [==============================] - 6s 18ms/step - loss: 0.3433 - accuracy: 0.8606 - val_loss: 0.2182 - val_accuracy: 0.9190
# Epoch 4/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.3267 - accuracy: 0.8626
# Epoch 4: val_loss improved from 0.18183 to 0.17978, saving model to chrono_v2_checkpoint_2.h5
# 334/334 [==============================] - 5s 15ms/step - loss: 0.3267 - accuracy: 0.8625 - val_loss: 0.1798 - val_accuracy: 0.9295
# Epoch 5/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.3149 - accuracy: 0.8739
# Epoch 5: val_loss improved from 0.17978 to 0.16098, saving model to chrono_v2_checkpoint_2.h5
# 334/334 [==============================] - 5s 15ms/step - loss: 0.3138 - accuracy: 0.8737 - val_loss: 0.1610 - val_accuracy: 0.9460
# Epoch 6/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.3094 - accuracy: 0.8727
# Epoch 6: val_loss did not improve from 0.16098
# 334/334 [==============================] - 6s 18ms/step - loss: 0.3093 - accuracy: 0.8719 - val_loss: 0.2224 - val_accuracy: 0.9175
# Epoch 7/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.3105 - accuracy: 0.8686
# Epoch 7: val_loss did not improve from 0.16098
# 334/334 [==============================] - 5s 14ms/step - loss: 0.3102 - accuracy: 0.8685 - val_loss: 0.2065 - val_accuracy: 0.9175
# Epoch 8/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.3048 - accuracy: 0.8784
# Epoch 8: val_loss did not improve from 0.16098
# 334/334 [==============================] - 5s 15ms/step - loss: 0.3038 - accuracy: 0.8786 - val_loss: 0.1882 - val_accuracy: 0.9310
# Epoch 9/20
# 334/334 [==============================] - ETA: 0s - loss: 0.3076 - accuracy: 0.8730
# Epoch 9: val_loss did not improve from 0.16098
# 334/334 [==============================] - 6s 17ms/step - loss: 0.3076 - accuracy: 0.8730 - val_loss: 0.2122 - val_accuracy: 0.9205
# Epoch 10/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.3037 - accuracy: 0.8799
# Epoch 10: val_loss did not improve from 0.16098
# 334/334 [==============================] - 5s 14ms/step - loss: 0.3035 - accuracy: 0.8790 - val_loss: 0.1963 - val_accuracy: 0.9280
# Epoch 11/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.3299 - accuracy: 0.8596
# Epoch 11: val_loss did not improve from 0.16098
# 334/334 [==============================] - 6s 18ms/step - loss: 0.3295 - accuracy: 0.8599 - val_loss: 0.2236 - val_accuracy: 0.9085
# Epoch 12/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2653 - accuracy: 0.8910
# Epoch 12: val_loss did not improve from 0.16098
# 334/334 [==============================] - 6s 19ms/step - loss: 0.2653 - accuracy: 0.8910 - val_loss: 0.2294 - val_accuracy: 0.9025
# Epoch 13/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2794 - accuracy: 0.8848
# Epoch 13: val_loss did not improve from 0.16098
# 334/334 [==============================] - 4s 13ms/step - loss: 0.2790 - accuracy: 0.8846 - val_loss: 0.1723 - val_accuracy: 0.9310
# Epoch 14/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2823 - accuracy: 0.8900
# Epoch 14: val_loss did not improve from 0.16098
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2822 - accuracy: 0.8902 - val_loss: 0.1998 - val_accuracy: 0.9115
# Epoch 15/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.2707 - accuracy: 0.8882
# Epoch 15: val_loss improved from 0.16098 to 0.16013, saving model to chrono_v2_checkpoint_2.h5
# 334/334 [==============================] - 6s 18ms/step - loss: 0.2748 - accuracy: 0.8876 - val_loss: 0.1601 - val_accuracy: 0.9370
# Epoch 16/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2910 - accuracy: 0.8835
# Epoch 16: val_loss did not improve from 0.16013
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2910 - accuracy: 0.8835 - val_loss: 0.2716 - val_accuracy: 0.8876
# Epoch 17/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.2820 - accuracy: 0.8769
# Epoch 17: val_loss did not improve from 0.16013
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2800 - accuracy: 0.8782 - val_loss: 0.1980 - val_accuracy: 0.9235
# Epoch 18/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.2927 - accuracy: 0.8765
# Epoch 18: val_loss did not improve from 0.16013
# 334/334 [==============================] - 6s 18ms/step - loss: 0.2920 - accuracy: 0.8767 - val_loss: 0.2111 - val_accuracy: 0.9145
# Epoch 19/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2581 - accuracy: 0.8962
# Epoch 19: val_loss did not improve from 0.16013
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2581 - accuracy: 0.8962 - val_loss: 0.2316 - val_accuracy: 0.8981
# Epoch 20/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.2932 - accuracy: 0.8792
# Epoch 20: val_loss did not improve from 0.16013
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2921 - accuracy: 0.8794 - val_loss: 0.1779 - val_accuracy: 0.9265
# 21/21 [==============================] - 0s 9ms/step - loss: 0.1779 - accuracy: 0.9265
# Epoch 1/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2980 - accuracy: 0.8822
# Epoch 1: val_loss improved from inf to 0.09780, saving model to chrono_v2_checkpoint_3.h5
# 334/334 [==============================] - 13s 20ms/step - loss: 0.2973 - accuracy: 0.8824 - val_loss: 0.0978 - val_accuracy: 0.9670
# Epoch 2/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2813 - accuracy: 0.8805
# Epoch 2: val_loss did not improve from 0.09780
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2813 - accuracy: 0.8805 - val_loss: 0.1117 - val_accuracy: 0.9535
# Epoch 3/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2995 - accuracy: 0.8831
# Epoch 3: val_loss did not improve from 0.09780
# 334/334 [==============================] - 6s 18ms/step - loss: 0.2995 - accuracy: 0.8831 - val_loss: 0.1466 - val_accuracy: 0.9430
# Epoch 4/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2808 - accuracy: 0.8854
# Epoch 4: val_loss did not improve from 0.09780
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2808 - accuracy: 0.8854 - val_loss: 0.1010 - val_accuracy: 0.9730
# Epoch 5/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2813 - accuracy: 0.8833
# Epoch 5: val_loss did not improve from 0.09780
# 334/334 [==============================] - 5s 16ms/step - loss: 0.2809 - accuracy: 0.8835 - val_loss: 0.1171 - val_accuracy: 0.9640
# Epoch 6/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2721 - accuracy: 0.8904
# Epoch 6: val_loss improved from 0.09780 to 0.09777, saving model to chrono_v2_checkpoint_3.h5
# 334/334 [==============================] - 5s 16ms/step - loss: 0.2717 - accuracy: 0.8906 - val_loss: 0.0978 - val_accuracy: 0.9670
# Epoch 7/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2505 - accuracy: 0.9009
# Epoch 7: val_loss did not improve from 0.09777
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2503 - accuracy: 0.9007 - val_loss: 0.1283 - val_accuracy: 0.9550
# Epoch 8/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2792 - accuracy: 0.8825
# Epoch 8: val_loss did not improve from 0.09777
# 334/334 [==============================] - 6s 17ms/step - loss: 0.2781 - accuracy: 0.8831 - val_loss: 0.1103 - val_accuracy: 0.9625
# Epoch 9/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2568 - accuracy: 0.8946
# Epoch 9: val_loss improved from 0.09777 to 0.09731, saving model to chrono_v2_checkpoint_3.h5
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2561 - accuracy: 0.8947 - val_loss: 0.0973 - val_accuracy: 0.9550
# Epoch 10/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.2701 - accuracy: 0.8939
# Epoch 10: val_loss did not improve from 0.09731
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2720 - accuracy: 0.8936 - val_loss: 0.1270 - val_accuracy: 0.9490
# Epoch 11/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2611 - accuracy: 0.8904
# Epoch 11: val_loss did not improve from 0.09731
# 334/334 [==============================] - 6s 18ms/step - loss: 0.2608 - accuracy: 0.8906 - val_loss: 0.1134 - val_accuracy: 0.9520
# Epoch 12/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2764 - accuracy: 0.8833
# Epoch 12: val_loss did not improve from 0.09731
# 334/334 [==============================] - 5s 16ms/step - loss: 0.2759 - accuracy: 0.8835 - val_loss: 0.1247 - val_accuracy: 0.9520
# Epoch 13/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2648 - accuracy: 0.8883
# Epoch 13: val_loss did not improve from 0.09731
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2648 - accuracy: 0.8883 - val_loss: 0.1238 - val_accuracy: 0.9445
# Epoch 14/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2500 - accuracy: 0.9086
# Epoch 14: val_loss did not improve from 0.09731
# 334/334 [==============================] - 6s 18ms/step - loss: 0.2500 - accuracy: 0.9086 - val_loss: 0.1580 - val_accuracy: 0.9340
# Epoch 15/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2366 - accuracy: 0.9048
# Epoch 15: val_loss did not improve from 0.09731
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2366 - accuracy: 0.9048 - val_loss: 0.1273 - val_accuracy: 0.9475
# Epoch 16/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2551 - accuracy: 0.9003
# Epoch 16: val_loss did not improve from 0.09731
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2551 - accuracy: 0.9003 - val_loss: 0.1398 - val_accuracy: 0.9325
# Epoch 17/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2516 - accuracy: 0.8968
# Epoch 17: val_loss did not improve from 0.09731
# 334/334 [==============================] - 6s 19ms/step - loss: 0.2509 - accuracy: 0.8973 - val_loss: 0.1559 - val_accuracy: 0.9415
# Epoch 18/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.2836 - accuracy: 0.8720
# Epoch 18: val_loss did not improve from 0.09731
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2826 - accuracy: 0.8719 - val_loss: 0.2349 - val_accuracy: 0.8981
# Epoch 19/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2426 - accuracy: 0.8968
# Epoch 19: val_loss did not improve from 0.09731
# 334/334 [==============================] - 7s 20ms/step - loss: 0.2422 - accuracy: 0.8966 - val_loss: 0.1572 - val_accuracy: 0.9325
# Epoch 20/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2557 - accuracy: 0.8870
# Epoch 20: val_loss did not improve from 0.09731
# 334/334 [==============================] - 6s 17ms/step - loss: 0.2556 - accuracy: 0.8872 - val_loss: 0.1930 - val_accuracy: 0.9205
# 21/21 [==============================] - 0s 9ms/step - loss: 0.1930 - accuracy: 0.9205
# Epoch 1/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2902 - accuracy: 0.8810
# Epoch 1: val_loss improved from inf to 0.09150, saving model to chrono_v2_checkpoint_4.h5
# 334/334 [==============================] - 12s 17ms/step - loss: 0.2905 - accuracy: 0.8805 - val_loss: 0.0915 - val_accuracy: 0.9745
# Epoch 2/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2655 - accuracy: 0.8983
# Epoch 2: val_loss did not improve from 0.09150
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2650 - accuracy: 0.8985 - val_loss: 0.1444 - val_accuracy: 0.9460
# Epoch 3/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2604 - accuracy: 0.8923
# Epoch 3: val_loss did not improve from 0.09150
# 334/334 [==============================] - 6s 18ms/step - loss: 0.2597 - accuracy: 0.8925 - val_loss: 0.0982 - val_accuracy: 0.9655
# Epoch 4/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2558 - accuracy: 0.8919
# Epoch 4: val_loss did not improve from 0.09150
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2555 - accuracy: 0.8921 - val_loss: 0.1282 - val_accuracy: 0.9535
# Epoch 5/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2367 - accuracy: 0.9017
# Epoch 5: val_loss did not improve from 0.09150
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2364 - accuracy: 0.9018 - val_loss: 0.1031 - val_accuracy: 0.9625
# Epoch 6/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2457 - accuracy: 0.8970
# Epoch 6: val_loss did not improve from 0.09150
# 334/334 [==============================] - 6s 18ms/step - loss: 0.2457 - accuracy: 0.8970 - val_loss: 0.1262 - val_accuracy: 0.9550
# Epoch 7/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2470 - accuracy: 0.8898
# Epoch 7: val_loss did not improve from 0.09150
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2470 - accuracy: 0.8898 - val_loss: 0.1153 - val_accuracy: 0.9565
# Epoch 8/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2323 - accuracy: 0.9029
# Epoch 8: val_loss did not improve from 0.09150
# 334/334 [==============================] - 5s 16ms/step - loss: 0.2322 - accuracy: 0.9030 - val_loss: 0.1115 - val_accuracy: 0.9550
# Epoch 9/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2331 - accuracy: 0.9043
# Epoch 9: val_loss did not improve from 0.09150
# 334/334 [==============================] - 6s 18ms/step - loss: 0.2338 - accuracy: 0.9041 - val_loss: 0.1769 - val_accuracy: 0.9250
# Epoch 10/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2326 - accuracy: 0.9089
# Epoch 10: val_loss did not improve from 0.09150
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2326 - accuracy: 0.9086 - val_loss: 0.1423 - val_accuracy: 0.9430
# Epoch 11/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2428 - accuracy: 0.9070
# Epoch 11: val_loss did not improve from 0.09150
# 334/334 [==============================] - 5s 16ms/step - loss: 0.2434 - accuracy: 0.9071 - val_loss: 0.1540 - val_accuracy: 0.9295
# Epoch 12/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2288 - accuracy: 0.9127
# Epoch 12: val_loss did not improve from 0.09150
# 334/334 [==============================] - 5s 16ms/step - loss: 0.2298 - accuracy: 0.9120 - val_loss: 0.1396 - val_accuracy: 0.9445
# Epoch 13/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2275 - accuracy: 0.9138
# Epoch 13: val_loss did not improve from 0.09150
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2275 - accuracy: 0.9138 - val_loss: 0.1759 - val_accuracy: 0.9265
# Epoch 14/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2111 - accuracy: 0.9153
# Epoch 14: val_loss did not improve from 0.09150
# 334/334 [==============================] - 6s 17ms/step - loss: 0.2109 - accuracy: 0.9149 - val_loss: 0.1390 - val_accuracy: 0.9490
# Epoch 15/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2154 - accuracy: 0.9078
# Epoch 15: val_loss did not improve from 0.09150
# 334/334 [==============================] - 5s 16ms/step - loss: 0.2154 - accuracy: 0.9078 - val_loss: 0.1468 - val_accuracy: 0.9415
# Epoch 16/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2390 - accuracy: 0.9025
# Epoch 16: val_loss did not improve from 0.09150
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2390 - accuracy: 0.9022 - val_loss: 0.1894 - val_accuracy: 0.9205
# Epoch 17/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2346 - accuracy: 0.9115
# Epoch 17: val_loss did not improve from 0.09150
# 334/334 [==============================] - 6s 17ms/step - loss: 0.2339 - accuracy: 0.9112 - val_loss: 0.1946 - val_accuracy: 0.9175
# Epoch 18/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2095 - accuracy: 0.9179
# Epoch 18: val_loss did not improve from 0.09150
# 334/334 [==============================] - 5s 16ms/step - loss: 0.2100 - accuracy: 0.9176 - val_loss: 0.1531 - val_accuracy: 0.9340
# Epoch 19/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.2091 - accuracy: 0.9165
# Epoch 19: val_loss did not improve from 0.09150
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2079 - accuracy: 0.9168 - val_loss: 0.1472 - val_accuracy: 0.9475
# Epoch 20/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2103 - accuracy: 0.9194
# Epoch 20: val_loss did not improve from 0.09150
# 334/334 [==============================] - 6s 18ms/step - loss: 0.2103 - accuracy: 0.9194 - val_loss: 0.1619 - val_accuracy: 0.9325
# 21/21 [==============================] - 0s 13ms/step - loss: 0.1619 - accuracy: 0.9325
# Average loss: 0.22703501880168914
# Average accuracy: 0.9026030421257019

# %%
chrono_v2_model = load_model("/content/chrono_v2_checkpoint_3.h5")

# %%
metric(x_train,y_train,chrono_v2_model)
# Out:
# 79/79 [==============================] - 3s 13ms/step
# Accuracy: 0.9699129057798892
# Precision: 0.9311163895486936
# F1-score: 0.9116279069767441
# ROC-curve: 0.9543942992874109
# Confusion matrix:

# %%
metric(x_test,y_test,chrono_v2_model)
# Out:
# 26/26 [==============================] - 0s 8ms/step
# Accuracy: 0.9851851851851852
# Precision: 0.9555555555555556
# F1-score: 0.9555555555555556
# ROC-curve: 0.9733333333333334
# Confusion matrix:

# %% [markdown]
# **V3**

# %%
def ChronoNet(input_shape=(32, None, 1)):
  # Input layer
  X_input = Input(input_shape)

  # Convolutional layer
  X = Conv2D(8, (32, 1), strides=(4, 1), padding='same', activation=None)(X_input)
  X = BatchNormalization()(X)
  X = Activation('relu')(X)
  X = MaxPooling2D((2, 1), strides=(2, 1), padding='same')(X)
  X = Dropout(0.5)(X)

  # Reshape to convert to 3D tensor
  X = Reshape((-1, X.shape[2]*X.shape[3]))(X)

  # Recurrent layer
  X = LSTM(16, return_sequences=True)(X)
  X = Dropout(0.5)(X)
  X = LSTM(16)(X)
  X = Dropout(0.5)(X)

  # Output layer
  X = Dense(1, activation='sigmoid')(X)

  # Create model
  model = Model(inputs=X_input, outputs=X)

  return model

# %%
chrono_v3_model = None
chrono_v3_model = ChronoNet(input_shape=(32, 32, 1))
K_Fold_Val("chrono_v3", chrono_v3_model, x, y, 20, 8, K=5) #32
# Out:
# Epoch 1/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.6918 - accuracy: 0.5693
# Epoch 1: val_loss improved from inf to 0.67366, saving model to chrono_v3_checkpoint_0.h5
# 334/334 [==============================] - 12s 17ms/step - loss: 0.6920 - accuracy: 0.5693 - val_loss: 0.6737 - val_accuracy: 0.5853
# Epoch 2/20
# 334/334 [==============================] - ETA: 0s - loss: 0.6449 - accuracy: 0.6600
# Epoch 2: val_loss did not improve from 0.67366
# 334/334 [==============================] - 5s 15ms/step - loss: 0.6449 - accuracy: 0.6600 - val_loss: 0.7427 - val_accuracy: 0.5509
# Epoch 3/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.6090 - accuracy: 0.6847
# Epoch 3: val_loss improved from 0.67366 to 0.48702, saving model to chrono_v3_checkpoint_0.h5
# 334/334 [==============================] - 6s 18ms/step - loss: 0.6103 - accuracy: 0.6833 - val_loss: 0.4870 - val_accuracy: 0.7889
# Epoch 4/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.5596 - accuracy: 0.7311
# Epoch 4: val_loss improved from 0.48702 to 0.44653, saving model to chrono_v3_checkpoint_0.h5
# 334/334 [==============================] - 5s 15ms/step - loss: 0.5594 - accuracy: 0.7305 - val_loss: 0.4465 - val_accuracy: 0.8039
# Epoch 5/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.5426 - accuracy: 0.7504
# Epoch 5: val_loss did not improve from 0.44653
# 334/334 [==============================] - 6s 17ms/step - loss: 0.5423 - accuracy: 0.7504 - val_loss: 0.4863 - val_accuracy: 0.7710
# Epoch 6/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.5112 - accuracy: 0.7791
# Epoch 6: val_loss improved from 0.44653 to 0.44372, saving model to chrono_v3_checkpoint_0.h5
# 334/334 [==============================] - 5s 16ms/step - loss: 0.5118 - accuracy: 0.7785 - val_loss: 0.4437 - val_accuracy: 0.8024
# Epoch 7/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.4799 - accuracy: 0.7898
# Epoch 7: val_loss improved from 0.44372 to 0.36740, saving model to chrono_v3_checkpoint_0.h5
# 334/334 [==============================] - 5s 15ms/step - loss: 0.4788 - accuracy: 0.7912 - val_loss: 0.3674 - val_accuracy: 0.8428
# Epoch 8/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.4977 - accuracy: 0.7789
# Epoch 8: val_loss did not improve from 0.36740
# 334/334 [==============================] - 6s 17ms/step - loss: 0.5001 - accuracy: 0.7777 - val_loss: 0.3735 - val_accuracy: 0.8608
# Epoch 9/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.4743 - accuracy: 0.7983
# Epoch 9: val_loss did not improve from 0.36740
# 334/334 [==============================] - 5s 14ms/step - loss: 0.4742 - accuracy: 0.7980 - val_loss: 0.4265 - val_accuracy: 0.8189
# Epoch 10/20
# 334/334 [==============================] - ETA: 0s - loss: 0.4759 - accuracy: 0.7691
# Epoch 10: val_loss did not improve from 0.36740
# 334/334 [==============================] - 5s 14ms/step - loss: 0.4759 - accuracy: 0.7691 - val_loss: 0.4256 - val_accuracy: 0.7844
# Epoch 11/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.4472 - accuracy: 0.8005
# Epoch 11: val_loss did not improve from 0.36740
# 334/334 [==============================] - 6s 18ms/step - loss: 0.4467 - accuracy: 0.8010 - val_loss: 0.5310 - val_accuracy: 0.7575
# Epoch 12/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.4301 - accuracy: 0.8078
# Epoch 12: val_loss improved from 0.36740 to 0.30907, saving model to chrono_v3_checkpoint_0.h5
# 334/334 [==============================] - 5s 15ms/step - loss: 0.4298 - accuracy: 0.8077 - val_loss: 0.3091 - val_accuracy: 0.8743
# Epoch 13/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.4449 - accuracy: 0.7922
# Epoch 13: val_loss did not improve from 0.30907
# 334/334 [==============================] - 5s 15ms/step - loss: 0.4439 - accuracy: 0.7927 - val_loss: 0.3930 - val_accuracy: 0.8278
# Epoch 14/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.4262 - accuracy: 0.7982
# Epoch 14: val_loss did not improve from 0.30907
# 334/334 [==============================] - 10s 30ms/step - loss: 0.4270 - accuracy: 0.7976 - val_loss: 0.4205 - val_accuracy: 0.7994
# Epoch 15/20
# 334/334 [==============================] - ETA: 0s - loss: 0.4130 - accuracy: 0.8231
# Epoch 15: val_loss did not improve from 0.30907
# 334/334 [==============================] - 5s 16ms/step - loss: 0.4130 - accuracy: 0.8231 - val_loss: 0.4042 - val_accuracy: 0.8174
# Epoch 16/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.4150 - accuracy: 0.8116
# Epoch 16: val_loss did not improve from 0.30907
# 334/334 [==============================] - 5s 14ms/step - loss: 0.4149 - accuracy: 0.8115 - val_loss: 0.3421 - val_accuracy: 0.8503
# Epoch 17/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.3893 - accuracy: 0.8319
# Epoch 17: val_loss did not improve from 0.30907
# 334/334 [==============================] - 6s 18ms/step - loss: 0.3897 - accuracy: 0.8321 - val_loss: 0.3178 - val_accuracy: 0.8668
# Epoch 18/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.4174 - accuracy: 0.8084
# Epoch 18: val_loss improved from 0.30907 to 0.29863, saving model to chrono_v3_checkpoint_0.h5
# 334/334 [==============================] - 4s 13ms/step - loss: 0.4171 - accuracy: 0.8088 - val_loss: 0.2986 - val_accuracy: 0.8832
# Epoch 19/20
# 334/334 [==============================] - ETA: 0s - loss: 0.3836 - accuracy: 0.8355
# Epoch 19: val_loss improved from 0.29863 to 0.29386, saving model to chrono_v3_checkpoint_0.h5
# 334/334 [==============================] - 5s 15ms/step - loss: 0.3836 - accuracy: 0.8355 - val_loss: 0.2939 - val_accuracy: 0.8877
# Epoch 20/20
# 334/334 [==============================] - ETA: 0s - loss: 0.3665 - accuracy: 0.8430
# Epoch 20: val_loss did not improve from 0.29386
# 334/334 [==============================] - 6s 17ms/step - loss: 0.3665 - accuracy: 0.8430 - val_loss: 0.3231 - val_accuracy: 0.8653
# 21/21 [==============================] - 0s 9ms/step - loss: 0.3231 - accuracy: 0.8653
# Epoch 1/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.3959 - accuracy: 0.8453
# Epoch 1: val_loss improved from inf to 0.20321, saving model to chrono_v3_checkpoint_1.h5
# 334/334 [==============================] - 12s 19ms/step - loss: 0.3954 - accuracy: 0.8456 - val_loss: 0.2032 - val_accuracy: 0.9280
# Epoch 2/20
# 334/334 [==============================] - ETA: 0s - loss: 0.3901 - accuracy: 0.8389
# Epoch 2: val_loss did not improve from 0.20321
# 334/334 [==============================] - 5s 14ms/step - loss: 0.3901 - accuracy: 0.8389 - val_loss: 0.3534 - val_accuracy: 0.8351
# Epoch 3/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.3813 - accuracy: 0.8327
# Epoch 3: val_loss did not improve from 0.20321
# 334/334 [==============================] - 6s 18ms/step - loss: 0.3815 - accuracy: 0.8321 - val_loss: 0.2684 - val_accuracy: 0.8891
# Epoch 4/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.3670 - accuracy: 0.8409
# Epoch 4: val_loss did not improve from 0.20321
# 334/334 [==============================] - 5s 14ms/step - loss: 0.3675 - accuracy: 0.8411 - val_loss: 0.2787 - val_accuracy: 0.8711
# Epoch 5/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.3568 - accuracy: 0.8437
# Epoch 5: val_loss did not improve from 0.20321
# 334/334 [==============================] - 4s 13ms/step - loss: 0.3569 - accuracy: 0.8438 - val_loss: 0.3149 - val_accuracy: 0.8426
# Epoch 6/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.3597 - accuracy: 0.8375
# Epoch 6: val_loss did not improve from 0.20321
# 334/334 [==============================] - 6s 18ms/step - loss: 0.3601 - accuracy: 0.8370 - val_loss: 0.2691 - val_accuracy: 0.8906
# Epoch 7/20
# 334/334 [==============================] - ETA: 0s - loss: 0.3488 - accuracy: 0.8426
# Epoch 7: val_loss did not improve from 0.20321
# 334/334 [==============================] - 4s 13ms/step - loss: 0.3488 - accuracy: 0.8426 - val_loss: 0.2329 - val_accuracy: 0.9100
# Epoch 8/20
# 334/334 [==============================] - ETA: 0s - loss: 0.3426 - accuracy: 0.8550
# Epoch 8: val_loss did not improve from 0.20321
# 334/334 [==============================] - 4s 13ms/step - loss: 0.3426 - accuracy: 0.8550 - val_loss: 0.2524 - val_accuracy: 0.8891
# Epoch 9/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.3266 - accuracy: 0.8426
# Epoch 9: val_loss did not improve from 0.20321
# 334/334 [==============================] - 6s 18ms/step - loss: 0.3258 - accuracy: 0.8430 - val_loss: 0.2350 - val_accuracy: 0.8786
# Epoch 10/20
# 334/334 [==============================] - ETA: 0s - loss: 0.3348 - accuracy: 0.8498
# Epoch 10: val_loss did not improve from 0.20321
# 334/334 [==============================] - 5s 15ms/step - loss: 0.3348 - accuracy: 0.8498 - val_loss: 0.3165 - val_accuracy: 0.8441
# Epoch 11/20
# 334/334 [==============================] - ETA: 0s - loss: 0.3327 - accuracy: 0.8494
# Epoch 11: val_loss did not improve from 0.20321
# 334/334 [==============================] - 4s 13ms/step - loss: 0.3327 - accuracy: 0.8494 - val_loss: 0.2081 - val_accuracy: 0.9130
# Epoch 12/20
# 334/334 [==============================] - ETA: 0s - loss: 0.3188 - accuracy: 0.8513
# Epoch 12: val_loss did not improve from 0.20321
# 334/334 [==============================] - 6s 18ms/step - loss: 0.3188 - accuracy: 0.8513 - val_loss: 0.2165 - val_accuracy: 0.9010
# Epoch 13/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.3112 - accuracy: 0.8553
# Epoch 13: val_loss did not improve from 0.20321
# 334/334 [==============================] - 5s 14ms/step - loss: 0.3096 - accuracy: 0.8561 - val_loss: 0.2961 - val_accuracy: 0.8636
# Epoch 14/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.3200 - accuracy: 0.8595
# Epoch 14: val_loss did not improve from 0.20321
# 334/334 [==============================] - 5s 14ms/step - loss: 0.3221 - accuracy: 0.8580 - val_loss: 0.3388 - val_accuracy: 0.8516
# Epoch 15/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.2879 - accuracy: 0.8674
# Epoch 15: val_loss did not improve from 0.20321
# 334/334 [==============================] - 6s 19ms/step - loss: 0.2883 - accuracy: 0.8670 - val_loss: 0.2615 - val_accuracy: 0.8951
# Epoch 16/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.3069 - accuracy: 0.8659
# Epoch 16: val_loss did not improve from 0.20321
# 334/334 [==============================] - 4s 13ms/step - loss: 0.3092 - accuracy: 0.8655 - val_loss: 0.2314 - val_accuracy: 0.9025
# Epoch 17/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.3055 - accuracy: 0.8622
# Epoch 17: val_loss improved from 0.20321 to 0.19261, saving model to chrono_v3_checkpoint_1.h5
# 334/334 [==============================] - 5s 14ms/step - loss: 0.3051 - accuracy: 0.8621 - val_loss: 0.1926 - val_accuracy: 0.9220
# Epoch 18/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.3050 - accuracy: 0.8670
# Epoch 18: val_loss did not improve from 0.19261
# 334/334 [==============================] - 6s 18ms/step - loss: 0.3076 - accuracy: 0.8666 - val_loss: 0.2246 - val_accuracy: 0.9040
# Epoch 19/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.2723 - accuracy: 0.8826
# Epoch 19: val_loss did not improve from 0.19261
# 334/334 [==============================] - 4s 13ms/step - loss: 0.2708 - accuracy: 0.8827 - val_loss: 0.1966 - val_accuracy: 0.9205
# Epoch 20/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2806 - accuracy: 0.8686
# Epoch 20: val_loss did not improve from 0.19261
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2800 - accuracy: 0.8685 - val_loss: 0.2355 - val_accuracy: 0.8861
# 21/21 [==============================] - 0s 13ms/step - loss: 0.2355 - accuracy: 0.8861
# Epoch 1/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.3350 - accuracy: 0.8701
# Epoch 1: val_loss improved from inf to 0.19731, saving model to chrono_v3_checkpoint_2.h5
# 334/334 [==============================] - 15s 20ms/step - loss: 0.3339 - accuracy: 0.8707 - val_loss: 0.1973 - val_accuracy: 0.9175
# Epoch 2/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2891 - accuracy: 0.8784
# Epoch 2: val_loss did not improve from 0.19731
# 334/334 [==============================] - 6s 17ms/step - loss: 0.2902 - accuracy: 0.8775 - val_loss: 0.2556 - val_accuracy: 0.8981
# Epoch 3/20
# 334/334 [==============================] - ETA: 0s - loss: 0.3176 - accuracy: 0.8670
# Epoch 3: val_loss improved from 0.19731 to 0.19302, saving model to chrono_v3_checkpoint_2.h5
# 334/334 [==============================] - 4s 13ms/step - loss: 0.3176 - accuracy: 0.8670 - val_loss: 0.1930 - val_accuracy: 0.9340
# Epoch 4/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2848 - accuracy: 0.8848
# Epoch 4: val_loss did not improve from 0.19302
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2849 - accuracy: 0.8842 - val_loss: 0.2055 - val_accuracy: 0.9265
# Epoch 5/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.2743 - accuracy: 0.8897
# Epoch 5: val_loss did not improve from 0.19302
# 334/334 [==============================] - 5s 16ms/step - loss: 0.2740 - accuracy: 0.8891 - val_loss: 0.2960 - val_accuracy: 0.8651
# Epoch 6/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2730 - accuracy: 0.8836
# Epoch 6: val_loss did not improve from 0.19302
# 334/334 [==============================] - 4s 13ms/step - loss: 0.2735 - accuracy: 0.8835 - val_loss: 0.2239 - val_accuracy: 0.9040
# Epoch 7/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2712 - accuracy: 0.8844
# Epoch 7: val_loss improved from 0.19302 to 0.18526, saving model to chrono_v3_checkpoint_2.h5
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2732 - accuracy: 0.8842 - val_loss: 0.1853 - val_accuracy: 0.9280
# Epoch 8/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.2749 - accuracy: 0.8720
# Epoch 8: val_loss did not improve from 0.18526
# 334/334 [==============================] - 6s 17ms/step - loss: 0.2769 - accuracy: 0.8715 - val_loss: 0.2019 - val_accuracy: 0.9085
# Epoch 9/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2773 - accuracy: 0.8758
# Epoch 9: val_loss did not improve from 0.18526
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2767 - accuracy: 0.8760 - val_loss: 0.2119 - val_accuracy: 0.9070
# Epoch 10/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2617 - accuracy: 0.8816
# Epoch 10: val_loss did not improve from 0.18526
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2617 - accuracy: 0.8816 - val_loss: 0.1967 - val_accuracy: 0.9235
# Epoch 11/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2412 - accuracy: 0.8994
# Epoch 11: val_loss improved from 0.18526 to 0.18294, saving model to chrono_v3_checkpoint_2.h5
# 334/334 [==============================] - 6s 17ms/step - loss: 0.2408 - accuracy: 0.8996 - val_loss: 0.1829 - val_accuracy: 0.9175
# Epoch 12/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.2416 - accuracy: 0.8988
# Epoch 12: val_loss did not improve from 0.18294
# 334/334 [==============================] - 4s 13ms/step - loss: 0.2423 - accuracy: 0.8988 - val_loss: 0.2158 - val_accuracy: 0.9160
# Epoch 13/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2560 - accuracy: 0.8868
# Epoch 13: val_loss did not improve from 0.18294
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2560 - accuracy: 0.8868 - val_loss: 0.1963 - val_accuracy: 0.9025
# Epoch 14/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.2458 - accuracy: 0.8943
# Epoch 14: val_loss did not improve from 0.18294
# 334/334 [==============================] - 5s 16ms/step - loss: 0.2446 - accuracy: 0.8947 - val_loss: 0.2051 - val_accuracy: 0.9115
# Epoch 15/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2351 - accuracy: 0.8972
# Epoch 15: val_loss did not improve from 0.18294
# 334/334 [==============================] - 4s 13ms/step - loss: 0.2345 - accuracy: 0.8977 - val_loss: 0.1916 - val_accuracy: 0.9160
# Epoch 16/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2403 - accuracy: 0.9030
# Epoch 16: val_loss did not improve from 0.18294
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2403 - accuracy: 0.9030 - val_loss: 0.1857 - val_accuracy: 0.9295
# Epoch 17/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2496 - accuracy: 0.8977
# Epoch 17: val_loss improved from 0.18294 to 0.18178, saving model to chrono_v3_checkpoint_2.h5
# 334/334 [==============================] - 6s 17ms/step - loss: 0.2496 - accuracy: 0.8977 - val_loss: 0.1818 - val_accuracy: 0.9205
# Epoch 18/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.2349 - accuracy: 0.8992
# Epoch 18: val_loss did not improve from 0.18178
# 334/334 [==============================] - 4s 13ms/step - loss: 0.2351 - accuracy: 0.8988 - val_loss: 0.2140 - val_accuracy: 0.9100
# Epoch 19/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2270 - accuracy: 0.9005
# Epoch 19: val_loss did not improve from 0.18178
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2269 - accuracy: 0.9003 - val_loss: 0.2420 - val_accuracy: 0.9010
# Epoch 20/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2349 - accuracy: 0.8927
# Epoch 20: val_loss improved from 0.18178 to 0.17532, saving model to chrono_v3_checkpoint_2.h5
# 334/334 [==============================] - 6s 17ms/step - loss: 0.2360 - accuracy: 0.8925 - val_loss: 0.1753 - val_accuracy: 0.9250
# 21/21 [==============================] - 0s 8ms/step - loss: 0.1753 - accuracy: 0.9250
# Epoch 1/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2858 - accuracy: 0.8925
# Epoch 1: val_loss improved from inf to 0.10835, saving model to chrono_v3_checkpoint_3.h5
# 334/334 [==============================] - 12s 21ms/step - loss: 0.2858 - accuracy: 0.8925 - val_loss: 0.1084 - val_accuracy: 0.9535
# Epoch 2/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2383 - accuracy: 0.8980
# Epoch 2: val_loss improved from 0.10835 to 0.10386, saving model to chrono_v3_checkpoint_3.h5
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2417 - accuracy: 0.8981 - val_loss: 0.1039 - val_accuracy: 0.9520
# Epoch 3/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2676 - accuracy: 0.8868
# Epoch 3: val_loss did not improve from 0.10386
# 334/334 [==============================] - 4s 13ms/step - loss: 0.2676 - accuracy: 0.8868 - val_loss: 0.1598 - val_accuracy: 0.9310
# Epoch 4/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2662 - accuracy: 0.8915
# Epoch 4: val_loss did not improve from 0.10386
# 334/334 [==============================] - 5s 16ms/step - loss: 0.2666 - accuracy: 0.8913 - val_loss: 0.1631 - val_accuracy: 0.9265
# Epoch 5/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2332 - accuracy: 0.8945
# Epoch 5: val_loss improved from 0.10386 to 0.08688, saving model to chrono_v3_checkpoint_3.h5
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2327 - accuracy: 0.8947 - val_loss: 0.0869 - val_accuracy: 0.9655
# Epoch 6/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.2432 - accuracy: 0.8955
# Epoch 6: val_loss did not improve from 0.08688
# 334/334 [==============================] - 4s 13ms/step - loss: 0.2420 - accuracy: 0.8958 - val_loss: 0.1167 - val_accuracy: 0.9535
# Epoch 7/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2641 - accuracy: 0.8831
# Epoch 7: val_loss did not improve from 0.08688
# 334/334 [==============================] - 6s 17ms/step - loss: 0.2641 - accuracy: 0.8831 - val_loss: 0.1899 - val_accuracy: 0.9010
# Epoch 8/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2480 - accuracy: 0.8930
# Epoch 8: val_loss did not improve from 0.08688
# 334/334 [==============================] - 7s 20ms/step - loss: 0.2484 - accuracy: 0.8928 - val_loss: 0.1717 - val_accuracy: 0.9340
# Epoch 9/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.2586 - accuracy: 0.8856
# Epoch 9: val_loss did not improve from 0.08688
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2577 - accuracy: 0.8857 - val_loss: 0.1317 - val_accuracy: 0.9430
# Epoch 10/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.2367 - accuracy: 0.8958
# Epoch 10: val_loss did not improve from 0.08688
# 334/334 [==============================] - 5s 16ms/step - loss: 0.2357 - accuracy: 0.8966 - val_loss: 0.1205 - val_accuracy: 0.9490
# Epoch 11/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2226 - accuracy: 0.9047
# Epoch 11: val_loss did not improve from 0.08688
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2227 - accuracy: 0.9045 - val_loss: 0.1410 - val_accuracy: 0.9430
# Epoch 12/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.2245 - accuracy: 0.9033
# Epoch 12: val_loss did not improve from 0.08688
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2235 - accuracy: 0.9037 - val_loss: 0.1135 - val_accuracy: 0.9535
# Epoch 13/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2424 - accuracy: 0.9095
# Epoch 13: val_loss did not improve from 0.08688
# 334/334 [==============================] - 6s 17ms/step - loss: 0.2421 - accuracy: 0.9097 - val_loss: 0.1249 - val_accuracy: 0.9445
# Epoch 14/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.2345 - accuracy: 0.9034
# Epoch 14: val_loss did not improve from 0.08688
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2346 - accuracy: 0.9033 - val_loss: 0.1352 - val_accuracy: 0.9385
# Epoch 15/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2235 - accuracy: 0.9095
# Epoch 15: val_loss did not improve from 0.08688
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2234 - accuracy: 0.9093 - val_loss: 0.1565 - val_accuracy: 0.9340
# Epoch 16/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.1942 - accuracy: 0.9140
# Epoch 16: val_loss did not improve from 0.08688
# 334/334 [==============================] - 5s 16ms/step - loss: 0.1948 - accuracy: 0.9135 - val_loss: 0.1804 - val_accuracy: 0.9325
# Epoch 17/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.1972 - accuracy: 0.9211
# Epoch 17: val_loss did not improve from 0.08688
# 334/334 [==============================] - 5s 16ms/step - loss: 0.1995 - accuracy: 0.9206 - val_loss: 0.1204 - val_accuracy: 0.9445
# Epoch 18/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.2119 - accuracy: 0.9124
# Epoch 18: val_loss did not improve from 0.08688
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2114 - accuracy: 0.9120 - val_loss: 0.1503 - val_accuracy: 0.9340
# Epoch 19/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2165 - accuracy: 0.9148
# Epoch 19: val_loss did not improve from 0.08688
# 334/334 [==============================] - 6s 17ms/step - loss: 0.2164 - accuracy: 0.9149 - val_loss: 0.1273 - val_accuracy: 0.9445
# Epoch 20/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2017 - accuracy: 0.9127
# Epoch 20: val_loss did not improve from 0.08688
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2017 - accuracy: 0.9127 - val_loss: 0.1171 - val_accuracy: 0.9505
# 21/21 [==============================] - 0s 10ms/step - loss: 0.1171 - accuracy: 0.9505
# Epoch 1/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2795 - accuracy: 0.8925
# Epoch 1: val_loss improved from inf to 0.07450, saving model to chrono_v3_checkpoint_4.h5
# 334/334 [==============================] - 12s 20ms/step - loss: 0.2795 - accuracy: 0.8925 - val_loss: 0.0745 - val_accuracy: 0.9700
# Epoch 2/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.2225 - accuracy: 0.9090
# Epoch 2: val_loss did not improve from 0.07450
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2218 - accuracy: 0.9090 - val_loss: 0.0774 - val_accuracy: 0.9685
# Epoch 3/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.2250 - accuracy: 0.9162
# Epoch 3: val_loss did not improve from 0.07450
# 334/334 [==============================] - 4s 13ms/step - loss: 0.2251 - accuracy: 0.9157 - val_loss: 0.1114 - val_accuracy: 0.9535
# Epoch 4/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9149
# Epoch 4: val_loss did not improve from 0.07450
# 334/334 [==============================] - 6s 17ms/step - loss: 0.2019 - accuracy: 0.9146 - val_loss: 0.1068 - val_accuracy: 0.9625
# Epoch 5/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2195 - accuracy: 0.9168
# Epoch 5: val_loss did not improve from 0.07450
# 334/334 [==============================] - 4s 13ms/step - loss: 0.2195 - accuracy: 0.9168 - val_loss: 0.1061 - val_accuracy: 0.9610
# Epoch 6/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2208 - accuracy: 0.9024
# Epoch 6: val_loss did not improve from 0.07450
# 334/334 [==============================] - 5s 14ms/step - loss: 0.2212 - accuracy: 0.9018 - val_loss: 0.1473 - val_accuracy: 0.9385
# Epoch 7/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.1981 - accuracy: 0.9170
# Epoch 7: val_loss did not improve from 0.07450
# 334/334 [==============================] - 6s 17ms/step - loss: 0.1977 - accuracy: 0.9172 - val_loss: 0.1002 - val_accuracy: 0.9565
# Epoch 8/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.1992 - accuracy: 0.9175
# Epoch 8: val_loss did not improve from 0.07450
# 334/334 [==============================] - 5s 14ms/step - loss: 0.1996 - accuracy: 0.9176 - val_loss: 0.1274 - val_accuracy: 0.9520
# Epoch 9/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.1951 - accuracy: 0.9209
# Epoch 9: val_loss did not improve from 0.07450
# 334/334 [==============================] - 4s 13ms/step - loss: 0.1947 - accuracy: 0.9209 - val_loss: 0.1402 - val_accuracy: 0.9415
# Epoch 10/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2102 - accuracy: 0.9175
# Epoch 10: val_loss did not improve from 0.07450
# 334/334 [==============================] - 6s 17ms/step - loss: 0.2095 - accuracy: 0.9179 - val_loss: 0.1720 - val_accuracy: 0.9280
# Epoch 11/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.1928 - accuracy: 0.9168
# Epoch 11: val_loss did not improve from 0.07450
# 334/334 [==============================] - 5s 15ms/step - loss: 0.1921 - accuracy: 0.9172 - val_loss: 0.1230 - val_accuracy: 0.9460
# Epoch 12/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.1889 - accuracy: 0.9194
# Epoch 12: val_loss did not improve from 0.07450
# 334/334 [==============================] - 5s 14ms/step - loss: 0.1886 - accuracy: 0.9194 - val_loss: 0.2015 - val_accuracy: 0.9175
# Epoch 13/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.1769 - accuracy: 0.9206
# Epoch 13: val_loss did not improve from 0.07450
# 334/334 [==============================] - 6s 17ms/step - loss: 0.1782 - accuracy: 0.9202 - val_loss: 0.1364 - val_accuracy: 0.9445
# Epoch 14/20
# 334/334 [==============================] - ETA: 0s - loss: 0.1945 - accuracy: 0.9232
# Epoch 14: val_loss did not improve from 0.07450
# 334/334 [==============================] - 5s 14ms/step - loss: 0.1945 - accuracy: 0.9232 - val_loss: 0.1310 - val_accuracy: 0.9430
# Epoch 15/20
# 334/334 [==============================] - ETA: 0s - loss: 0.1749 - accuracy: 0.9356
# Epoch 15: val_loss did not improve from 0.07450
# 334/334 [==============================] - 4s 13ms/step - loss: 0.1749 - accuracy: 0.9356 - val_loss: 0.1659 - val_accuracy: 0.9280
# Epoch 16/20
# 334/334 [==============================] - ETA: 0s - loss: 0.1762 - accuracy: 0.9299
# Epoch 16: val_loss did not improve from 0.07450
# 334/334 [==============================] - 5s 16ms/step - loss: 0.1762 - accuracy: 0.9299 - val_loss: 0.1578 - val_accuracy: 0.9385
# Epoch 17/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.2183 - accuracy: 0.9129
# Epoch 17: val_loss did not improve from 0.07450
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2191 - accuracy: 0.9127 - val_loss: 0.1794 - val_accuracy: 0.9205
# Epoch 18/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.2050 - accuracy: 0.9082
# Epoch 18: val_loss did not improve from 0.07450
# 334/334 [==============================] - 4s 13ms/step - loss: 0.2044 - accuracy: 0.9090 - val_loss: 0.1621 - val_accuracy: 0.9295
# Epoch 19/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2045 - accuracy: 0.9175
# Epoch 19: val_loss did not improve from 0.07450
# 334/334 [==============================] - 5s 16ms/step - loss: 0.2038 - accuracy: 0.9179 - val_loss: 0.1214 - val_accuracy: 0.9520
# Epoch 20/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.1770 - accuracy: 0.9317
# Epoch 20: val_loss did not improve from 0.07450
# 334/334 [==============================] - 5s 16ms/step - loss: 0.1768 - accuracy: 0.9318 - val_loss: 0.1419 - val_accuracy: 0.9460
# 21/21 [==============================] - 0s 9ms/step - loss: 0.1419 - accuracy: 0.9460
# Average loss: 0.19857859313488008
# Average accuracy: 0.9145831346511841

# %%
chrono_v3_model = load_model("/content/chrono_v3_checkpoint_4.h5")

# %%
metric(x_train,y_train,chrono_v3_model)
# Out:
# 79/79 [==============================] - 3s 8ms/step
# Accuracy: 0.9647664291369754
# Precision: 0.9833729216152018
# F1-score: 0.9029443838604144
# ROC-curve: 0.972209026128266
# Confusion matrix:

# %%
metric(x_test,y_test,chrono_v3_model)
# Out:
# 26/26 [==============================] - 0s 9ms/step
# Accuracy: 0.9666666666666667
# Precision: 0.9925925925925926
# F1-score: 0.9084745762711864
# ROC-curve: 0.9770370370370369
# Confusion matrix:

# %% [markdown]
# # **DRCNN**

# %%
#Deep recurrent conv NN
def DRCNN(num_samples=64,num_channels=32,time_steps = 32):

    model = Sequential()
    model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(time_steps, num_channels)))
    model.add(BatchNormalization())
    model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=1))
    model.add(LSTM(64, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(128))
    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))

    return model

# %%
DRCNN_model = None
DRCNN_model = DRCNN(time_steps=32)
K_Fold_Val("DRCNN", DRCNN_model, x, y, 20, 8, K=5) #16
# Out:
# Epoch 1/20
# 334/334 [==============================] - ETA: 0s - loss: 0.6813 - accuracy: 0.6694
# Epoch 1: val_loss improved from inf to 0.64297, saving model to DRCNN_checkpoint_0.h5
# 334/334 [==============================] - 19s 23ms/step - loss: 0.6813 - accuracy: 0.6694 - val_loss: 0.6430 - val_accuracy: 0.6138
# Epoch 2/20
# 334/334 [==============================] - ETA: 0s - loss: 0.5797 - accuracy: 0.7256
# Epoch 2: val_loss improved from 0.64297 to 0.48253, saving model to DRCNN_checkpoint_0.h5
# 334/334 [==============================] - 5s 15ms/step - loss: 0.5797 - accuracy: 0.7256 - val_loss: 0.4825 - val_accuracy: 0.7515
# Epoch 3/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.4922 - accuracy: 0.8078
# Epoch 3: val_loss did not improve from 0.48253
# 334/334 [==============================] - 7s 20ms/step - loss: 0.4945 - accuracy: 0.8077 - val_loss: 0.5043 - val_accuracy: 0.7994
# Epoch 4/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.4336 - accuracy: 0.8257
# Epoch 4: val_loss improved from 0.48253 to 0.47143, saving model to DRCNN_checkpoint_0.h5
# 334/334 [==============================] - 5s 15ms/step - loss: 0.4325 - accuracy: 0.8261 - val_loss: 0.4714 - val_accuracy: 0.8159
# Epoch 5/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.3643 - accuracy: 0.8622
# Epoch 5: val_loss improved from 0.47143 to 0.45123, saving model to DRCNN_checkpoint_0.h5
# 334/334 [==============================] - 6s 17ms/step - loss: 0.3639 - accuracy: 0.8624 - val_loss: 0.4512 - val_accuracy: 0.7904
# Epoch 6/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.3153 - accuracy: 0.8822
# Epoch 6: val_loss improved from 0.45123 to 0.36747, saving model to DRCNN_checkpoint_0.h5
# 334/334 [==============================] - 6s 19ms/step - loss: 0.3158 - accuracy: 0.8827 - val_loss: 0.3675 - val_accuracy: 0.8413
# Epoch 7/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2755 - accuracy: 0.8941
# Epoch 7: val_loss improved from 0.36747 to 0.34916, saving model to DRCNN_checkpoint_0.h5
# 334/334 [==============================] - 5s 15ms/step - loss: 0.2753 - accuracy: 0.8943 - val_loss: 0.3492 - val_accuracy: 0.8772
# Epoch 8/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.2511 - accuracy: 0.9155
# Epoch 8: val_loss improved from 0.34916 to 0.30672, saving model to DRCNN_checkpoint_0.h5
# 334/334 [==============================] - 7s 20ms/step - loss: 0.2509 - accuracy: 0.9157 - val_loss: 0.3067 - val_accuracy: 0.8847
# Epoch 9/20
# 334/334 [==============================] - ETA: 0s - loss: 0.1841 - accuracy: 0.9307
# Epoch 9: val_loss did not improve from 0.30672
# 334/334 [==============================] - 5s 15ms/step - loss: 0.1841 - accuracy: 0.9307 - val_loss: 0.3558 - val_accuracy: 0.8772
# Epoch 10/20
# 334/334 [==============================] - ETA: 0s - loss: 0.1830 - accuracy: 0.9202
# Epoch 10: val_loss did not improve from 0.30672
# 334/334 [==============================] - 5s 14ms/step - loss: 0.1830 - accuracy: 0.9202 - val_loss: 0.3392 - val_accuracy: 0.8668
# Epoch 11/20
# 334/334 [==============================] - ETA: 0s - loss: 0.1778 - accuracy: 0.9423
# Epoch 11: val_loss did not improve from 0.30672
# 334/334 [==============================] - 7s 20ms/step - loss: 0.1778 - accuracy: 0.9423 - val_loss: 0.3296 - val_accuracy: 0.8772
# Epoch 12/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.1545 - accuracy: 0.9369
# Epoch 12: val_loss did not improve from 0.30672
# 334/334 [==============================] - 7s 20ms/step - loss: 0.1545 - accuracy: 0.9367 - val_loss: 0.3595 - val_accuracy: 0.8533
# Epoch 13/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.2107 - accuracy: 0.9138
# Epoch 13: val_loss did not improve from 0.30672
# 334/334 [==============================] - 6s 19ms/step - loss: 0.2111 - accuracy: 0.9130 - val_loss: 0.4539 - val_accuracy: 0.8293
# Epoch 14/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.1416 - accuracy: 0.9466
# Epoch 14: val_loss did not improve from 0.30672
# 334/334 [==============================] - 5s 15ms/step - loss: 0.1440 - accuracy: 0.9460 - val_loss: 0.4635 - val_accuracy: 0.8488
# Epoch 15/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.1675 - accuracy: 0.9309
# Epoch 15: val_loss did not improve from 0.30672
# 334/334 [==============================] - 5s 14ms/step - loss: 0.1678 - accuracy: 0.9303 - val_loss: 0.4690 - val_accuracy: 0.8653
# Epoch 16/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.1119 - accuracy: 0.9573
# Epoch 16: val_loss did not improve from 0.30672
# 334/334 [==============================] - 7s 20ms/step - loss: 0.1125 - accuracy: 0.9565 - val_loss: 0.4397 - val_accuracy: 0.8728
# Epoch 17/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.1214 - accuracy: 0.9559
# Epoch 17: val_loss did not improve from 0.30672
# 334/334 [==============================] - 5s 15ms/step - loss: 0.1216 - accuracy: 0.9558 - val_loss: 0.4482 - val_accuracy: 0.8503
# Epoch 18/20
# 334/334 [==============================] - ETA: 0s - loss: 0.1243 - accuracy: 0.9475
# Epoch 18: val_loss did not improve from 0.30672
# 334/334 [==============================] - 5s 15ms/step - loss: 0.1243 - accuracy: 0.9475 - val_loss: 0.4437 - val_accuracy: 0.8383
# Epoch 19/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.0757 - accuracy: 0.9756
# Epoch 19: val_loss did not improve from 0.30672
# 334/334 [==============================] - 6s 19ms/step - loss: 0.0756 - accuracy: 0.9756 - val_loss: 0.4507 - val_accuracy: 0.8892
# Epoch 20/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.1108 - accuracy: 0.9669
# Epoch 20: val_loss did not improve from 0.30672
# 334/334 [==============================] - 5s 15ms/step - loss: 0.1111 - accuracy: 0.9670 - val_loss: 0.4149 - val_accuracy: 0.8593
# 21/21 [==============================] - 0s 7ms/step - loss: 0.4149 - accuracy: 0.8593
# Epoch 1/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2547 - accuracy: 0.9356
# Epoch 1: val_loss improved from inf to 0.10318, saving model to DRCNN_checkpoint_1.h5
# 334/334 [==============================] - 16s 19ms/step - loss: 0.2547 - accuracy: 0.9356 - val_loss: 0.1032 - val_accuracy: 0.9820
# Epoch 2/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.1737 - accuracy: 0.9503
# Epoch 2: val_loss improved from 0.10318 to 0.09861, saving model to DRCNN_checkpoint_1.h5
# 334/334 [==============================] - 7s 20ms/step - loss: 0.1743 - accuracy: 0.9502 - val_loss: 0.0986 - val_accuracy: 0.9640
# Epoch 3/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.1186 - accuracy: 0.9635
# Epoch 3: val_loss did not improve from 0.09861
# 334/334 [==============================] - 5s 15ms/step - loss: 0.1191 - accuracy: 0.9633 - val_loss: 0.1041 - val_accuracy: 0.9640
# Epoch 4/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.1182 - accuracy: 0.9595
# Epoch 4: val_loss did not improve from 0.09861
# 334/334 [==============================] - 5s 15ms/step - loss: 0.1181 - accuracy: 0.9595 - val_loss: 0.1199 - val_accuracy: 0.9550
# Epoch 5/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.1095 - accuracy: 0.9610
# Epoch 5: val_loss did not improve from 0.09861
# 334/334 [==============================] - 6s 19ms/step - loss: 0.1107 - accuracy: 0.9607 - val_loss: 0.1474 - val_accuracy: 0.9430
# Epoch 6/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.1010 - accuracy: 0.9568
# Epoch 6: val_loss did not improve from 0.09861
# 334/334 [==============================] - 5s 14ms/step - loss: 0.1005 - accuracy: 0.9569 - val_loss: 0.1624 - val_accuracy: 0.9295
# Epoch 7/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.1458 - accuracy: 0.9384
# Epoch 7: val_loss did not improve from 0.09861
# 334/334 [==============================] - 5s 16ms/step - loss: 0.1456 - accuracy: 0.9386 - val_loss: 0.1799 - val_accuracy: 0.9070
# Epoch 8/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.1030 - accuracy: 0.9688
# Epoch 8: val_loss did not improve from 0.09861
# 334/334 [==============================] - 6s 17ms/step - loss: 0.1025 - accuracy: 0.9689 - val_loss: 0.1470 - val_accuracy: 0.9400
# Epoch 9/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.0930 - accuracy: 0.9765
# Epoch 9: val_loss did not improve from 0.09861
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0928 - accuracy: 0.9760 - val_loss: 0.1875 - val_accuracy: 0.9295
# Epoch 10/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.1152 - accuracy: 0.9602
# Epoch 10: val_loss did not improve from 0.09861
# 334/334 [==============================] - 6s 18ms/step - loss: 0.1150 - accuracy: 0.9603 - val_loss: 0.2326 - val_accuracy: 0.9055
# Epoch 11/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.1273 - accuracy: 0.9606
# Epoch 11: val_loss did not improve from 0.09861
# 334/334 [==============================] - 5s 16ms/step - loss: 0.1280 - accuracy: 0.9603 - val_loss: 0.2013 - val_accuracy: 0.9415
# Epoch 12/20
# 334/334 [==============================] - ETA: 0s - loss: 0.0860 - accuracy: 0.9693
# Epoch 12: val_loss did not improve from 0.09861
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0860 - accuracy: 0.9693 - val_loss: 0.1929 - val_accuracy: 0.9100
# Epoch 13/20
# 334/334 [==============================] - ETA: 0s - loss: 0.0748 - accuracy: 0.9734
# Epoch 13: val_loss did not improve from 0.09861
# 334/334 [==============================] - 6s 19ms/step - loss: 0.0748 - accuracy: 0.9734 - val_loss: 0.2766 - val_accuracy: 0.9100
# Epoch 14/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.0796 - accuracy: 0.9702
# Epoch 14: val_loss did not improve from 0.09861
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0793 - accuracy: 0.9700 - val_loss: 0.2699 - val_accuracy: 0.9175
# Epoch 15/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.1348 - accuracy: 0.9512
# Epoch 15: val_loss did not improve from 0.09861
# 334/334 [==============================] - 5s 14ms/step - loss: 0.1346 - accuracy: 0.9513 - val_loss: 0.2850 - val_accuracy: 0.9220
# Epoch 16/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.1019 - accuracy: 0.9656
# Epoch 16: val_loss did not improve from 0.09861
# 334/334 [==============================] - 6s 19ms/step - loss: 0.1019 - accuracy: 0.9652 - val_loss: 0.2517 - val_accuracy: 0.9325
# Epoch 17/20
# 334/334 [==============================] - ETA: 0s - loss: 0.0835 - accuracy: 0.9801
# Epoch 17: val_loss did not improve from 0.09861
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0835 - accuracy: 0.9801 - val_loss: 0.3313 - val_accuracy: 0.8981
# Epoch 18/20
# 334/334 [==============================] - ETA: 0s - loss: 0.1222 - accuracy: 0.9682
# Epoch 18: val_loss did not improve from 0.09861
# 334/334 [==============================] - 6s 18ms/step - loss: 0.1222 - accuracy: 0.9682 - val_loss: 0.1701 - val_accuracy: 0.9385
# Epoch 19/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.0795 - accuracy: 0.9797
# Epoch 19: val_loss did not improve from 0.09861
# 334/334 [==============================] - 6s 18ms/step - loss: 0.0797 - accuracy: 0.9798 - val_loss: 0.2153 - val_accuracy: 0.9535
# Epoch 20/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.0656 - accuracy: 0.9841
# Epoch 20: val_loss did not improve from 0.09861
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0653 - accuracy: 0.9843 - val_loss: 0.1875 - val_accuracy: 0.9415
# 21/21 [==============================] - 0s 6ms/step - loss: 0.1875 - accuracy: 0.9415
# Epoch 1/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.1198 - accuracy: 0.9620
# Epoch 1: val_loss improved from inf to 0.03565, saving model to DRCNN_checkpoint_2.h5
# 334/334 [==============================] - 19s 22ms/step - loss: 0.1228 - accuracy: 0.9618 - val_loss: 0.0357 - val_accuracy: 0.9910
# Epoch 2/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.0775 - accuracy: 0.9717
# Epoch 2: val_loss did not improve from 0.03565
# 334/334 [==============================] - 7s 21ms/step - loss: 0.0769 - accuracy: 0.9719 - val_loss: 0.0566 - val_accuracy: 0.9820
# Epoch 3/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.0981 - accuracy: 0.9771
# Epoch 3: val_loss did not improve from 0.03565
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0979 - accuracy: 0.9771 - val_loss: 0.0475 - val_accuracy: 0.9805
# Epoch 4/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.0673 - accuracy: 0.9737
# Epoch 4: val_loss did not improve from 0.03565
# 334/334 [==============================] - 5s 16ms/step - loss: 0.0673 - accuracy: 0.9738 - val_loss: 0.1016 - val_accuracy: 0.9475
# Epoch 5/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.0805 - accuracy: 0.9655
# Epoch 5: val_loss did not improve from 0.03565
# 334/334 [==============================] - 6s 18ms/step - loss: 0.0804 - accuracy: 0.9655 - val_loss: 0.0907 - val_accuracy: 0.9685
# Epoch 6/20
# 334/334 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9880
# Epoch 6: val_loss did not improve from 0.03565
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0349 - accuracy: 0.9880 - val_loss: 0.1294 - val_accuracy: 0.9640
# Epoch 7/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.0836 - accuracy: 0.9722
# Epoch 7: val_loss did not improve from 0.03565
# 334/334 [==============================] - 5s 16ms/step - loss: 0.0835 - accuracy: 0.9723 - val_loss: 0.1755 - val_accuracy: 0.9340
# Epoch 8/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.0866 - accuracy: 0.9713
# Epoch 8: val_loss did not improve from 0.03565
# 334/334 [==============================] - 6s 17ms/step - loss: 0.0863 - accuracy: 0.9715 - val_loss: 0.1682 - val_accuracy: 0.9490
# Epoch 9/20
# 334/334 [==============================] - ETA: 0s - loss: 0.0523 - accuracy: 0.9820
# Epoch 9: val_loss did not improve from 0.03565
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0523 - accuracy: 0.9820 - val_loss: 0.2347 - val_accuracy: 0.9535
# Epoch 10/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.1471 - accuracy: 0.9673
# Epoch 10: val_loss did not improve from 0.03565
# 334/334 [==============================] - 6s 17ms/step - loss: 0.1469 - accuracy: 0.9674 - val_loss: 0.2059 - val_accuracy: 0.9460
# Epoch 11/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.0493 - accuracy: 0.9800
# Epoch 11: val_loss did not improve from 0.03565
# 334/334 [==============================] - 5s 16ms/step - loss: 0.0491 - accuracy: 0.9801 - val_loss: 0.2475 - val_accuracy: 0.9520
# Epoch 12/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.0667 - accuracy: 0.9793
# Epoch 12: val_loss did not improve from 0.03565
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0672 - accuracy: 0.9790 - val_loss: 0.2098 - val_accuracy: 0.9220
# Epoch 13/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.0937 - accuracy: 0.9676
# Epoch 13: val_loss did not improve from 0.03565
# 334/334 [==============================] - 6s 19ms/step - loss: 0.0932 - accuracy: 0.9678 - val_loss: 0.2108 - val_accuracy: 0.9190
# Epoch 14/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.1187 - accuracy: 0.9663
# Epoch 14: val_loss did not improve from 0.03565
# 334/334 [==============================] - 5s 15ms/step - loss: 0.1177 - accuracy: 0.9667 - val_loss: 0.1948 - val_accuracy: 0.9490
# Epoch 15/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.0850 - accuracy: 0.9724
# Epoch 15: val_loss did not improve from 0.03565
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0845 - accuracy: 0.9726 - val_loss: 0.2049 - val_accuracy: 0.9475
# Epoch 16/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.0930 - accuracy: 0.9693
# Epoch 16: val_loss did not improve from 0.03565
# 334/334 [==============================] - 7s 19ms/step - loss: 0.0925 - accuracy: 0.9689 - val_loss: 0.2205 - val_accuracy: 0.9445
# Epoch 17/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.0490 - accuracy: 0.9872
# Epoch 17: val_loss did not improve from 0.03565
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0488 - accuracy: 0.9873 - val_loss: 0.1847 - val_accuracy: 0.9565
# Epoch 18/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.0346 - accuracy: 0.9887
# Epoch 18: val_loss did not improve from 0.03565
# 334/334 [==============================] - 5s 15ms/step - loss: 0.0344 - accuracy: 0.9888 - val_loss: 0.2219 - val_accuracy: 0.9535
# Epoch 19/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.0614 - accuracy: 0.9854
# Epoch 19: val_loss did not improve from 0.03565
# 334/334 [==============================] - 6s 19ms/step - loss: 0.0613 - accuracy: 0.9854 - val_loss: 0.3618 - val_accuracy: 0.9430
# Epoch 20/20
# 334/334 [==============================] - ETA: 0s - loss: 0.0843 - accuracy: 0.9801
# Epoch 20: val_loss did not improve from 0.03565
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0843 - accuracy: 0.9801 - val_loss: 0.2434 - val_accuracy: 0.9400
# 21/21 [==============================] - 0s 7ms/step - loss: 0.2434 - accuracy: 0.9400
# Epoch 1/20
# 334/334 [==============================] - ETA: 0s - loss: 0.2002 - accuracy: 0.9618
# Epoch 1: val_loss improved from inf to 0.05213, saving model to DRCNN_checkpoint_3.h5
# 334/334 [==============================] - 16s 18ms/step - loss: 0.2002 - accuracy: 0.9618 - val_loss: 0.0521 - val_accuracy: 0.9850
# Epoch 2/20
# 334/334 [==============================] - ETA: 0s - loss: 0.0819 - accuracy: 0.9741
# Epoch 2: val_loss improved from 0.05213 to 0.02833, saving model to DRCNN_checkpoint_3.h5
# 334/334 [==============================] - 6s 19ms/step - loss: 0.0819 - accuracy: 0.9741 - val_loss: 0.0283 - val_accuracy: 0.9925
# Epoch 3/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.0495 - accuracy: 0.9827
# Epoch 3: val_loss did not improve from 0.02833
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0523 - accuracy: 0.9820 - val_loss: 0.0429 - val_accuracy: 0.9850
# Epoch 4/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.0557 - accuracy: 0.9801
# Epoch 4: val_loss did not improve from 0.02833
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0556 - accuracy: 0.9801 - val_loss: 0.0453 - val_accuracy: 0.9865
# Epoch 5/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.0342 - accuracy: 0.9887
# Epoch 5: val_loss did not improve from 0.02833
# 334/334 [==============================] - 6s 19ms/step - loss: 0.0355 - accuracy: 0.9884 - val_loss: 0.1044 - val_accuracy: 0.9700
# Epoch 6/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.0516 - accuracy: 0.9807
# Epoch 6: val_loss did not improve from 0.02833
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0519 - accuracy: 0.9809 - val_loss: 0.0919 - val_accuracy: 0.9805
# Epoch 7/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.0249 - accuracy: 0.9917
# Epoch 7: val_loss did not improve from 0.02833
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0249 - accuracy: 0.9918 - val_loss: 0.0938 - val_accuracy: 0.9790
# Epoch 8/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.0364 - accuracy: 0.9857
# Epoch 8: val_loss did not improve from 0.02833
# 334/334 [==============================] - 6s 19ms/step - loss: 0.0363 - accuracy: 0.9858 - val_loss: 0.1106 - val_accuracy: 0.9835
# Epoch 9/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.0599 - accuracy: 0.9808
# Epoch 9: val_loss did not improve from 0.02833
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0597 - accuracy: 0.9809 - val_loss: 0.2040 - val_accuracy: 0.9580
# Epoch 10/20
# 334/334 [==============================] - ETA: 0s - loss: 0.0629 - accuracy: 0.9712
# Epoch 10: val_loss did not improve from 0.02833
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0629 - accuracy: 0.9712 - val_loss: 0.1552 - val_accuracy: 0.9790
# Epoch 11/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.0267 - accuracy: 0.9880
# Epoch 11: val_loss did not improve from 0.02833
# 334/334 [==============================] - 6s 19ms/step - loss: 0.0267 - accuracy: 0.9880 - val_loss: 0.1319 - val_accuracy: 0.9835
# Epoch 12/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.0656 - accuracy: 0.9771
# Epoch 12: val_loss did not improve from 0.02833
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0655 - accuracy: 0.9771 - val_loss: 0.1611 - val_accuracy: 0.9685
# Epoch 13/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.0584 - accuracy: 0.9846
# Epoch 13: val_loss did not improve from 0.02833
# 334/334 [==============================] - 6s 17ms/step - loss: 0.0583 - accuracy: 0.9846 - val_loss: 0.1005 - val_accuracy: 0.9790
# Epoch 14/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.0639 - accuracy: 0.9763
# Epoch 14: val_loss did not improve from 0.02833
# 334/334 [==============================] - 8s 25ms/step - loss: 0.0639 - accuracy: 0.9760 - val_loss: 0.1717 - val_accuracy: 0.9505
# Epoch 15/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.0376 - accuracy: 0.9860
# Epoch 15: val_loss did not improve from 0.02833
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0374 - accuracy: 0.9861 - val_loss: 0.1621 - val_accuracy: 0.9685
# Epoch 16/20
# 334/334 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9910
# Epoch 16: val_loss did not improve from 0.02833
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0284 - accuracy: 0.9910 - val_loss: 0.3207 - val_accuracy: 0.9430
# Epoch 17/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.0675 - accuracy: 0.9789
# Epoch 17: val_loss did not improve from 0.02833
# 334/334 [==============================] - 6s 19ms/step - loss: 0.0670 - accuracy: 0.9790 - val_loss: 0.1862 - val_accuracy: 0.9580
# Epoch 18/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.0874 - accuracy: 0.9690
# Epoch 18: val_loss did not improve from 0.02833
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0877 - accuracy: 0.9685 - val_loss: 0.1299 - val_accuracy: 0.9595
# Epoch 19/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.0557 - accuracy: 0.9823
# Epoch 19: val_loss did not improve from 0.02833
# 334/334 [==============================] - 5s 16ms/step - loss: 0.0556 - accuracy: 0.9824 - val_loss: 0.1541 - val_accuracy: 0.9625
# Epoch 20/20
# 330/334 [============================>.] - ETA: 0s - loss: 0.0470 - accuracy: 0.9864
# Epoch 20: val_loss did not improve from 0.02833
# 334/334 [==============================] - 6s 18ms/step - loss: 0.0472 - accuracy: 0.9858 - val_loss: 0.1739 - val_accuracy: 0.9475
# 21/21 [==============================] - 0s 6ms/step - loss: 0.1739 - accuracy: 0.9475
# Epoch 1/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.1496 - accuracy: 0.9721
# Epoch 1: val_loss improved from inf to 0.03127, saving model to DRCNN_checkpoint_4.h5
# 334/334 [==============================] - 16s 20ms/step - loss: 0.1529 - accuracy: 0.9719 - val_loss: 0.0313 - val_accuracy: 0.9910
# Epoch 2/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.0442 - accuracy: 0.9797
# Epoch 2: val_loss improved from 0.03127 to 0.02595, saving model to DRCNN_checkpoint_4.h5
# 334/334 [==============================] - 7s 20ms/step - loss: 0.0440 - accuracy: 0.9798 - val_loss: 0.0260 - val_accuracy: 0.9925
# Epoch 3/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.0396 - accuracy: 0.9880
# Epoch 3: val_loss did not improve from 0.02595
# 334/334 [==============================] - 5s 15ms/step - loss: 0.0396 - accuracy: 0.9880 - val_loss: 0.0466 - val_accuracy: 0.9865
# Epoch 4/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.0525 - accuracy: 0.9894
# Epoch 4: val_loss improved from 0.02595 to 0.02117, saving model to DRCNN_checkpoint_4.h5
# 334/334 [==============================] - 5s 16ms/step - loss: 0.0522 - accuracy: 0.9895 - val_loss: 0.0212 - val_accuracy: 0.9955
# Epoch 5/20
# 334/334 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9906
# Epoch 5: val_loss did not improve from 0.02117
# 334/334 [==============================] - 6s 19ms/step - loss: 0.0284 - accuracy: 0.9906 - val_loss: 0.0923 - val_accuracy: 0.9715
# Epoch 6/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.1044 - accuracy: 0.9796
# Epoch 6: val_loss did not improve from 0.02117
# 334/334 [==============================] - 5s 15ms/step - loss: 0.1044 - accuracy: 0.9794 - val_loss: 0.0958 - val_accuracy: 0.9685
# Epoch 7/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.0645 - accuracy: 0.9804
# Epoch 7: val_loss did not improve from 0.02117
# 334/334 [==============================] - 6s 18ms/step - loss: 0.0642 - accuracy: 0.9805 - val_loss: 0.0829 - val_accuracy: 0.9730
# Epoch 8/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.0423 - accuracy: 0.9853
# Epoch 8: val_loss did not improve from 0.02117
# 334/334 [==============================] - 5s 16ms/step - loss: 0.0432 - accuracy: 0.9850 - val_loss: 0.1147 - val_accuracy: 0.9790
# Epoch 9/20
# 334/334 [==============================] - ETA: 0s - loss: 0.0465 - accuracy: 0.9790
# Epoch 9: val_loss did not improve from 0.02117
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0465 - accuracy: 0.9790 - val_loss: 0.1100 - val_accuracy: 0.9685
# Epoch 10/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.0422 - accuracy: 0.9887
# Epoch 10: val_loss did not improve from 0.02117
# 334/334 [==============================] - 6s 18ms/step - loss: 0.0424 - accuracy: 0.9884 - val_loss: 0.1744 - val_accuracy: 0.9715
# Epoch 11/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.0349 - accuracy: 0.9876
# Epoch 11: val_loss did not improve from 0.02117
# 334/334 [==============================] - 5s 16ms/step - loss: 0.0347 - accuracy: 0.9876 - val_loss: 0.0875 - val_accuracy: 0.9775
# Epoch 12/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.0342 - accuracy: 0.9936
# Epoch 12: val_loss did not improve from 0.02117
# 334/334 [==============================] - 5s 15ms/step - loss: 0.0340 - accuracy: 0.9936 - val_loss: 0.1191 - val_accuracy: 0.9595
# Epoch 13/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.0306 - accuracy: 0.9917
# Epoch 13: val_loss did not improve from 0.02117
# 334/334 [==============================] - 6s 19ms/step - loss: 0.0305 - accuracy: 0.9918 - val_loss: 0.0944 - val_accuracy: 0.9790
# Epoch 14/20
# 332/334 [============================>.] - ETA: 0s - loss: 0.0112 - accuracy: 0.9970
# Epoch 14: val_loss did not improve from 0.02117
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0111 - accuracy: 0.9970 - val_loss: 0.1178 - val_accuracy: 0.9775
# Epoch 15/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.0192 - accuracy: 0.9959
# Epoch 15: val_loss did not improve from 0.02117
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0191 - accuracy: 0.9959 - val_loss: 0.1400 - val_accuracy: 0.9715
# Epoch 16/20
# 331/334 [============================>.] - ETA: 0s - loss: 0.0364 - accuracy: 0.9909
# Epoch 16: val_loss did not improve from 0.02117
# 334/334 [==============================] - 7s 20ms/step - loss: 0.0367 - accuracy: 0.9903 - val_loss: 0.2145 - val_accuracy: 0.9445
# Epoch 17/20
# 333/334 [============================>.] - ETA: 0s - loss: 0.0324 - accuracy: 0.9876
# Epoch 17: val_loss did not improve from 0.02117
# 334/334 [==============================] - 5s 14ms/step - loss: 0.0324 - accuracy: 0.9876 - val_loss: 0.1588 - val_accuracy: 0.9685
# Epoch 18/20
# 334/334 [==============================] - ETA: 0s - loss: 0.0421 - accuracy: 0.9843
# Epoch 18: val_loss did not improve from 0.02117
# 334/334 [==============================] - 5s 16ms/step - loss: 0.0421 - accuracy: 0.9843 - val_loss: 0.1878 - val_accuracy: 0.9595
# Epoch 19/20
# 334/334 [==============================] - ETA: 0s - loss: 0.0395 - accuracy: 0.9858
# Epoch 19: val_loss did not improve from 0.02117
# 334/334 [==============================] - 8s 23ms/step - loss: 0.0395 - accuracy: 0.9858 - val_loss: 0.1024 - val_accuracy: 0.9670
# Epoch 20/20
# 334/334 [==============================] - ETA: 0s - loss: 0.0688 - accuracy: 0.9756
# Epoch 20: val_loss did not improve from 0.02117
# 334/334 [==============================] - 5s 16ms/step - loss: 0.0688 - accuracy: 0.9756 - val_loss: 0.2292 - val_accuracy: 0.9235
# 21/21 [==============================] - 0s 7ms/step - loss: 0.2292 - accuracy: 0.9235
# Average loss: 0.24976588785648346
# Average accuracy: 0.9223810076713562

# %%
DRCNN_model = load_model("/content/DRCNN_checkpoint_4.h5")

# %%
metric(x_train,y_train,DRCNN_model)
# Out:
# 79/79 [==============================] - 2s 6ms/step
# Accuracy: 0.9980205859065716
# Precision: 1.0
# F1-score: 0.9940968122786306
# ROC-curve: 0.998812351543943
# Confusion matrix:

# %%
metric(x_test,y_test,DRCNN_model)
# Out:
# 26/26 [==============================] - 0s 9ms/step
# Accuracy: 0.9962962962962963
# Precision: 0.9925925925925926
# F1-score: 0.988929889298893
# ROC-curve: 0.9948148148148148
# Confusion matrix:

# %% [markdown]
# # **CNN**

# %%
def CNN(input_shape=(32, 32, 1)):
  # Define the CNN model
  model = tf.keras.Sequential()

  # Add the convolutional layers
  model.add(layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 1)))
  model.add(layers.Conv2D(64, kernel_size=(3, 3), activation='relu'))

  # Add the pooling layers
  model.add(layers.MaxPooling2D(pool_size=(2, 2)))

  # Add the flatten layer
  model.add(layers.Flatten())

  # Add the fully connected layers
  model.add(layers.Dense(128, activation='relu'))
  model.add(layers.Dense(1, activation='sigmoid'))
  model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

  return model

# %%
CNN_model = None
CNN_model = CNN()
K_Fold_Val("CNN", CNN_model, x, y, 30, 16, K=6)
# Out:
# Epoch 1/30
# 174/174 [==============================] - ETA: 0s - loss: 0.6050 - accuracy: 0.7187
# Epoch 1: val_loss improved from inf to 0.49913, saving model to CNN_checkpoint_0.h5
# 174/174 [==============================] - 16s 82ms/step - loss: 0.6050 - accuracy: 0.7187 - val_loss: 0.4991 - val_accuracy: 0.7626
# Epoch 2/30
# 174/174 [==============================] - ETA: 0s - loss: 0.3610 - accuracy: 0.8385
# Epoch 2: val_loss improved from 0.49913 to 0.23546, saving model to CNN_checkpoint_0.h5
# 174/174 [==============================] - 13s 74ms/step - loss: 0.3610 - accuracy: 0.8385 - val_loss: 0.2355 - val_accuracy: 0.9245
# Epoch 3/30
# 105/174 [=================>............] - ETA: 4s - loss: 0.2760 - accuracy: 0.8845
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-e3bec58cb10d> in <cell line: 3>()
#       1 CNN_model = None
#       2 CNN_model = CNN()
# ----> 3 K_Fold_Val("CNN", CNN_model, x, y, 30, 16, K=6)
#
# <ipython-input-22-41ded6c9866a> in K_Fold_Val(model_name, model, X, y, epochs, batch_size, K)
#      25
#      26       # train model with checkpoint callback
# ---> 27       model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, class_weight=class_weights, validation_data=(X_test, y_test), callbacks=[checkpoint])
#      28
#      29       # evaluate model on testing set
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1683                         ):
#    1684                             callbacks.on_train_batch_begin(step)
# -> 1685                             tmp_logs = self.train_function(iterator)
#    1686                             if data_handler.should_sync:
#    1687                                 context.async_wait()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     892
#     893       with OptionalXlaContext(self._jit_compile):
# --> 894         result = self._call(*args, **kwds)
#     895
#     896       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     924       # In this case we have created variables on the first call, so we run the
#     925       # defunned version which is guaranteed to never create variables.
# --> 926       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927     elif self._variable_creation_fn is not None:
#     928       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     141       (concrete_function,
#     142        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143     return concrete_function._call_flat(
#     144         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     145
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1755         and executing_eagerly):
#    1756       # No tape is watching; skip to running the function.
# -> 1757       return self._build_call_outputs(self._inference_function.call(
#    1758           ctx, args, cancellation_manager=cancellation_manager))
#    1759     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     379       with _InterpolateFunctionError(self):
#     380         if cancellation_manager is None:
# --> 381           outputs = execute.execute(
#     382               str(self.signature.name),
#     383               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
for i in range(5):
  print(f"-------------------------------------------{i}----------------------------------------------")
  eegmodel = load_model(f"/content/CNN_checkpoint_{i}.h5")
  print("-----------------------------------------training--------------------------------------------")
  metric(x_train,y_train,eegmodel)
  print("-----------------------------------------testing---------------------------------------------")
  metric(x_test,y_test,eegmodel)
  print("---------------------------------------------------------------------------------------------")
# Out:
# -------------------------------------------0----------------------------------------------
# -----------------------------------------training--------------------------------------------
# 78/78 [==============================] - 2s 28ms/step
# Accuracy: 0.9557165861513688
# Precision: 0.8164251207729468
# F1-score: 0.8600508905852418
# ROC-curve: 0.9
# Confusion matrix:
# -----------------------------------------testing---------------------------------------------
# 27/27 [==============================] - 1s 28ms/step
# Accuracy: 0.9808153477218226
# Precision: 0.9424460431654677
# F1-score: 0.9424460431654677
# ROC-curve: 0.9654676258992805
# Confusion matrix:
# ---------------------------------------------------------------------------------------------
# -------------------------------------------1----------------------------------------------
# -----------------------------------------training--------------------------------------------
# 78/78 [==============================] - 2s 29ms/step
# Accuracy: 1.0
# Precision: 1.0
# F1-score: 1.0
# ROC-curve: 1.0
# Confusion matrix:
# -----------------------------------------testing---------------------------------------------
# 27/27 [==============================] - 1s 52ms/step
# Accuracy: 0.9976019184652278
# Precision: 1.0
# F1-score: 0.9928571428571429
# ROC-curve: 0.9985611510791367
# Confusion matrix:
# ---------------------------------------------------------------------------------------------
# -------------------------------------------2----------------------------------------------
# -----------------------------------------training--------------------------------------------
# 78/78 [==============================] - 4s 44ms/step
# Accuracy: 1.0
# Precision: 1.0
# F1-score: 1.0
# ROC-curve: 1.0
# Confusion matrix:
# -----------------------------------------testing---------------------------------------------
# 27/27 [==============================] - 1s 28ms/step
# Accuracy: 0.9976019184652278
# Precision: 1.0
# F1-score: 0.9928571428571429
# ROC-curve: 0.9985611510791367
# Confusion matrix:
# ---------------------------------------------------------------------------------------------
# -------------------------------------------3----------------------------------------------
# -----------------------------------------training--------------------------------------------
# 78/78 [==============================] - 2s 29ms/step
# Accuracy: 1.0
# Precision: 1.0
# F1-score: 1.0
# ROC-curve: 1.0
# Confusion matrix:
# -----------------------------------------testing---------------------------------------------
# 27/27 [==============================] - 1s 29ms/step
# Accuracy: 1.0
# Precision: 1.0
# F1-score: 1.0
# ROC-curve: 1.0
# Confusion matrix:
# ---------------------------------------------------------------------------------------------
# -------------------------------------------4----------------------------------------------
# -----------------------------------------training--------------------------------------------
# 78/78 [==============================] - 3s 41ms/step
# Accuracy: 1.0
# Precision: 1.0
# F1-score: 1.0
# ROC-curve: 1.0
# Confusion matrix:
# -----------------------------------------testing---------------------------------------------
# 27/27 [==============================] - 1s 30ms/step
# Accuracy: 0.9988009592326139
# Precision: 0.9928057553956835
# F1-score: 0.996389891696751
# ROC-curve: 0.9964028776978417
# Confusion matrix:
# ---------------------------------------------------------------------------------------------
